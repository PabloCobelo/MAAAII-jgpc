# %% [markdown]
# # Notebook 6: Aprendizaje por refuerzo - Programación dinámica
#
# En este notebook nos familizarizaremos con [Gym](https://www.gymlibrary.dev/), una librería de Python para simular problemas que se pueden resolver utilizando aprendizaje por refuerzo.
# Además, desarrollaremos algunos métodos de control basados en programación dinámica.
#
# ## Gym
# Gym es una herramienta para desarrollar y comparar algoritmos de aprendizaje por refuerzo. Facilita la simulación de interacciones de un agente con entornos muy diversos.
#
# Para utilizar OpenGym, el primer paso es importar la librería. Una vez hecho, podremos crear un entorno que nos permita simular el problema que deseemos de entre los muchos disponibles.
#
# En esta práctica utilizaremos un entorno muy sencillo que simula un *GridWorld*, es decir, un mundo compuesto por casillas por las que el agente podrá desplazarse. En particular, cargaremos el entorno `MiniGrid-Empty-5x5-v0`.

# %%
# Si los paquetes no están instalados, hay que ejecutar estas líneas:
#!pip install gymnasium[classic-control]
# !pip install minigrid
import gymnasium as gym
import minigrid
import numpy as np
env = gym.make('MiniGrid-Empty-5x5-v0', render_mode='rgb_array')
# Out:
# Collecting minigrid
#   Downloading minigrid-3.0.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from minigrid) (2.0.2)
# Requirement already satisfied: gymnasium>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from minigrid) (1.1.1)
# Requirement already satisfied: pygame>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from minigrid) (2.6.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=0.28.1->minigrid) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=0.28.1->minigrid) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=0.28.1->minigrid) (0.0.4)
# Downloading minigrid-3.0.0-py3-none-any.whl (136 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.7/136.7 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: minigrid
# Successfully installed minigrid-3.0.0

# %% [markdown]
# El método `gym.make` devuelve un objeto de tipo entorno que nos ofrece, entre otros, los siguientes métodos y propiedades:
#  - `reset`: Devuelve el entorno a su estado original
#  - `actions`: Muestra una lista de las acciones disponibles
#  - `max_steps`: Fija el número máximo de acciones que puede realizar el agente en cada episodio
#  - `render`: Devuelve una imagen donde aparece representada la situación actual
#  - `step(accion)`: Ejecuta una acción y actualiza el entorno en consecuencia
#
# El objetivo del agente en este problema es alcanzar la meta, representada por una casilla verde. El agente aparece representado como una flecha roja que refleja su posición y orientación.

# %%
# Muestra las acciones disponibles
acciones = env.get_wrapper_attr('actions')
print([a.name for a in acciones])

# Resetea el entorno
env.reset()

# Muestra el entorno en su estado inicial
import matplotlib.pyplot as plt

def muestra_entorno(env:gym.Env) -> None:
    im = plt.imshow(env.render())
    plt.show()
muestra_entorno(env)

# TODO: Ejecuta la acción forward (puedes referirte a la acción i-ésima como acciones(i) o como acciones.nombre) y muestra el entorno de nuevo
print("Moviendo hacia delante")
obs, reward, terminated,truncated, info = env.step(acciones.forward)
muestra_entorno(env)

# TODO: Prueba a ver cómo afectan las distintas acciones al entorno
print("Girando hacia derecha")
obs, reward, terminated,truncated, info = env.step(acciones.right)
muestra_entorno(env)

print("Moviendo hacia delante")
obs, reward, terminated,truncated, info = env.step(acciones.forward)
muestra_entorno(env)

print("Moviendo hacia delante")
obs, reward, terminated,truncated, info = env.step(acciones.forward)
muestra_entorno(env)

print("Girando hacia izquierda")
obs, reward, terminated,truncated, info = env.step(acciones.left)
muestra_entorno(env)

print("Moviendo hacia delante")
obs, reward, terminated,truncated, info = env.step(acciones.forward)
muestra_entorno(env)
# Out:
# ['left', 'right', 'forward', 'pickup', 'drop', 'toggle', 'done']
# Moviendo hacia delante
# Girando hacia derecha
# Moviendo hacia delante
# Moviendo hacia delante
# Girando hacia izquierda
# Moviendo hacia delante

# %% [markdown]
# El método [`step(acción)`](https://gymnasium.farama.org/api/env/#gymnasium.Env.step) devuelve cinco valores:
#  - Observación: Representa lo que puede percibir el agente del entorno en su estado actual
#  - Recompensa: Indica el valor de la señal de recompensa para la ejecución de la acción aplicada en el estado en que se aplicó.
#  - Terminated: Valor booleano que indica si se ha terminado el episodio
#  - Truncated: Valor booleano que indica si el episodio ha alcanzado el número máximo de pasos
#  - Info: Información adicional
#
# De cara a aprender una política, debemos buscar una manera de representar los estados. Habitualmente, el agente se basaría en sus observaciones para generar una representación del estado. Sin embargo, para este problema en particular, vamos a utilizar una representación del estado más sencilla que la observación que puede hacer el agente. Esta labor de representación del estado la llevaría a cabo el **intérprete** en el esquema habitual de un problema de aprendizaje por refuerzo.
# ![Esquema de aprendizaje por refuerzo](https://raw.githubusercontent.com/eirasf/GCED-AA3/94f123b1ad1ec5686d86b8ce7c8cda757a26ca02/lab4/img/Reinforcement_learning_diagram.svg)
#
# El intérprete identificará el estado con un vector de tres componentes que indicarán, respectivamente, la columna, fila y orientación del agente. Las filas/columnas se numerarán del 0 al 2 (de arriba a abajo y derecha a izquierda) y la orientación podrá tomar los siguientes valores:
#  - 0 $\rightarrow$ derecha
#  - 1 $\rightarrow$ abajo
#  - 2 $\rightarrow$ izquierda
#  - 3 $\rightarrow$ arriba
#
# El entorno de este problema nos da acceso directo a dos variables que serán de utilidad:
#  - `agent_pos`: Indica la casilla en la que está el agente. Las casillas del tablero están numeradas del 1 al 3, por lo que será necesario adaptar dicha numeración.
#  - `agent_dir`: Indica la orientación del agente usando el código descrito en el párrafo anterior.
#
#  Puedes acceder a estos valores como `env.get_wrapper_attr('agent_pos')` y `env.get_wrapper_attr('agent_dir')` respectivamente.
# Creemos una función que haga las labores de intérprete y devuelva la codificación del estado actual del entorno:

# %%
from collections import namedtuple

# Representaremos los estados como tuplas con los siguientes campos con nombre:
#  - x: Representa la columna en que se encuentra el agente. La columna visitable más a la izquierda será la 0
#  - y: Representa la fila en que se encuentra el agente. La fila visitable más arriba será la 0
#  - dir: Representa la dirección en que apunta el agente. Respetaremos el código numérico indicado por agent_dir
Estado = namedtuple('Estado', ['x', 'y', 'dir'])

def get_estado(env:gym.Env) -> Estado:
    # TODO - Completa la función
    x = env.get_wrapper_attr('agent_pos')[0] - 1
    y = env.get_wrapper_attr('agent_pos')[1] - 1
    dir = env.get_wrapper_attr('agent_dir')
    return Estado(x, y, dir)

env.reset()

# COMPROBACIÓN
estado_actual = get_estado(env)
assert estado_actual.x == 0, f'El estado inmediatamente después de resetear debe indicar x=0 y el tuyo indica {estado_actual.x}'
assert estado_actual.y == 0, f'El estado inmediatamente después de resetear debe indicar y=0 y el tuyo indica {estado_actual.y}'
assert estado_actual.dir == 0, f'El estado inmediatamente después de resetear debe indicar dir=0 y el tuyo indica {estado_actual.dir}'

# %% [markdown]
# ### Simulación de un episodio con política aleatoria
#
# Ahora que sabemos manejar el entorno, vamos a probar qué tal funciona una política aleatoria.
#
# Crea un bucle que simule un episodio completo siguiendo una política aleatoria, es decir, que aplique una acción aleatoria hasta que el entorno nos indique que el episodio ha acabado. Puedes obtener una acción aleatoria llamando a `env.action_space.sample()`.
#
# Muestra el entorno tras aplicar cada acción. Además muestra un mensaje que indique:
#  - Qué número de paso se ha ejecutado
#  - El nombre de la acción aplicada
#  - El estado resultante
#  - La recompensa obtenida en ese paso
#  - Si ha terminado la ejecución

# %%
# Eliminamos el límite de pasos por episodio. Solo acabará el episodio al alcanzar la meta.
env.unwrapped.max_steps = 9999


env.reset()
completado = False
contador = 0
while not completado:
    # TODO - Completa el bucle
    action = env.action_space.sample()
    obs, reward, terminated, truncated, info = env.step(action)
    muestra_entorno(env)
    contador += 1
    print(f"PASO {contador}")
    print(f"Acción: {acciones(action).name}")
    print(f"Estado: {get_estado(env)}")
    print(f"Recompensa: {reward}")
    print("#########################################################")
    if terminated or truncated:
        completado = True
# Out:
# PASO 1
# Acción: right
# Estado: Estado(x=0, y=0, dir=1)
# Recompensa: 0
# #########################################################
# PASO 2
# Acción: drop
# Estado: Estado(x=0, y=0, dir=1)
# Recompensa: 0
# #########################################################
# PASO 3
# Acción: pickup
# Estado: Estado(x=0, y=0, dir=1)
# Recompensa: 0
# #########################################################
# PASO 4
# Acción: toggle
# Estado: Estado(x=0, y=0, dir=1)
# Recompensa: 0
# #########################################################
# PASO 5
# Acción: forward
# Estado: Estado(x=np.int64(0), y=np.int64(1), dir=1)
# Recompensa: 0
# #########################################################
# PASO 6
# Acción: toggle
# Estado: Estado(x=np.int64(0), y=np.int64(1), dir=1)
# Recompensa: 0
# #########################################################
# PASO 7
# Acción: left
# Estado: Estado(x=np.int64(0), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 8
# Acción: left
# Estado: Estado(x=np.int64(0), y=np.int64(1), dir=3)
# Recompensa: 0
# #########################################################
# PASO 9
# Acción: left
# Estado: Estado(x=np.int64(0), y=np.int64(1), dir=2)
# Recompensa: 0
# #########################################################
# PASO 10
# Acción: drop
# Estado: Estado(x=np.int64(0), y=np.int64(1), dir=2)
# Recompensa: 0
# #########################################################
# PASO 11
# Acción: pickup
# Estado: Estado(x=np.int64(0), y=np.int64(1), dir=2)
# Recompensa: 0
# #########################################################
# PASO 12
# Acción: drop
# Estado: Estado(x=np.int64(0), y=np.int64(1), dir=2)
# Recompensa: 0
# #########################################################
# PASO 13
# Acción: right
# Estado: Estado(x=np.int64(0), y=np.int64(1), dir=3)
# Recompensa: 0
# #########################################################
# PASO 14
# Acción: left
# Estado: Estado(x=np.int64(0), y=np.int64(1), dir=2)
# Recompensa: 0
# #########################################################
# PASO 15
# Acción: left
# Estado: Estado(x=np.int64(0), y=np.int64(1), dir=1)
# Recompensa: 0
# #########################################################
# PASO 16
# Acción: pickup
# Estado: Estado(x=np.int64(0), y=np.int64(1), dir=1)
# Recompensa: 0
# #########################################################
# PASO 17
# Acción: forward
# Estado: Estado(x=np.int64(0), y=np.int64(2), dir=1)
# Recompensa: 0
# #########################################################
# PASO 18
# Acción: left
# Estado: Estado(x=np.int64(0), y=np.int64(2), dir=0)
# Recompensa: 0
# #########################################################
# PASO 19
# Acción: forward
# Estado: Estado(x=np.int64(1), y=np.int64(2), dir=0)
# Recompensa: 0
# #########################################################
# PASO 20
# Acción: done
# Estado: Estado(x=np.int64(1), y=np.int64(2), dir=0)
# Recompensa: 0
# #########################################################
# PASO 21
# Acción: done
# Estado: Estado(x=np.int64(1), y=np.int64(2), dir=0)
# Recompensa: 0
# #########################################################
# PASO 22
# Acción: left
# Estado: Estado(x=np.int64(1), y=np.int64(2), dir=3)
# Recompensa: 0
# #########################################################
# PASO 23
# Acción: done
# Estado: Estado(x=np.int64(1), y=np.int64(2), dir=3)
# Recompensa: 0
# #########################################################
# PASO 24
# Acción: forward
# Estado: Estado(x=np.int64(1), y=np.int64(1), dir=3)
# Recompensa: 0
# #########################################################
# PASO 25
# Acción: toggle
# Estado: Estado(x=np.int64(1), y=np.int64(1), dir=3)
# Recompensa: 0
# #########################################################
# PASO 26
# Acción: right
# Estado: Estado(x=np.int64(1), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 27
# Acción: forward
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 28
# Acción: forward
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 29
# Acción: done
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 30
# Acción: done
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 31
# Acción: done
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 32
# Acción: pickup
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 33
# Acción: toggle
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 34
# Acción: drop
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 35
# Acción: forward
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 36
# Acción: drop
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 37
# Acción: pickup
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 38
# Acción: left
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=3)
# Recompensa: 0
# #########################################################
# PASO 39
# Acción: done
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=3)
# Recompensa: 0
# #########################################################
# PASO 40
# Acción: toggle
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=3)
# Recompensa: 0
# #########################################################
# PASO 41
# Acción: forward
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa: 0
# #########################################################
# PASO 42
# Acción: done
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa: 0
# #########################################################
# PASO 43
# Acción: right
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=0)
# Recompensa: 0
# #########################################################
# PASO 44
# Acción: forward
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=0)
# Recompensa: 0
# #########################################################
# PASO 45
# Acción: right
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=1)
# Recompensa: 0
# #########################################################
# PASO 46
# Acción: done
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=1)
# Recompensa: 0
# #########################################################
# PASO 47
# Acción: done
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=1)
# Recompensa: 0
# #########################################################
# PASO 48
# Acción: done
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=1)
# Recompensa: 0
# #########################################################
# PASO 49
# Acción: forward
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=1)
# Recompensa: 0
# #########################################################
# PASO 50
# Acción: right
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=2)
# Recompensa: 0
# #########################################################
# PASO 51
# Acción: forward
# Estado: Estado(x=np.int64(1), y=np.int64(1), dir=2)
# Recompensa: 0
# #########################################################
# PASO 52
# Acción: pickup
# Estado: Estado(x=np.int64(1), y=np.int64(1), dir=2)
# Recompensa: 0
# #########################################################
# PASO 53
# Acción: right
# Estado: Estado(x=np.int64(1), y=np.int64(1), dir=3)
# Recompensa: 0
# #########################################################
# PASO 54
# Acción: left
# Estado: Estado(x=np.int64(1), y=np.int64(1), dir=2)
# Recompensa: 0
# #########################################################
# PASO 55
# Acción: done
# Estado: Estado(x=np.int64(1), y=np.int64(1), dir=2)
# Recompensa: 0
# #########################################################
# PASO 56
# Acción: done
# Estado: Estado(x=np.int64(1), y=np.int64(1), dir=2)
# Recompensa: 0
# #########################################################
# PASO 57
# Acción: pickup
# Estado: Estado(x=np.int64(1), y=np.int64(1), dir=2)
# Recompensa: 0
# #########################################################
# PASO 58
# Acción: done
# Estado: Estado(x=np.int64(1), y=np.int64(1), dir=2)
# Recompensa: 0
# #########################################################
# PASO 59
# Acción: right
# Estado: Estado(x=np.int64(1), y=np.int64(1), dir=3)
# Recompensa: 0
# #########################################################
# PASO 60
# Acción: drop
# Estado: Estado(x=np.int64(1), y=np.int64(1), dir=3)
# Recompensa: 0
# #########################################################
# PASO 61
# Acción: drop
# Estado: Estado(x=np.int64(1), y=np.int64(1), dir=3)
# Recompensa: 0
# #########################################################
# PASO 62
# Acción: right
# Estado: Estado(x=np.int64(1), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 63
# Acción: forward
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 64
# Acción: right
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=1)
# Recompensa: 0
# #########################################################
# PASO 65
# Acción: toggle
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=1)
# Recompensa: 0
# #########################################################
# PASO 66
# Acción: right
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=2)
# Recompensa: 0
# #########################################################
# PASO 67
# Acción: done
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=2)
# Recompensa: 0
# #########################################################
# PASO 68
# Acción: done
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=2)
# Recompensa: 0
# #########################################################
# PASO 69
# Acción: right
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=3)
# Recompensa: 0
# #########################################################
# PASO 70
# Acción: toggle
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=3)
# Recompensa: 0
# #########################################################
# PASO 71
# Acción: done
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=3)
# Recompensa: 0
# #########################################################
# PASO 72
# Acción: done
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=3)
# Recompensa: 0
# #########################################################
# PASO 73
# Acción: drop
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=3)
# Recompensa: 0
# #########################################################
# PASO 74
# Acción: done
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=3)
# Recompensa: 0
# #########################################################
# PASO 75
# Acción: left
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=2)
# Recompensa: 0
# #########################################################
# PASO 76
# Acción: toggle
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=2)
# Recompensa: 0
# #########################################################
# PASO 77
# Acción: toggle
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=2)
# Recompensa: 0
# #########################################################
# PASO 78
# Acción: forward
# Estado: Estado(x=np.int64(1), y=np.int64(1), dir=2)
# Recompensa: 0
# #########################################################
# PASO 79
# Acción: pickup
# Estado: Estado(x=np.int64(1), y=np.int64(1), dir=2)
# Recompensa: 0
# #########################################################
# PASO 80
# Acción: right
# Estado: Estado(x=np.int64(1), y=np.int64(1), dir=3)
# Recompensa: 0
# #########################################################
# PASO 81
# Acción: right
# Estado: Estado(x=np.int64(1), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 82
# Acción: forward
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 83
# Acción: toggle
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 84
# Acción: drop
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 85
# Acción: toggle
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 86
# Acción: toggle
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 87
# Acción: forward
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 88
# Acción: pickup
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 89
# Acción: done
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 90
# Acción: left
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=3)
# Recompensa: 0
# #########################################################
# PASO 91
# Acción: toggle
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=3)
# Recompensa: 0
# #########################################################
# PASO 92
# Acción: forward
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa: 0
# #########################################################
# PASO 93
# Acción: toggle
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa: 0
# #########################################################
# PASO 94
# Acción: pickup
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa: 0
# #########################################################
# PASO 95
# Acción: drop
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa: 0
# #########################################################
# PASO 96
# Acción: toggle
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa: 0
# #########################################################
# PASO 97
# Acción: pickup
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa: 0
# #########################################################
# PASO 98
# Acción: right
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=0)
# Recompensa: 0
# #########################################################
# PASO 99
# Acción: pickup
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=0)
# Recompensa: 0
# #########################################################
# PASO 100
# Acción: right
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=1)
# Recompensa: 0
# #########################################################
# PASO 101
# Acción: done
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=1)
# Recompensa: 0
# #########################################################
# PASO 102
# Acción: right
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=2)
# Recompensa: 0
# #########################################################
# PASO 103
# Acción: drop
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=2)
# Recompensa: 0
# #########################################################
# PASO 104
# Acción: right
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa: 0
# #########################################################
# PASO 105
# Acción: done
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa: 0
# #########################################################
# PASO 106
# Acción: done
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa: 0
# #########################################################
# PASO 107
# Acción: right
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=0)
# Recompensa: 0
# #########################################################
# PASO 108
# Acción: drop
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=0)
# Recompensa: 0
# #########################################################
# PASO 109
# Acción: pickup
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=0)
# Recompensa: 0
# #########################################################
# PASO 110
# Acción: right
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=1)
# Recompensa: 0
# #########################################################
# PASO 111
# Acción: drop
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=1)
# Recompensa: 0
# #########################################################
# PASO 112
# Acción: left
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=0)
# Recompensa: 0
# #########################################################
# PASO 113
# Acción: toggle
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=0)
# Recompensa: 0
# #########################################################
# PASO 114
# Acción: done
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=0)
# Recompensa: 0
# #########################################################
# PASO 115
# Acción: left
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa: 0
# #########################################################
# PASO 116
# Acción: done
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa: 0
# #########################################################
# PASO 117
# Acción: done
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa: 0
# #########################################################
# PASO 118
# Acción: forward
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa: 0
# #########################################################
# PASO 119
# Acción: forward
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa: 0
# #########################################################
# PASO 120
# Acción: left
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=2)
# Recompensa: 0
# #########################################################
# PASO 121
# Acción: right
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa: 0
# #########################################################
# PASO 122
# Acción: right
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=0)
# Recompensa: 0
# #########################################################
# PASO 123
# Acción: done
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=0)
# Recompensa: 0
# #########################################################
# PASO 124
# Acción: pickup
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=0)
# Recompensa: 0
# #########################################################
# PASO 125
# Acción: left
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa: 0
# #########################################################
# PASO 126
# Acción: left
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=2)
# Recompensa: 0
# #########################################################
# PASO 127
# Acción: drop
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=2)
# Recompensa: 0
# #########################################################
# PASO 128
# Acción: drop
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=2)
# Recompensa: 0
# #########################################################
# PASO 129
# Acción: forward
# Estado: Estado(x=np.int64(1), y=np.int64(0), dir=2)
# Recompensa: 0
# #########################################################
# PASO 130
# Acción: pickup
# Estado: Estado(x=np.int64(1), y=np.int64(0), dir=2)
# Recompensa: 0
# #########################################################
# PASO 131
# Acción: toggle
# Estado: Estado(x=np.int64(1), y=np.int64(0), dir=2)
# Recompensa: 0
# #########################################################
# PASO 132
# Acción: right
# Estado: Estado(x=np.int64(1), y=np.int64(0), dir=3)
# Recompensa: 0
# #########################################################
# PASO 133
# Acción: toggle
# Estado: Estado(x=np.int64(1), y=np.int64(0), dir=3)
# Recompensa: 0
# #########################################################
# PASO 134
# Acción: done
# Estado: Estado(x=np.int64(1), y=np.int64(0), dir=3)
# Recompensa: 0
# #########################################################
# PASO 135
# Acción: drop
# Estado: Estado(x=np.int64(1), y=np.int64(0), dir=3)
# Recompensa: 0
# #########################################################
# PASO 136
# Acción: drop
# Estado: Estado(x=np.int64(1), y=np.int64(0), dir=3)
# Recompensa: 0
# #########################################################
# PASO 137
# Acción: right
# Estado: Estado(x=np.int64(1), y=np.int64(0), dir=0)
# Recompensa: 0
# #########################################################
# PASO 138
# Acción: done
# Estado: Estado(x=np.int64(1), y=np.int64(0), dir=0)
# Recompensa: 0
# #########################################################
# PASO 139
# Acción: forward
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=0)
# Recompensa: 0
# #########################################################
# PASO 140
# Acción: toggle
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=0)
# Recompensa: 0
# #########################################################
# PASO 141
# Acción: right
# Estado: Estado(x=np.int64(2), y=np.int64(0), dir=1)
# Recompensa: 0
# #########################################################
# PASO 142
# Acción: forward
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=1)
# Recompensa: 0
# #########################################################
# PASO 143
# Acción: left
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 144
# Acción: forward
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 145
# Acción: done
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 146
# Acción: drop
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 147
# Acción: drop
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 148
# Acción: forward
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 149
# Acción: pickup
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 150
# Acción: drop
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 151
# Acción: drop
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 152
# Acción: forward
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 153
# Acción: forward
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 154
# Acción: toggle
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 155
# Acción: forward
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 156
# Acción: forward
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 157
# Acción: right
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=1)
# Recompensa: 0
# #########################################################
# PASO 158
# Acción: drop
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=1)
# Recompensa: 0
# #########################################################
# PASO 159
# Acción: toggle
# Estado: Estado(x=np.int64(2), y=np.int64(1), dir=1)
# Recompensa: 0
# #########################################################
# PASO 160
# Acción: forward
# Estado: Estado(x=np.int64(2), y=np.int64(2), dir=1)
# Recompensa: 0.9855985598559855
# #########################################################

# %% [markdown]
# ### Simplificación del espacio de acciones y definición de políticas
# Habrás comprobado que hay acciones que no son útiles para este problema. Vamos a simplificar la búsqueda reduciendo el espacio de acciones a tres:
#  1. left
#  2. right
#  3. forward
#
# Al hacer esto, ya no podemos generar una acción aleatoria utilizando `env.action_space.sample()`. Además, dicha función elige una acción al azar, lo cual no nos interesa. Nuestro objetivo es obtener una **política** que determine la mejor acción en cada situación, así que vamos a aprovechar el momento para definir una estructura de datos que nos permita hacer eso.
#
# La política debe indicar una probabilidad $\pi(a|s)$ de elegir la acción $a$ estando en el estado $s$ (así que $\sum_{a'}\pi(a'|s)=1$, con $s\in \mathcal{S}$ y $a\in \mathcal{A}$). Declararemos una política como un `numpy.array` que asocie a cada estado $s$ una distribución de probabilidad sobre las distintas acciones.
#
# La política aleatoria otorgará la misma probabilidad a todas las acciones para cada estado (como hay tres acciones, para cualquier par estado-acción la probabilidad será 1/3).

# %%
# Seleccionamos solo las tres acciones indicadas
ACCIONES_UTILES = [acciones.left, acciones.right, acciones.forward]


# TODO - Indica el shape de la policy
politica_aleatoria = np.zeros((3,3,4,3))
# Inicializamos todos los valores a 1/3
politica_aleatoria[:] = 1.0/3

# %% [markdown]
# Una vez hemos definido la política, podemos definir una función para sustituir a `env.action_space.sample()`. Esta función recibirá la política que debe seguir y el estado para el que seleccionar la acción. Devolverá la acción muestreada siguiendo la distribución descrita por la política para ese estado.

# %%
def muestrea_politica(estado:Estado, politica:np.ndarray) -> int:
    # Obtenemos la distribución de probabilidad
    probs = politica[estado.x, estado.y, estado.dir, :]
    # Comprobación de que la política está bien (se puede comentar cuando estemos seguros de que es así)
    np.testing.assert_almost_equal(np.sum(probs), 1.0, err_msg='La política para un estado siempre debe sumar 1')
    # Devolvemos una acción aleatoria muestreada según las probabilidades indicadas por la política
    return np.random.choice(ACCIONES_UTILES, p=probs)

# TODO - Obtén la acción muestreada de la policy_aleatoria para el estado en que el agente está en la casilla central mirando hacia abajo
accion = muestrea_politica(get_estado(env), politica_aleatoria)

print(accion)
# Out:
# 2

# %% [markdown]
# ### Simulación de episodios siguiendo una política prefijada
# Al disponer ya de una definición para políticas y de una función de muestreo sobre cualquier política, podemos adaptar nuestro bucle que simula un episodio para que lo haga siguiendo una política concreta.
#
# Definiremos una función llamada `simula_episodio` para ello. La función debe recibir la política a seguir y dos parámetros que nos indicarán, respectivamente, si se mostrarán los *renders* de los pasos del episodio y si se mostrarán mensajes de texto.
#
# La función deberá devolver una tupla con el **retorno** obtenido, es decir, la suma de las recompensas recibidas en cada paso y el **número de pasos** necesarios para completar el episodio.

# %%
def simula_episodio(politica:np.ndarray, muestra_renders:bool=False, imprime:bool=False) -> tuple[float, int]:
    env.reset()
    # TODO - Adapta el bucle que escribiste 3 celdas de código más arriba para que use la política para decidir qué acción tomar en cada paso
    completado = False
    ret = 0
    contador = 0
    while not completado:
        action = muestrea_politica(get_estado(env), politica)
        obs, reward, terminated, truncated, info = env.step(action)
        ret += reward
        contador += 1
        if imprime :
          print(f"PASO {contador}")
          print(f"Acción: {acciones(action).name}")
          print(f"Estado: {get_estado(env)}")
          print(f"Recompensa: {reward}")
          muestra_entorno(env)
          print("#########################################################")
        elif muestra_renders:
          muestra_entorno(env)
        if terminated or truncated:
            completado = True
    return (ret, contador)

retorno, num_pasos = simula_episodio(politica_aleatoria, muestra_renders=False, imprime=True)
print(f'Simulado un episodio con retorno {retorno} ({num_pasos})')
# Out:
# PASO 1
# Acción: left
# Estado: Estado(x=0, y=0, dir=3)
# Recompensa: 0
# #########################################################
# PASO 2
# Acción: left
# Estado: Estado(x=0, y=0, dir=2)
# Recompensa: 0
# #########################################################
# PASO 3
# Acción: left
# Estado: Estado(x=0, y=0, dir=1)
# Recompensa: 0
# #########################################################
# PASO 4
# Acción: forward
# Estado: Estado(x=np.int64(0), y=np.int64(1), dir=1)
# Recompensa: 0
# #########################################################
# PASO 5
# Acción: left
# Estado: Estado(x=np.int64(0), y=np.int64(1), dir=0)
# Recompensa: 0
# #########################################################
# PASO 6
# Acción: right
# Estado: Estado(x=np.int64(0), y=np.int64(1), dir=1)
# Recompensa: 0
# #########################################################
# PASO 7
# Acción: forward
# Estado: Estado(x=np.int64(0), y=np.int64(2), dir=1)
# Recompensa: 0
# #########################################################
# PASO 8
# Acción: left
# Estado: Estado(x=np.int64(0), y=np.int64(2), dir=0)
# Recompensa: 0
# #########################################################
# PASO 9
# Acción: forward
# Estado: Estado(x=np.int64(1), y=np.int64(2), dir=0)
# Recompensa: 0
# #########################################################
# PASO 10
# Acción: forward
# Estado: Estado(x=np.int64(2), y=np.int64(2), dir=0)
# Recompensa: 0.9990999099909991
# #########################################################
# Simulado un episodio con retorno 0.9990999099909991 (10)

# %% [markdown]
# ### Comprobación del rendimiento de la política
#
# Hagamos un experimento para evaluar la eficacia de la política aleatoria. Simularemos 200 episodios, anotando el número de pasos necesarios para completar cada uno. No es necesario que llevemos cuenta de los retornos obtenidos porque en este problema siempre será 1 (dado que solo la última acción da recompensa, con valor 1).
#
# Mostraremos estadísticas y gráficos que nos puedan ayudar a tener una idea de cómo de bien funciona.

# %%
def comprueba_politica(politica:np.ndarray) -> None:
    episodios_pasos = []

    # TODO - Simula 200 episodios, añadiendo sus respectivos números de pasos a episodios_pasos y mostrando por cada uno un mensaje de la forma '{iteracion} - Simulado un episodio con retorno {retorno} ({num_pasos})'
    for i in range(200):
      retorno, num_pasos = simula_episodio(politica)
      episodios_pasos.append(num_pasos)
      print(f"{i+1} - Simulado un episodio con retorno {retorno} ({num_pasos})")

    assert(len(episodios_pasos)==200)

    # Mostramos un histograma para la duración de los episodios
    plt.hist(episodios_pasos)
    plt.show()

    # Mostramos también un diagrama de caja
    plt.boxplot(episodios_pasos)
    plt.show()

    # Por último, escribimos un par de estadísticas
    print('Se han necesitado de media',np.mean(episodios_pasos),'pasos (+-',np.std(episodios_pasos),')')
    print('El episodio más corto duró',np.min(episodios_pasos),'pasos y el episodio más largo duró',np.max(episodios_pasos),'pasos')

comprueba_politica(politica_aleatoria)
# Out:
# 1 - Simulado un episodio con retorno 0.997029702970297 (33)
# 2 - Simulado un episodio con retorno 0.9977497749774977 (25)
# 3 - Simulado un episodio con retorno 0.9945094509450945 (61)
# 4 - Simulado un episodio con retorno 0.9986498649864987 (15)
# 5 - Simulado un episodio con retorno 0.9984698469846984 (17)
# 6 - Simulado un episodio con retorno 0.9955895589558956 (49)
# 7 - Simulado un episodio con retorno 0.9914491449144914 (95)
# 8 - Simulado un episodio con retorno 0.9923492349234924 (85)
# 9 - Simulado un episodio con retorno 0.9918091809180918 (91)
# 10 - Simulado un episodio con retorno 0.9886588658865887 (126)
# 11 - Simulado un episodio con retorno 0.9992799279927993 (8)
# 12 - Simulado un episodio con retorno 0.996939693969397 (34)
# 13 - Simulado un episodio con retorno 0.995049504950495 (55)
# 14 - Simulado un episodio con retorno 0.9976597659765977 (26)
# 15 - Simulado un episodio con retorno 0.991899189918992 (90)
# 16 - Simulado un episodio con retorno 0.996039603960396 (44)
# 17 - Simulado un episodio con retorno 0.9937893789378938 (69)
# 18 - Simulado un episodio con retorno 0.9958595859585958 (46)
# 19 - Simulado un episodio con retorno 0.9901890189018902 (109)
# 20 - Simulado un episodio con retorno 0.9927992799279928 (80)
# 21 - Simulado un episodio con retorno 0.9908190819081908 (102)
# 22 - Simulado un episodio con retorno 0.9954995499549955 (50)
# 23 - Simulado un episodio con retorno 0.997029702970297 (33)
# 24 - Simulado un episodio con retorno 0.9982898289828983 (19)
# 25 - Simulado un episodio con retorno 0.9799279927992799 (223)
# 26 - Simulado un episodio con retorno 0.9954995499549955 (50)
# 27 - Simulado un episodio con retorno 0.9987398739873987 (14)
# 28 - Simulado un episodio con retorno 0.9956795679567957 (48)
# 29 - Simulado un episodio con retorno 0.9852385238523852 (164)
# 30 - Simulado un episodio con retorno 0.9888388838883888 (124)
# 31 - Simulado un episodio con retorno 0.9957695769576957 (47)
# 32 - Simulado un episodio con retorno 0.998919891989199 (12)
# 33 - Simulado un episodio con retorno 0.9974797479747974 (28)
# 34 - Simulado un episodio con retorno 0.9971197119711971 (32)
# 35 - Simulado un episodio con retorno 0.9943294329432943 (63)
# 36 - Simulado un episodio con retorno 0.9840684068406841 (177)
# 37 - Simulado un episodio con retorno 0.997029702970297 (33)
# 38 - Simulado un episodio con retorno 0.9984698469846984 (17)
# 39 - Simulado un episodio con retorno 0.997929792979298 (23)
# 40 - Simulado un episodio con retorno 0.9791179117911791 (232)
# 41 - Simulado un episodio con retorno 0.9992799279927993 (8)
# 42 - Simulado un episodio con retorno 0.9928892889288929 (79)
# 43 - Simulado un episodio con retorno 0.9978397839783978 (24)
# 44 - Simulado un episodio con retorno 0.994059405940594 (66)
# 45 - Simulado un episodio con retorno 0.998019801980198 (22)
# 46 - Simulado un episodio con retorno 0.9964896489648964 (39)
# 47 - Simulado un episodio con retorno 0.9941494149414941 (65)
# 48 - Simulado un episodio con retorno 0.9972997299729973 (30)
# 49 - Simulado un episodio con retorno 0.9912691269126913 (97)
# 50 - Simulado un episodio con retorno 0.9963996399639964 (40)
# 51 - Simulado un episodio con retorno 0.998019801980198 (22)
# 52 - Simulado un episodio con retorno 0.9955895589558956 (49)
# 53 - Simulado un episodio con retorno 0.9987398739873987 (14)
# 54 - Simulado un episodio con retorno 0.9882088208820882 (131)
# 55 - Simulado un episodio con retorno 0.9972097209720973 (31)
# 56 - Simulado un episodio con retorno 0.9851485148514851 (165)
# 57 - Simulado un episodio con retorno 0.9988298829882988 (13)
# 58 - Simulado un episodio con retorno 0.993969396939694 (67)
# 59 - Simulado un episodio con retorno 0.9978397839783978 (24)
# 60 - Simulado un episodio con retorno 0.9873987398739874 (140)
# 61 - Simulado un episodio con retorno 0.9858685868586858 (157)
# 62 - Simulado un episodio con retorno 0.9920792079207921 (88)
# 63 - Simulado un episodio con retorno 0.993969396939694 (67)
# 64 - Simulado un episodio con retorno 0.9992799279927993 (8)
# 65 - Simulado un episodio con retorno 0.9954095409540954 (51)
# 66 - Simulado un episodio con retorno 0.9927992799279928 (80)
# 67 - Simulado un episodio con retorno 0.998019801980198 (22)
# 68 - Simulado un episodio con retorno 0.9884788478847885 (128)
# 69 - Simulado un episodio con retorno 0.9952295229522953 (53)
# 70 - Simulado un episodio con retorno 0.9900990099009901 (110)
# 71 - Simulado un episodio con retorno 0.9891989198919892 (120)
# 72 - Simulado un episodio con retorno 0.9935193519351935 (72)
# 73 - Simulado un episodio con retorno 0.9935193519351935 (72)
# 74 - Simulado un episodio con retorno 0.9973897389738974 (29)
# 75 - Simulado un episodio con retorno 0.9881188118811881 (132)
# 76 - Simulado un episodio con retorno 0.9953195319531953 (52)
# 77 - Simulado un episodio con retorno 0.9965796579657966 (38)
# 78 - Simulado un episodio con retorno 0.996039603960396 (44)
# 79 - Simulado un episodio con retorno 0.9905490549054905 (105)
# 80 - Simulado un episodio con retorno 0.9816381638163816 (204)
# 81 - Simulado un episodio con retorno 0.9882988298829883 (130)
# 82 - Simulado un episodio con retorno 0.9965796579657966 (38)
# 83 - Simulado un episodio con retorno 0.9976597659765977 (26)
# 84 - Simulado un episodio con retorno 0.9968496849684968 (35)
# 85 - Simulado un episodio con retorno 0.996939693969397 (34)
# 86 - Simulado un episodio con retorno 0.9789378937893789 (234)
# 87 - Simulado un episodio con retorno 0.9900990099009901 (110)
# 88 - Simulado un episodio con retorno 0.9925292529252925 (83)
# 89 - Simulado un episodio con retorno 0.9923492349234924 (85)
# 90 - Simulado un episodio con retorno 0.9974797479747974 (28)
# 91 - Simulado un episodio con retorno 0.9937893789378938 (69)
# 92 - Simulado un episodio con retorno 0.998019801980198 (22)
# 93 - Simulado un episodio con retorno 0.9982898289828983 (19)
# 94 - Simulado un episodio con retorno 0.9944194419441944 (62)
# 95 - Simulado un episodio con retorno 0.9830783078307831 (188)
# 96 - Simulado un episodio con retorno 0.9954995499549955 (50)
# 97 - Simulado un episodio con retorno 0.9743474347434743 (285)
# 98 - Simulado un episodio con retorno 0.993969396939694 (67)
# 99 - Simulado un episodio con retorno 0.9992799279927993 (8)
# 100 - Simulado un episodio con retorno 0.9954095409540954 (51)
# 101 - Simulado un episodio con retorno 0.9956795679567957 (48)
# 102 - Simulado un episodio con retorno 0.9676867686768676 (359)
# 103 - Simulado un episodio con retorno 0.9981998199819982 (20)
# 104 - Simulado un episodio con retorno 0.9985598559855986 (16)
# 105 - Simulado un episodio con retorno 0.9984698469846984 (17)
# 106 - Simulado un episodio con retorno 0.9988298829882988 (13)
# 107 - Simulado un episodio con retorno 0.9991899189918992 (9)
# 108 - Simulado un episodio con retorno 0.9945994599459946 (60)
# 109 - Simulado un episodio con retorno 0.994059405940594 (66)
# 110 - Simulado un episodio con retorno 0.9975697569756976 (27)
# 111 - Simulado un episodio con retorno 0.9983798379837984 (18)
# 112 - Simulado un episodio con retorno 0.9955895589558956 (49)
# 113 - Simulado un episodio con retorno 0.9967596759675967 (36)
# 114 - Simulado un episodio con retorno 0.9974797479747974 (28)
# 115 - Simulado un episodio con retorno 0.9914491449144914 (95)
# 116 - Simulado un episodio con retorno 0.9943294329432943 (63)
# 117 - Simulado un episodio con retorno 0.986948694869487 (145)
# 118 - Simulado un episodio con retorno 0.9973897389738974 (29)
# 119 - Simulado un episodio con retorno 0.9972997299729973 (30)
# 120 - Simulado un episodio con retorno 0.9962196219621963 (42)
# 121 - Simulado un episodio con retorno 0.9926192619261927 (82)
# 122 - Simulado un episodio con retorno 0.9993699369936994 (7)
# 123 - Simulado un episodio con retorno 0.9906390639063907 (104)
# 124 - Simulado un episodio con retorno 0.9934293429342934 (73)
# 125 - Simulado un episodio con retorno 0.9954095409540954 (51)
# 126 - Simulado un episodio con retorno 0.9981998199819982 (20)
# 127 - Simulado un episodio con retorno 0.9937893789378938 (69)
# 128 - Simulado un episodio con retorno 0.9907290729072907 (103)
# 129 - Simulado un episodio con retorno 0.9977497749774977 (25)
# 130 - Simulado un episodio con retorno 0.9986498649864987 (15)
# 131 - Simulado un episodio con retorno 0.9877587758775878 (136)
# 132 - Simulado un episodio con retorno 0.9828982898289829 (190)
# 133 - Simulado un episodio con retorno 0.9897389738973897 (114)
# 134 - Simulado un episodio con retorno 0.9955895589558956 (49)
# 135 - Simulado un episodio con retorno 0.9921692169216921 (87)
# 136 - Simulado un episodio con retorno 0.991989198919892 (89)
# 137 - Simulado un episodio con retorno 0.9976597659765977 (26)
# 138 - Simulado un episodio con retorno 0.998919891989199 (12)
# 139 - Simulado un episodio con retorno 0.9952295229522953 (53)
# 140 - Simulado un episodio con retorno 0.9938793879387939 (68)
# 141 - Simulado un episodio con retorno 0.997929792979298 (23)
# 142 - Simulado un episodio con retorno 0.9853285328532854 (163)
# 143 - Simulado un episodio con retorno 0.9973897389738974 (29)
# 144 - Simulado un episodio con retorno 0.9981098109810981 (21)
# 145 - Simulado un episodio con retorno 0.9881188118811881 (132)
# 146 - Simulado un episodio con retorno 0.9952295229522953 (53)
# 147 - Simulado un episodio con retorno 0.9883888388838884 (129)
# 148 - Simulado un episodio con retorno 0.9944194419441944 (62)
# 149 - Simulado un episodio con retorno 0.9927992799279928 (80)
# 150 - Simulado un episodio con retorno 0.994959495949595 (56)
# 151 - Simulado un episodio con retorno 0.990999099909991 (100)
# 152 - Simulado un episodio con retorno 0.9908190819081908 (102)
# 153 - Simulado un episodio con retorno 0.9975697569756976 (27)
# 154 - Simulado un episodio con retorno 0.9954095409540954 (51)
# 155 - Simulado un episodio con retorno 0.994059405940594 (66)
# 156 - Simulado un episodio con retorno 0.9904590459045904 (106)
# 157 - Simulado un episodio con retorno 0.9936993699369937 (70)
# 158 - Simulado un episodio con retorno 0.9956795679567957 (48)
# 159 - Simulado un episodio con retorno 0.9866786678667867 (148)
# 160 - Simulado un episodio con retorno 0.9982898289828983 (19)
# 161 - Simulado un episodio con retorno 0.9877587758775878 (136)
# 162 - Simulado un episodio con retorno 0.995949594959496 (45)
# 163 - Simulado un episodio con retorno 0.9954095409540954 (51)
# 164 - Simulado un episodio con retorno 0.9921692169216921 (87)
# 165 - Simulado un episodio con retorno 0.9928892889288929 (79)
# 166 - Simulado un episodio con retorno 0.9985598559855986 (16)
# 167 - Simulado un episodio con retorno 0.9943294329432943 (63)
# 168 - Simulado un episodio con retorno 0.9977497749774977 (25)
# 169 - Simulado un episodio con retorno 0.9747074707470748 (281)
# 170 - Simulado un episodio con retorno 0.9956795679567957 (48)
# 171 - Simulado un episodio con retorno 0.9943294329432943 (63)
# 172 - Simulado un episodio con retorno 0.9914491449144914 (95)
# 173 - Simulado un episodio con retorno 0.9943294329432943 (63)
# 174 - Simulado un episodio con retorno 0.999009900990099 (11)
# 175 - Simulado un episodio con retorno 0.9810981098109811 (210)
# 176 - Simulado un episodio con retorno 0.9924392439243924 (84)
# 177 - Simulado un episodio con retorno 0.9955895589558956 (49)
# 178 - Simulado un episodio con retorno 0.9915391539153915 (94)
# 179 - Simulado un episodio con retorno 0.9961296129612961 (43)
# 180 - Simulado un episodio con retorno 0.993969396939694 (67)
# 181 - Simulado un episodio con retorno 0.9983798379837984 (18)
# 182 - Simulado un episodio con retorno 0.998019801980198 (22)
# 183 - Simulado un episodio con retorno 0.982988298829883 (189)
# 184 - Simulado un episodio con retorno 0.9877587758775878 (136)
# 185 - Simulado un episodio con retorno 0.997929792979298 (23)
# 186 - Simulado un episodio con retorno 0.9972997299729973 (30)
# 187 - Simulado un episodio con retorno 0.9963096309630963 (41)
# 188 - Simulado un episodio con retorno 0.9976597659765977 (26)
# 189 - Simulado un episodio con retorno 0.995949594959496 (45)
# 190 - Simulado un episodio con retorno 0.9984698469846984 (17)
# 191 - Simulado un episodio con retorno 0.9975697569756976 (27)
# 192 - Simulado un episodio con retorno 0.9963096309630963 (41)
# 193 - Simulado un episodio con retorno 0.9978397839783978 (24)
# 194 - Simulado un episodio con retorno 0.9821782178217822 (198)
# 195 - Simulado un episodio con retorno 0.9955895589558956 (49)
# 196 - Simulado un episodio con retorno 0.9806480648064807 (215)
# 197 - Simulado un episodio con retorno 0.9912691269126913 (97)
# 198 - Simulado un episodio con retorno 0.9982898289828983 (19)
# 199 - Simulado un episodio con retorno 0.9856885688568857 (159)
# 200 - Simulado un episodio con retorno 0.9991899189918992 (9)
# Se han necesitado de media 70.27 pasos (+- 58.79725418758941 )
# El episodio más corto duró 7 pasos y el episodio más largo duró 359 pasos

# %% [markdown]
# # Obtención de políticas óptimas
# ## Métodos de programación dinámica
#
# A la hora de encontrar una política óptima que guíe las acciones de nuestro agente, los métodos basados en programación dinámica son una buena opción cuando disponemos de conocimento respecto a las dinámicas del entorno.
#
# En particular, estos métodos requieren conocer $p(s',r | s,a)$, es decir, la probabilidad de acabar en un estado $s'$ recibiendo una recompensa $r$ si aplicamos la acción $a$ al estado $s$.
#
# OpenGym no nos proporciona esta información, pero en este problema sencillo podemos reconstruirla. Este entorno es determinista, lo que quiere decir que si aplicamos la acción $a$ al estado $s$ siempre obtendremos el mismo estado $s'$ y la misma recompensa $r$ con probabilidad 1 (cualquier otro estado $s_j$ o recompensa $r_j$ tendrán $p(s_j,r_j|s,a)=0$).
#
# Podemos, por tanto, representar el modelo con dos variables:
#  - `modelo_transiciones`: Para cada combinación $s,a$, almacena el estado $s'$ al que conduce aplicar la acción $a$ a $s$.
#  - `modelo_recompensas`: Para cada combinación $s,a$, almacena el valor de la recompensa obtenida al aplicar la acción $a$ a $s$.
#
# Sabiendo cómo se comporta el entorno, definimos estas dos variables con los valores adecuados.

# %%
# DEFINICIÓN DEL MODELO

# Modelo de transiciones - Almacena a qué estado lleva aplicar cada acción a cada estado
# Lo almacenamos en un array numpy en el que para cada estado almacenemos, para cada acción, el estado al que lleva.
modelo_transiciones = np.zeros((3,3,4,3,3),dtype=np.int16)
# Recorremos cada estado para completar el estado al que lleva cada una de las tres acciones posibles
for i in range(3): # Columnas (x)
    for j in range(3): # Filas (y)
        for k in range(4): # Orientaciones (dir)
            # Aplicar la acción left gira el agente a la izquierda, así que el estado resultante tendrá el mismo valor para filas y columnas pero variará la orientación
            modelo_transiciones[i,j,k,0]=[i,j,(k+4-1)%4]
            # Aplicar la acción right gira el agente a la derecha, así que el estado resultante tendrá el mismo valor para filas y columnas pero variará la orientación
            modelo_transiciones[i,j,k,1]=[i,j,(k+1)%4]
        # Aplicar la acción forward mantiene la orientación, pero cambia filas o columnas en función de hacia dónde esté orientado
        if i<2:
            modelo_transiciones[i,j,0,2]=[i+1,j,0] # Derecha
        if j<2:
            modelo_transiciones[i,j,1,2]=[i,j+1,1] # Abajo
        if i>0:
            modelo_transiciones[i,j,2,2]=[i-1,j,2] # Izquierda
        if j>0:
            modelo_transiciones[i,j,3,2]=[i,j-1,3] # Arriba

# Modelo de transiciones - Almacena qué recompensa proporciona aplicar cada acción a cada estado
# Lo almacenamos en un array numpy en el que para cada estado almacenemos, para cada acción, la recompensa.
modelo_recompensas = np.zeros((3,3,4,3))
# Será 0 siempre menos en dos casos:
# 1 - Está en la segunda columna de la tercera fila, orientado a la derecha y se usa la acción forward
modelo_recompensas[1,2,0,2] = 1
# 2 - Está en la tercera columna de la segunda fila, orientado hacia abajo y se usa la acción forward
modelo_recompensas[2,1,1,2] = 1

# Función auxiliar para consultar los estados a los que lleva cada acción para un estado dado
def get_resultados_por_accion_en(estado: Estado) -> list[Estado]:
    valores_estados_para_cada_accion = modelo_transiciones[estado.x, estado.y, estado.dir]
    return list(map(lambda x: Estado(*x), valores_estados_para_cada_accion))

# Función auxiliar para consultar las recompensas de aplicar cada acción en un estado dado
def get_recompensas_por_accion_en(estado: Estado,accion) -> np.ndarray:

    return modelo_recompensas[estado.x, estado.y, estado.dir, accion]

# TODO - Muestra los estados resultantes y las recompensas de aplicar las distintas acciones cuando el agente está en la tercera casilla de la segunda fila, orientado hacia abajo y se ejecuta la acción forward
estado = Estado(2,1,1)

estados = get_resultados_por_accion_en(estado)

for accion,i in enumerate(ACCIONES_UTILES):
  print(f"Estado inicial: {estado}  Movimiento:{accion}    Estado final: {estados[i]} - Recompensa: {get_recompensas_por_accion_en(estado,i)}")
# Out:
# Estado inicial: Estado(x=2, y=1, dir=1)  Movimiento:0    Estado final: Estado(x=np.int16(2), y=np.int16(1), dir=np.int16(0)) - Recompensa: 0.0
# Estado inicial: Estado(x=2, y=1, dir=1)  Movimiento:1    Estado final: Estado(x=np.int16(2), y=np.int16(1), dir=np.int16(2)) - Recompensa: 0.0
# Estado inicial: Estado(x=2, y=1, dir=1)  Movimiento:2    Estado final: Estado(x=np.int16(2), y=np.int16(2), dir=np.int16(1)) - Recompensa: 1.0

# %% [markdown]
# ## Algoritmo 1: Evaluación de políticas iterativa
# El algoritmo de evaluación de políticas iterativa calcula el valor $v_\pi(s)$ para todo estado $s$ siguiendo la política $\pi$. La fórmula que utiliza, que está basada en la ecuación de Bellman para $v_\pi(s)$, es esta:
#
# $$v_\pi(s)=\mathbb{E}_\pi [R_{t+1}+\gamma v_k(S_{t+1}) | S_t=s]$$
#
# $$=\sum_a\pi(a|s)\sum_{s',r}p(s',r|s,a)[r+\gamma v_k(s')]$$
#
# Al ser este un problema determinista, la expresión se simplifica, dado que $p(s',r|s,a)$ será 0 en todos los casos menos en 1 (porque aplicar la acción $a$ al estado $s$ conduce siempre a un estado $s'$ fijo y único y otorga siempre una recompensa $r$ fija y única; ambos valores los podemos obtener del modelo).
#
# Puedes ver el algoritmo al completo aquí:
#
# ![Evaluación de políticas iterativa](https://github.com/eirasf/GCED-AA3/blob/main/lab4/img/iterative-policy-evaluation.png?raw=true)
#
# Implementemos el algoritmo para obtener los valores asignados a cada estado siguiendo una política fija.
#
# **CONSEJO: Para asegurar la convergencia, actualiza todos los valores de $V_{t+1}(s)$ a partir de los valores $V_t(s)$, es decir, crea una variable `nuevos_valores_estados` donde almacenes todos los calculados en una iteración y al completar la iteración establece `valores_estados = nuevos_valores_estados`**

# %%
GAMMA = 0.1

def iterative_policy_evaluation(politica: np.ndarray) ->np.ndarray:
    THETA = 0.00001

    # En esta variable almacenaremos los valores calculados para los estados
    # TODO - Indica el shape adecuado. Debes almacenar un valor por cada estado posible
    valores_estados = np.zeros((3, 3, 4))

    # TODO - Completa el algoritmo según lo descrito arriba
    while True:
        delta = 0
        nuevos_valores_estados = np.zeros_like(valores_estados)

        for x in range(3):
            for y in range(3):
                for dir in range(4):
                    estado = Estado(x, y, dir)
                    v = valores_estados[x, y, dir]
                    nuevo_valor = 0

                    # Recorremos las 3 acciones útiles
                    for idx_accion, accion in enumerate(ACCIONES_UTILES):
                        prob_accion = politica[x, y, dir, idx_accion]
                        siguiente_estado = modelo_transiciones[x, y, dir, idx_accion]
                        recompensa = modelo_recompensas[x, y, dir, idx_accion]
                        valor_siguiente = valores_estados[tuple(siguiente_estado)]

                        nuevo_valor += prob_accion * (recompensa + GAMMA * valor_siguiente)

                    nuevos_valores_estados[x, y, dir] = nuevo_valor
                    delta = max(delta, abs(v - nuevo_valor))

        valores_estados = nuevos_valores_estados

        if delta < THETA:
            break

    return valores_estados

valores_estados = iterative_policy_evaluation(politica_aleatoria)
print(valores_estados)

# COMPROBACIÓN
np.testing.assert_almost_equal(valores_estados[0,0,1], 4.11522634e-07)
# Out:
# [[[4.11522634e-07 4.11522634e-07 0.00000000e+00 0.00000000e+00]
#   [1.31687243e-05 1.27572016e-05 4.11522634e-07 4.11522634e-07]
#   [1.11604938e-02 3.72839506e-04 2.46913580e-05 3.72839506e-04]]
#
#  [[1.27572016e-05 1.31687243e-05 4.11522634e-07 4.11522634e-07]
#   [3.85185185e-04 3.85185185e-04 1.31687243e-05 1.31687243e-05]
#   [3.34077366e-01 1.11604938e-02 7.44855967e-04 1.11609053e-02]]
#
#  [[3.72839506e-04 1.11604938e-02 3.72839506e-04 2.46913580e-05]
#   [1.11604938e-02 3.34077366e-01 1.11609053e-02 7.44855967e-04]
#   [8.23045267e-07 8.23045267e-07 2.55144033e-05 2.55144033e-05]]]

# %% [markdown]
# ### Optimización de políticas
#
# En el apartado anterior hemos obtenido un valor para cada estado del problema cuando se sigue la política $\pi$;  podemos utilizar estos valores para encontrar una nueva política $\pi'$ que sea igual o mejor que $\pi$.
#
# Cuando disponemos de $v_\pi(s)$ y del modelo que describe el funcionamiento del entorno, podemos obtener una política $\pi'\geq\pi$ simplemente seleccionando, para cada estado, la acción que nos da un mayor retorno, que podemos calcular como la recompensa inmediata más el valor del estado al que llegamos (descontado por $\gamma$).
#
# $$\pi'(s)=\arg\max_a\sum_{s',r}p(s',r|s,a)\left[r+\gamma v_\pi(s')\right]$$
#
# Escribamos un algoritmo que obtenga $\pi'$ a partir de `state_values`.

# %%
def crea_politica_avara(valores_estados: np.ndarray) -> np.ndarray:
    nueva_shape = list(valores_estados.shape)
    nueva_shape.append(3)
    # TODO - Indica la shape apropiada. Por cada par estado-acción debemos almacenar la probabilidad que da esta política de tomar esa acción estando en dicho estado
    # Como la política es determinista, para un estado concreto todas las acciones tendrán probabilidad 0 menos una que tendrá probabilidad 1

    politica = np.zeros(tuple(nueva_shape))
    # TODO - Haz bucles anidados para recorrer todos los estados

                # Ahora para este estado debemos calcular, para todas las acciones a, G=(r + GAMMA*state_values[s[0],s[1],s[2]]) donde r es la recompensa de aplicar a y s es el estado resultante.
                # De todos esos valores, tomaremos el mejor (supongamos que es el i-ésimo) y pondremos probabilidad 1 en la acción i-ésima para dicho estado.
                # TODO - Recorre las acciones, calculando su G. Selecciona el mejor y pon a 1 la probabilidad de la acción correspondiente.

    for x in range(3):
        for y in range(3):
            for dir in range(4):
                mejor_G = -np.inf
                mejor_accion = 0

                # Recorremos las acciones, calculando su G
                for i in range(3):
                    s_prim = modelo_transiciones[x, y, dir, i]
                    r = modelo_recompensas[x, y, dir, i]
                    G = r + GAMMA * valores_estados[tuple(s_prim)]

                    if G > mejor_G:
                        mejor_G = G
                        mejor_accion = i

                # Ponemos probabilidad 1 en la acción que maximizó G
                politica[x, y, dir, mejor_accion] = 1.0

    return politica

politica_mejorada = crea_politica_avara(valores_estados)

# COMPROBACIÓN
assert(np.array_equal(politica_mejorada[2,1,1],[0., 0., 1.]))

# %% [markdown]
# ## Obtención de la política óptima - Policy iteration
# Ahora que podemos evaluar una política y, a partir de esos valores, obtener una política mejorada, podemos repetir el proceso para seguir mejorando nuestra política hasta que no cambie. Este procedimiento se denomina *policy iteration* y lo tienes aquí descrito:
#
# ![Policy iteration](https://github.com/eirasf/GCED-AA3/blob/main/lab4/img/policy-iteration.png?raw=true)
#
# Implementémoslo (la mayoría ya lo tenemos hecho).

# %%
def policy_iteration(politica_inicial: np.ndarray) -> np.ndarray:
    politica_actual = politica_inicial
    politica_estable = False
    # Llevaremos cuenta del paso en que estamos
    paso = 0
    while not politica_estable:
        # TODO - Calcula los valores para current_policy
        valores_actuales = ...
        # TODO - Obtén la nueva política mejorada a partir de los valores calculados
        nueva_politica = ...
        # Comprobamos si la política ha cambiado
        politica_estable = np.array_equal(politica_actual, nueva_politica)
        # Preparamos la siguiente iteración
        politica_actual = nueva_politica
        paso+=1
        print('Paso #',paso)
    # Al terminar el bucle habremos obtenido una política que ya no mejora
    return politica_actual

politica_optima = policy_iteration(politica_aleatoria)
print(politica_optima)

# COMPROBACIÓN
assert(np.array_equal(politica_optima[2,0,1], [0., 0., 1.]))
# Out:
# Paso # 1
# Paso # 2
# Ellipsis
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-009f25a65c66> in <cell line: 0>()
#      22
#      23 # COMPROBACIÓN
# ---> 24 assert(np.array_equal(politica_optima[2,0,1], [0., 0., 1.]))
#
# TypeError: 'ellipsis' object is not subscriptable

# %% [markdown]
# Comprobemos que la política obtenida funciona bien simulando un episodio siguiéndola.

# %%
simula_episodio(politica_optima, muestra_renders=True, imprime=True)

# %% [markdown]
# ## Obtención de la política óptima - Iteración de valores
# El proceso de iteración de políticas es costoso porque requiere hacer una estimación iterativa de $v_\pi(s)$ para todas las políticas por las que se pasa. Este proceso se puede simplificar y obtener una política óptima siguiendo el algoritmo de iteración de valores:
#
# ![Value iteration](https://github.com/eirasf/GCED-AA3/blob/main/lab4/img/value-iteration.png?raw=true)
#
# El algoritmo es muy similar al de evaluación de políticas iterativas. La diferencia es que, en lugar de calcular $\mathbb{E}_\pi [R_{t+1}+\gamma v_k(S_{t+1}) | S_t=s]$, se toma el valor de la mejor acción. Al final, se devuelve la política greedy derivada de los valores calculados. Implementémoslo.

# %%
def value_iteration() -> np.ndarray: # No recibe ningún parámetro. Calcula valores y política a partir del modelo del entorno.
    # TODO - Repite el algoritmo de evaluación de políticas iterativa pero tomando el G de la mejor acción para cada estado
    # Una vez tengas los state_values, devuelve la política derivada de ellos
    ...

otra_optima = value_iteration()
print(otra_optima)

# COMPROBACIÓN
assert(np.array_equal(otra_optima[2,0,1], [0., 0., 1.]))

# %% [markdown]
# Para terminar, comprobemos que la política obtenida así también funciona bien.

# %%
simula_episodio(otra_optima, muestra_renders=True, imprime=True)
env.close() # Cerramos, además, el entorno
