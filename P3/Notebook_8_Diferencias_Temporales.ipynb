# %% [markdown]
# # Notebook 8: Aprendizaje por refuerzo - Métodos de Temporal Difference
#
# En este notebook seguiremos explorando métodos tabulares de aprendizaje por refuerzo que no necesitan disponer de un modelo. En particular, estudiaremos los métodos de **Temporal Difference**.
#
# Para explorar estos métodos volveremos a utilizar [Gym](https://www.gymlibrary.dev/) con un entorno GridWorld, es decir, un tablero con casillas por las que se mueve el agente, tal como hicimos en el Lab4. En particular, vamos a utilizar el entorno `MiniGrid-DistShift1-v0`. En este entorno el agente deberá llegar hasta la meta, pero esta vez evitando caer en la lava, que hace que se termine el episodio con recompensa 0.
#
# Carguemos el entorno y explorémoslo brevemente.

# %%
# !pip install gymnasium[classic-control]
# !pip install minigrid
# Out:
# Requirement already satisfied: gymnasium[classic-control] in /usr/local/lib/python3.11/dist-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[classic-control]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[classic-control]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[classic-control]) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[classic-control]) (0.0.4)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.11/dist-packages (from gymnasium[classic-control]) (2.6.1)
# Collecting minigrid
#   Downloading minigrid-3.0.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from minigrid) (2.0.2)
# Requirement already satisfied: gymnasium>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from minigrid) (1.1.1)
# Requirement already satisfied: pygame>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from minigrid) (2.6.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=0.28.1->minigrid) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=0.28.1->minigrid) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=0.28.1->minigrid) (0.0.4)
# Downloading minigrid-3.0.0-py3-none-any.whl (136 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.7/136.7 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: minigrid
# Successfully installed minigrid-3.0.0

# %%
# Si los paquetes no están instalados, hay que ejecutar estas líneas:

import gymnasium as gym
import minigrid
import numpy as np
env = gym.make('MiniGrid-DistShift1-v0', render_mode='rgb_array')

import matplotlib.pyplot as plt

# TODO - Muestra el entorno para ver cómo es el tablero. Para ello, recupera la función muestra_entorno del lab4 y lánzala
def muestra_entorno(env:gym.Env) -> None:

    plt.imshow(env.render())
    plt.show()
env.reset()
muestra_entorno(env)

# %%
# TODO - Anotar las dimensiones del tablero para poder utilizarlas después
NUM_COLUMNAS = 7
NUM_FILAS = 5
NUM_ORIENTACIONES = 4

# Las acciones son las mismas que en el Notebook 6. Nos quedaremos de nuevo solo con LEFT, RIGHT y FORWARD
acciones = env.get_wrapper_attr('actions')
# Seleccionamos solo las tres acciones indicadas
ACCIONES_UTILES = [acciones.left, acciones.right, acciones.forward]
NUM_ACCIONES = len(ACCIONES_UTILES)

# %% [markdown]
# Comprueba el efecto de caer en la lava. El episodio debería terminarse y recibiendo el agente una recompensa de 0.

# %%
#TODO - Efectúa dos acciones para que el agente caiga en la lava y verifica que se recibe una recompensa de 0
obs, reward, terminated, truncated, info = env.step(acciones.forward)
obs, reward, terminated, truncated, info = env.step(acciones.forward)
muestra_entorno(env)
print(f"Recompensa: {reward}")
#COMPROBACIONES
assert(reward==0)
assert(terminated)
_ = env.reset()
# Out:
# Recompensa: 0

# %% [markdown]
# # Obtención de políticas óptimas
#
# ## Métodos de Temporal Difference
#
# Los métodos basados en **Temporal Difference**, al igual que los métodos Montecarlo, carecen de información respecto a cómo funciona el modelo (no conocen $p(s',r | s,a)$). Por ello, también deben interactuar con el entorno para obtener muestras con las que después hacer estimaciones.
#
# A diferencia de los métodos Montecarlo, los métodos de Temporal Difference no esperan a terminar un episodio para actualizar los valores de los estados transitados. En su lugar, los métodos Temporal Difference aprovechan la idea de que el valor $v(S)$ de un estado $S$ tiene relación con el valor de los estados $S'$ a los que se puede llegar desde $S$. Dicho de otra manera, los estados que pueden conducir a un estado malo serán también malos (y viceversa). Esta idea está codificada en las **ecuaciones de Bellman**:
#
# $$v_\pi(s)=\sum_{a}\pi(a|s)\sum_{s',r} p(s',r | s,a)\left[r + \gamma v_\pi(s')\right]$$
#
# La misma idea se puede aplicar a la hora de estimar el valor de ejecutar la acción $a$ estando en el estado $s$. Las acciones $a$ que lleven a estados $s'$ cuyas acciones tengan valores altos tendrán, a su vez, valores altos (y viceversa).
#
# $$q_\pi(s,a)=\sum_{s',r} p(s',r | s,a)\left[r + \gamma \sum_{a'}\pi(a'|s')q_\pi(s',a')\right]$$
#
# Aplicar esta idea nos permitirá hacer *bootstrapping* en nuestros cálculos: a la hora de calcular el valor de un estado podremos aprovechar la aproximación que tenemos para estados adyacentes.
#
# ### SARSA
# El primer método que probaremos es SARSA. Este algoritmo se denomina así por las variables involucradas en cada paso de actualización de la estimación de $Q(S,A)$. Las variables son $S_t,A_t,R_{t+1},S_{t+1},A_{t+1}$ y la actualización utiliza esta fórmula:
#
# $$Q(S_t,A_t) \leftarrow Q(S_t,A_t) + \alpha [R_{t+1} + \gamma Q(S_{t+1},A_{t+1}) - Q(S_t,A_t)]$$
#
# El algoritmo ejecutará repetidos episodios (potencialmente infinitos; es un algoritmo de control y el agente podría seguirlo utilizando durante toda su existencia) y, para cada paso del episodio hará la actualización según la fórmula indicada arriba. Esto requiere que haya decidido la siguiente acción a tomar ($A_{t+1}$) antes de actualizar el valor de la acción anterior ($A_t$).
#
# ![Sarsa](https://github.com/eirasf/GCED-AA3/blob/main/lab6/img/sarsa.png?raw=true)
#
# Para facilitar la implementación, vamos primero a escribir un par de funciones auxiliares que nos permitan representar estados y muestrear acciones a partir de $Q$.

# %%
from collections import namedtuple

GAMMA = 0.9 # Para este problema vamos a utilizar un factor de descuento de 0.9, es decir, las recompensas futuras se descontarán un 10% por cada paso que sea necesario para obtenerlas.

env.max_steps = 5000 # Fijamos el número máximo de acciones por episodio a 5000, para permitir episodios largos

# FUNCIONES AUXILIARES
#TODO - Recupera la función get_estado del Notebook 6. Esta función codifica el estado del entorno en una lista de tres elementos: columna, fila, orientación
Estado = namedtuple('Estado', ['x', 'y', 'dir'])

def get_estado(env:gym.Env) -> Estado:
    # TODO - Completa la función
    x = env.get_wrapper_attr('agent_pos')[0] - 1
    y = env.get_wrapper_attr('agent_pos')[1] - 1
    dir = env.get_wrapper_attr('agent_dir')
    return Estado(x, y, dir)

# COMPROBACIÓN
env.reset()
estado_actual = get_estado(env)
assert estado_actual.x == 0, f'El estado inmediatamente después de resetear debe indicar x=0 y el tuyo indica {estado_actual.x}'
assert estado_actual.y == 0, f'El estado inmediatamente después de resetear debe indicar y=0 y el tuyo indica {estado_actual.y}'
assert estado_actual.dir == 0, f'El estado inmediatamente después de resetear debe indicar dir=0 y el tuyo indica {estado_actual.dir}'

# TODO - Escribe una función que dados los valores q de las distintas acciones en un estado concreto, devuelva una acción haciendo una selección epsilon-greedy a partir de los q_valores.
def get_accion_epsilon_greedy(q_valores:np.ndarray, epsilon:float):
    '''
    Selecciona una acción basándose en los q_values proporcionados. Una fracción de las veces (indicada por epsilon) devolverá una acción al azar

    Argumentos:
    q_values -- Lista con los q valores de las acciones entre las que seleccionar.
    epsilon -- Fracción de las veces que se devolverá una acción al azar
    '''
    if np.random.random()<epsilon:
        # TODO - Devuelve una acción al azar
        accion = np.random.randint(0,NUM_ACCIONES)
        return  ACCIONES_UTILES[accion]
    # TODO - Devuelve el índice del mayor q valor
    accion = np.argmax(q_valores)
    return ACCIONES_UTILES[accion]


# COMPROBACIÓN
assert(get_accion_epsilon_greedy([1,2,4],0)==2)

# %% [markdown]
# Para algoritmos derivados de SARSA haremos _exploring starts_, es decir, comienzarán cada vez en un estado al azar. Esto facilita la exploración y, por tanto, el entrenamiento ya que facilita que se den episodios que el agente sea capaz de resolver incluso con una política aleatoria.
#
# Deberemos crear funciones que nos permitan llevar esto a cabo.

# %%
# TODO - Escribe una función que genere la codificación para un estado válido al azar. Devolverá una lista con tres valores que indiquen columna, fila y orientación
def get_estado_aleatorio() -> Estado:
    x = np.random.randint(0,NUM_FILAS)
    y = np.random.randint(0,NUM_COLUMNAS)
    dir = np.random.randint(0,NUM_ORIENTACIONES)
    return Estado(x, y, dir)

# TODO - Escribe una función que establezca el entorno para que coincida con lo indicado por un estado dado
def set_estado(env:gym.Env, estado: Estado):
    env.reset()
    env.step(acciones.right)
    for _ in range(estado.x):
        env.step(acciones.forward)
    env.step(acciones.left)
    for _ in range(estado.y):
        env.step(acciones.forward)
    for _ in range(estado.dir):
        env.step(acciones.right)



# COMPROBACIÓN
env.reset()
muestra_entorno(env) # Debe mostrar al agente en la casilla 0,0
set_estado(env, Estado(x=2, y=3, dir=0))
muestra_entorno(env) # Debe mostrar al agente en la casilla 2,3

# %% [markdown]
# Ya tenemos lo necesario para implementar SARSA. Vamos a establecer un número fijo de iteraciones y hacer que devuelva los valores $Q$ al terminar. Además, incluiremos mensajes al terminar cada episodio que indiquen:
#  - El número de episodio que se ha finalizado
#  - La recompensa obtenida
#  - El número de acciones necesarias para completar el episodio
#  - La recompensa media obtenida durante los últimos 100 episodios (si se han ejecutado al menos 100)

# %%
def sarsa(num_episodios:int = 500, ALPHA:float = 0.1, EPSILON:float = 0.25) -> np.ndarray:
    # TODO - Inicializa los valores Q a cero con el shape adecuado
    q_valores = np.zeros((NUM_FILAS, NUM_COLUMNAS, NUM_ORIENTACIONES, NUM_ACCIONES))

    # En ultimos100retornos almacenaremos los retornos de los últimos 100 episodios
    ultimos100retornos = []
    # TODO - Haz tantos episodios como indica num_episodes
    for i in range(num_episodios):
        # TODO - Devuelve el entorno a su estado inicial
        env.reset()
        # TODO - Initialize S
        estado = get_estado_aleatorio()
        set_estado(env, estado)
        # TODO - Choose A from S using policy derived from Q (e.g. epsilon-greedy)
        accion = get_accion_epsilon_greedy(q_valores[estado.x, estado.y, estado.dir], EPSILON)

        retorno = 0
        num_pasos = 0
        # TODO - Loop for each step of episode (repite hasta que el episodio termine)
        while True:
            num_pasos += 1
            # TODO - Take action A, observe R, S'
            obs, reward, terminated, truncated, info = env.step(accion)
            # TODO - Acumula la recompensa R a returns para poder imprimir el retorno del episodio
            retorno += reward
            # TODO - Choose A' from S' using policy derived from Q (e.g. epsilon-greedy)
            estado_siguiente = get_estado(env)
            #Verificar que los valores esten dentro de los rangos permitidos
            estado_siguiente = Estado(
                x=min(max(estado_siguiente.x, 0), NUM_FILAS - 1),
                y=min(max(estado_siguiente.y, 0), NUM_COLUMNAS - 1),
                dir=min(max(estado_siguiente.dir, 0), NUM_ORIENTACIONES - 1)
            )

            accion_siguiente = get_accion_epsilon_greedy(q_valores[estado_siguiente.x, estado_siguiente.y, estado_siguiente.dir], EPSILON)
            # TODO - Q(S,A) <- Q(S,A) + ALPHA * [R + GAMMA * Q(S',A') - Q(S,A)]
            q_valores[estado.x, estado.y, estado.dir, accion] += ALPHA * (reward + GAMMA * q_valores[estado_siguiente.x, estado_siguiente.y, estado_siguiente.dir, accion_siguiente])
            # TODO - S <- S'; A <- A'
            estado = estado_siguiente
            accion = accion_siguiente
            # TODO - Si el episodio ha terminado, sale del bucle
            if terminated or truncated:
                break
            if terminated and reward == 0:
              reward = -1


        # Tras terminar el episodio almacenamos el retorno en los 100 últimos...
        ultimos100retornos.append(retorno)
        string_retornos100 = ''
        if len(ultimos100retornos)==101: # ... y si hay ya más de 100...
            ultimos100retornos.pop(0) # ...quitamos el más antiguo (para tener siempre 100, no más)...
            #... y preparamos el mensaje para mostrar la media de los retornos
            string_retornos100=f'(retorno medio de {np.mean(ultimos100retornos)} en los últimos 100 episodios)'
        # Mostramos el mensaje tras cada episodio
        print(f'Terminado episodio {i} con retorno {retorno} en {num_pasos} pasos {string_retornos100}')
    return q_valores

# %%
# Entrenamos al agente usando los parámetros por defecto de la función que acabamos de definir
q_valores_sarsa = sarsa()
# Out:
# Terminado episodio 0 con retorno 0.9285714285714286 en 11 pasos
# Terminado episodio 1 con retorno 0 en 79 pasos
# Terminado episodio 2 con retorno 0 en 15 pasos
# Terminado episodio 3 con retorno 0 en 248 pasos
# Terminado episodio 4 con retorno 0.9035714285714286 en 19 pasos
# Terminado episodio 5 con retorno 0 en 241 pasos
# Terminado episodio 6 con retorno 0 en 239 pasos
# Terminado episodio 7 con retorno 0 en 5 pasos
# Terminado episodio 8 con retorno 0 en 4 pasos
# Terminado episodio 9 con retorno 0 en 15 pasos
# Terminado episodio 10 con retorno 0.40714285714285714 en 156 pasos
# Terminado episodio 11 con retorno 0 en 9 pasos
# Terminado episodio 12 con retorno 0.9214285714285715 en 11 pasos
# Terminado episodio 13 con retorno 0 en 9 pasos
# Terminado episodio 14 con retorno 0 en 81 pasos
# Terminado episodio 15 con retorno 0.825 en 39 pasos
# Terminado episodio 16 con retorno 0.7892857142857143 en 48 pasos
# Terminado episodio 17 con retorno 0 en 194 pasos
# Terminado episodio 18 con retorno 0.9321428571428572 en 5 pasos
# Terminado episodio 19 con retorno 0.9535714285714285 en 7 pasos
# Terminado episodio 20 con retorno 0 en 245 pasos
# Terminado episodio 21 con retorno 0 en 6 pasos
# Terminado episodio 22 con retorno 0 en 175 pasos
# Terminado episodio 23 con retorno 0 en 75 pasos
# Terminado episodio 24 con retorno 0.95 en 4 pasos
# Terminado episodio 25 con retorno 0 en 31 pasos
# Terminado episodio 26 con retorno 0 en 246 pasos
# Terminado episodio 27 con retorno 0 en 244 pasos
# Terminado episodio 28 con retorno 0 en 29 pasos
# Terminado episodio 29 con retorno 0 en 177 pasos
# Terminado episodio 30 con retorno 0 en 9 pasos
# Terminado episodio 31 con retorno 0 en 4 pasos
# Terminado episodio 32 con retorno 0.825 en 40 pasos
# Terminado episodio 33 con retorno 0 en 247 pasos
# Terminado episodio 34 con retorno 0.9142857142857143 en 12 pasos
# Terminado episodio 35 con retorno 0 en 242 pasos
# Terminado episodio 36 con retorno 0.9178571428571428 en 13 pasos
# Terminado episodio 37 con retorno 0 en 3 pasos
# Terminado episodio 38 con retorno 0 en 245 pasos
# Terminado episodio 39 con retorno 0 en 7 pasos
# Terminado episodio 40 con retorno 0.4928571428571429 en 134 pasos
# Terminado episodio 41 con retorno 0 en 242 pasos
# Terminado episodio 42 con retorno 0 en 120 pasos
# Terminado episodio 43 con retorno 0 en 15 pasos
# Terminado episodio 44 con retorno 0.9214285714285715 en 9 pasos
# Terminado episodio 45 con retorno 0 en 45 pasos
# Terminado episodio 46 con retorno 0.9571428571428572 en 4 pasos
# Terminado episodio 47 con retorno 0 en 149 pasos
# Terminado episodio 48 con retorno 0 en 25 pasos
# Terminado episodio 49 con retorno 0 en 8 pasos
# Terminado episodio 50 con retorno 0 en 3 pasos
# Terminado episodio 51 con retorno 0.9357142857142857 en 7 pasos
# Terminado episodio 52 con retorno 0 en 10 pasos
# Terminado episodio 53 con retorno 0 en 4 pasos
# Terminado episodio 54 con retorno 0 en 244 pasos
# Terminado episodio 55 con retorno 0.9357142857142857 en 7 pasos
# Terminado episodio 56 con retorno 0 en 33 pasos
# Terminado episodio 57 con retorno 0 en 83 pasos
# Terminado episodio 58 con retorno 0 en 25 pasos
# Terminado episodio 59 con retorno 0 en 241 pasos
# Terminado episodio 60 con retorno 0 en 12 pasos
# Terminado episodio 61 con retorno 0 en 166 pasos
# Terminado episodio 62 con retorno 0.9178571428571428 en 11 pasos
# Terminado episodio 63 con retorno 0 en 170 pasos
# Terminado episodio 64 con retorno 0 en 87 pasos
# Terminado episodio 65 con retorno 0.9285714285714286 en 10 pasos
# Terminado episodio 66 con retorno 0.9214285714285715 en 9 pasos
# Terminado episodio 67 con retorno 0 en 27 pasos
# Terminado episodio 68 con retorno 0.9607142857142857 en 2 pasos
# Terminado episodio 69 con retorno 0.9428571428571428 en 7 pasos
# Terminado episodio 70 con retorno 0 en 246 pasos
# Terminado episodio 71 con retorno 0 en 244 pasos
# Terminado episodio 72 con retorno 0.9214285714285715 en 12 pasos
# Terminado episodio 73 con retorno 0 en 32 pasos
# Terminado episodio 74 con retorno 0 en 7 pasos
# Terminado episodio 75 con retorno 0 en 1 pasos
# Terminado episodio 76 con retorno 0 en 219 pasos
# Terminado episodio 77 con retorno 0 en 27 pasos
# Terminado episodio 78 con retorno 0 en 2 pasos
# Terminado episodio 79 con retorno 0.9035714285714286 en 12 pasos
# Terminado episodio 80 con retorno 0 en 246 pasos
# Terminado episodio 81 con retorno 0 en 8 pasos
# Terminado episodio 82 con retorno 0.9142857142857143 en 13 pasos
# Terminado episodio 83 con retorno 0 en 249 pasos
# Terminado episodio 84 con retorno 0 en 9 pasos
# Terminado episodio 85 con retorno 0.9321428571428572 en 4 pasos
# Terminado episodio 86 con retorno 0.925 en 7 pasos
# Terminado episodio 87 con retorno 0.9321428571428572 en 6 pasos
# Terminado episodio 88 con retorno 0.9571428571428572 en 3 pasos
# Terminado episodio 89 con retorno 0 en 237 pasos
# Terminado episodio 90 con retorno 0 en 49 pasos
# Terminado episodio 91 con retorno 0 en 168 pasos
# Terminado episodio 92 con retorno 0 en 21 pasos
# Terminado episodio 93 con retorno 0.95 en 5 pasos
# Terminado episodio 94 con retorno 0 en 145 pasos
# Terminado episodio 95 con retorno 0 en 44 pasos
# Terminado episodio 96 con retorno 0.9285714285714286 en 10 pasos
# Terminado episodio 97 con retorno 0.9285714285714286 en 9 pasos
# Terminado episodio 98 con retorno 0.8857142857142857 en 24 pasos
# Terminado episodio 99 con retorno 0 en 66 pasos
# Terminado episodio 100 con retorno 0 en 6 pasos (retorno medio de 0.28432142857142856 en los últimos 100 episodios)
# Terminado episodio 101 con retorno 0 en 5 pasos (retorno medio de 0.28432142857142856 en los últimos 100 episodios)
# Terminado episodio 102 con retorno 0.9321428571428572 en 6 pasos (retorno medio de 0.29364285714285715 en los últimos 100 episodios)
# Terminado episodio 103 con retorno 0 en 24 pasos (retorno medio de 0.29364285714285715 en los últimos 100 episodios)
# Terminado episodio 104 con retorno 0 en 7 pasos (retorno medio de 0.28460714285714284 en los últimos 100 episodios)
# Terminado episodio 105 con retorno 0 en 4 pasos (retorno medio de 0.2846071428571429 en los últimos 100 episodios)
# Terminado episodio 106 con retorno 0 en 31 pasos (retorno medio de 0.2846071428571429 en los últimos 100 episodios)
# Terminado episodio 107 con retorno 0 en 102 pasos (retorno medio de 0.28460714285714284 en los últimos 100 episodios)
# Terminado episodio 108 con retorno 0 en 4 pasos (retorno medio de 0.28460714285714284 en los últimos 100 episodios)
# Terminado episodio 109 con retorno 0.9357142857142857 en 7 pasos (retorno medio de 0.29396428571428573 en los últimos 100 episodios)
# Terminado episodio 110 con retorno 0.9642857142857143 en 2 pasos (retorno medio de 0.29953571428571435 en los últimos 100 episodios)
# Terminado episodio 111 con retorno 0.9464285714285714 en 4 pasos (retorno medio de 0.30900000000000005 en los últimos 100 episodios)
# Terminado episodio 112 con retorno 0 en 10 pasos (retorno medio de 0.2997857142857143 en los últimos 100 episodios)
# Terminado episodio 113 con retorno 0 en 14 pasos (retorno medio de 0.2997857142857143 en los últimos 100 episodios)
# Terminado episodio 114 con retorno 0.925 en 10 pasos (retorno medio de 0.3090357142857143 en los últimos 100 episodios)
# Terminado episodio 115 con retorno 0.9035714285714286 en 15 pasos (retorno medio de 0.30982142857142864 en los últimos 100 episodios)
# Terminado episodio 116 con retorno 0.9607142857142857 en 3 pasos (retorno medio de 0.3115357142857143 en los últimos 100 episodios)
# Terminado episodio 117 con retorno 0 en 1 pasos (retorno medio de 0.3115357142857143 en los últimos 100 episodios)
# Terminado episodio 118 con retorno 0 en 8 pasos (retorno medio de 0.3022142857142857 en los últimos 100 episodios)
# Terminado episodio 119 con retorno 0 en 245 pasos (retorno medio de 0.2926785714285714 en los últimos 100 episodios)
# Terminado episodio 120 con retorno 0 en 6 pasos (retorno medio de 0.2926785714285714 en los últimos 100 episodios)
# Terminado episodio 121 con retorno 0 en 9 pasos (retorno medio de 0.29267857142857145 en los últimos 100 episodios)
# Terminado episodio 122 con retorno 0.9535714285714285 en 1 pasos (retorno medio de 0.3022142857142857 en los últimos 100 episodios)
# Terminado episodio 123 con retorno 0.9214285714285715 en 10 pasos (retorno medio de 0.31142857142857144 en los últimos 100 episodios)
# Terminado episodio 124 con retorno 0.9535714285714285 en 4 pasos (retorno medio de 0.31146428571428575 en los últimos 100 episodios)
# Terminado episodio 125 con retorno 0 en 4 pasos (retorno medio de 0.31146428571428575 en los últimos 100 episodios)
# Terminado episodio 126 con retorno 0.9392857142857143 en 5 pasos (retorno medio de 0.3208571428571429 en los últimos 100 episodios)
# Terminado episodio 127 con retorno 0 en 242 pasos (retorno medio de 0.3208571428571429 en los últimos 100 episodios)
# Terminado episodio 128 con retorno 0.9607142857142857 en 3 pasos (retorno medio de 0.33046428571428577 en los últimos 100 episodios)
# Terminado episodio 129 con retorno 0 en 243 pasos (retorno medio de 0.33046428571428577 en los últimos 100 episodios)
# Terminado episodio 130 con retorno 0 en 20 pasos (retorno medio de 0.33046428571428577 en los últimos 100 episodios)
# Terminado episodio 131 con retorno 0.9285714285714286 en 10 pasos (retorno medio de 0.3397500000000001 en los últimos 100 episodios)
# Terminado episodio 132 con retorno 0.9642857142857143 en 2 pasos (retorno medio de 0.3411428571428572 en los últimos 100 episodios)
# Terminado episodio 133 con retorno 0 en 9 pasos (retorno medio de 0.34114285714285714 en los últimos 100 episodios)
# Terminado episodio 134 con retorno 0 en 38 pasos (retorno medio de 0.332 en los últimos 100 episodios)
# Terminado episodio 135 con retorno 0 en 7 pasos (retorno medio de 0.332 en los últimos 100 episodios)
# Terminado episodio 136 con retorno 0 en 135 pasos (retorno medio de 0.3228214285714286 en los últimos 100 episodios)
# Terminado episodio 137 con retorno 0 en 7 pasos (retorno medio de 0.3228214285714286 en los últimos 100 episodios)
# Terminado episodio 138 con retorno 0 en 60 pasos (retorno medio de 0.3228214285714286 en los últimos 100 episodios)
# Terminado episodio 139 con retorno 0 en 83 pasos (retorno medio de 0.3228214285714286 en los últimos 100 episodios)
# Terminado episodio 140 con retorno 0 en 175 pasos (retorno medio de 0.3178928571428572 en los últimos 100 episodios)
# Terminado episodio 141 con retorno 0 en 28 pasos (retorno medio de 0.31789285714285714 en los últimos 100 episodios)
# Terminado episodio 142 con retorno 0 en 62 pasos (retorno medio de 0.3178928571428572 en los últimos 100 episodios)
# Terminado episodio 143 con retorno 0 en 53 pasos (retorno medio de 0.31789285714285714 en los últimos 100 episodios)
# Terminado episodio 144 con retorno 0.9285714285714286 en 7 pasos (retorno medio de 0.31796428571428575 en los últimos 100 episodios)
# Terminado episodio 145 con retorno 0 en 91 pasos (retorno medio de 0.3179642857142857 en los últimos 100 episodios)
# Terminado episodio 146 con retorno 0.9535714285714285 en 4 pasos (retorno medio de 0.31792857142857145 en los últimos 100 episodios)
# Terminado episodio 147 con retorno 0 en 136 pasos (retorno medio de 0.31792857142857145 en los últimos 100 episodios)
# Terminado episodio 148 con retorno 0.95 en 5 pasos (retorno medio de 0.32742857142857146 en los últimos 100 episodios)
# Terminado episodio 149 con retorno 0 en 17 pasos (retorno medio de 0.32742857142857146 en los últimos 100 episodios)
# Terminado episodio 150 con retorno 0 en 4 pasos (retorno medio de 0.32742857142857146 en los últimos 100 episodios)
# Terminado episodio 151 con retorno 0.9321428571428572 en 6 pasos (retorno medio de 0.3273928571428572 en los últimos 100 episodios)
# Terminado episodio 152 con retorno 0.9071428571428571 en 12 pasos (retorno medio de 0.3364642857142857 en los últimos 100 episodios)
# Terminado episodio 153 con retorno 0 en 43 pasos (retorno medio de 0.3364642857142857 en los últimos 100 episodios)
# Terminado episodio 154 con retorno 0 en 69 pasos (retorno medio de 0.3364642857142857 en los últimos 100 episodios)
# Terminado episodio 155 con retorno 0 en 2 pasos (retorno medio de 0.3271071428571429 en los últimos 100 episodios)
# Terminado episodio 156 con retorno 0 en 64 pasos (retorno medio de 0.3271071428571429 en los últimos 100 episodios)
# Terminado episodio 157 con retorno 0.9321428571428572 en 8 pasos (retorno medio de 0.33642857142857147 en los últimos 100 episodios)
# Terminado episodio 158 con retorno 0.95 en 5 pasos (retorno medio de 0.3459285714285715 en los últimos 100 episodios)
# Terminado episodio 159 con retorno 0.8821428571428571 en 23 pasos (retorno medio de 0.35475000000000007 en los últimos 100 episodios)
# Terminado episodio 160 con retorno 0.95 en 6 pasos (retorno medio de 0.36425000000000013 en los últimos 100 episodios)
# Terminado episodio 161 con retorno 0.27142857142857135 en 196 pasos (retorno medio de 0.36696428571428574 en los últimos 100 episodios)
# Terminado episodio 162 con retorno 0.925 en 13 pasos (retorno medio de 0.3670357142857143 en los últimos 100 episodios)
# Terminado episodio 163 con retorno 0.9571428571428572 en 3 pasos (retorno medio de 0.37660714285714286 en los últimos 100 episodios)
# Terminado episodio 164 con retorno 0.20000000000000007 en 214 pasos (retorno medio de 0.37860714285714286 en los últimos 100 episodios)
# Terminado episodio 165 con retorno 0.7642857142857142 en 57 pasos (retorno medio de 0.3769642857142857 en los últimos 100 episodios)
# Terminado episodio 166 con retorno 0 en 16 pasos (retorno medio de 0.36774999999999997 en los últimos 100 episodios)
# Terminado episodio 167 con retorno 0.5249999999999999 en 125 pasos (retorno medio de 0.373 en los últimos 100 episodios)
# Terminado episodio 168 con retorno 0 en 86 pasos (retorno medio de 0.3633928571428571 en los últimos 100 episodios)
# Terminado episodio 169 con retorno 0.95 en 4 pasos (retorno medio de 0.3634642857142857 en los últimos 100 episodios)
# Terminado episodio 170 con retorno 0.8142857142857143 en 41 pasos (retorno medio de 0.3716071428571429 en los últimos 100 episodios)
# Terminado episodio 171 con retorno 0.9392857142857143 en 7 pasos (retorno medio de 0.38100000000000006 en los últimos 100 episodios)
# Terminado episodio 172 con retorno 0.8357142857142857 en 35 pasos (retorno medio de 0.3801428571428573 en los últimos 100 episodios)
# Terminado episodio 173 con retorno 0.6571428571428571 en 91 pasos (retorno medio de 0.3867142857142858 en los últimos 100 episodios)
# Terminado episodio 174 con retorno 0.8714285714285714 en 30 pasos (retorno medio de 0.3954285714285715 en los últimos 100 episodios)
# Terminado episodio 175 con retorno 0.85 en 32 pasos (retorno medio de 0.4039285714285715 en los últimos 100 episodios)
# Terminado episodio 176 con retorno 0.9464285714285714 en 4 pasos (retorno medio de 0.41339285714285723 en los últimos 100 episodios)
# Terminado episodio 177 con retorno 0.95 en 5 pasos (retorno medio de 0.42289285714285724 en los últimos 100 episodios)
# Terminado episodio 178 con retorno 0.9642857142857143 en 3 pasos (retorno medio de 0.43253571428571436 en los últimos 100 episodios)
# Terminado episodio 179 con retorno 0 en 4 pasos (retorno medio de 0.4235 en los últimos 100 episodios)
# Terminado episodio 180 con retorno 0.8928571428571429 en 23 pasos (retorno medio de 0.4324285714285715 en los últimos 100 episodios)
# Terminado episodio 181 con retorno 0 en 247 pasos (retorno medio de 0.4324285714285715 en los últimos 100 episodios)
# Terminado episodio 182 con retorno 0.95 en 6 pasos (retorno medio de 0.4327857142857144 en los últimos 100 episodios)
# Terminado episodio 183 con retorno 0.7821428571428571 en 48 pasos (retorno medio de 0.4406071428571429 en los últimos 100 episodios)
# Terminado episodio 184 con retorno 0.8428571428571429 en 33 pasos (retorno medio de 0.44903571428571437 en los últimos 100 episodios)
# Terminado episodio 185 con retorno 0.8571428571428572 en 30 pasos (retorno medio de 0.4482857142857143 en los últimos 100 episodios)
# Terminado episodio 186 con retorno 0.5678571428571428 en 116 pasos (retorno medio de 0.44471428571428573 en los últimos 100 episodios)
# Terminado episodio 187 con retorno 0 en 69 pasos (retorno medio de 0.43539285714285714 en los últimos 100 episodios)
# Terminado episodio 188 con retorno 0 en 246 pasos (retorno medio de 0.4258214285714286 en los últimos 100 episodios)
# Terminado episodio 189 con retorno 0.8928571428571429 en 19 pasos (retorno medio de 0.43475 en los últimos 100 episodios)
# Terminado episodio 190 con retorno 0 en 5 pasos (retorno medio de 0.43475 en los últimos 100 episodios)
# Terminado episodio 191 con retorno 0 en 11 pasos (retorno medio de 0.43475 en los últimos 100 episodios)
# Terminado episodio 192 con retorno 0.775 en 51 pasos (retorno medio de 0.4425 en los últimos 100 episodios)
# Terminado episodio 193 con retorno 0 en 11 pasos (retorno medio de 0.433 en los últimos 100 episodios)
# Terminado episodio 194 con retorno 0.7642857142857142 en 55 pasos (retorno medio de 0.44064285714285717 en los últimos 100 episodios)
# Terminado episodio 195 con retorno 0.8071428571428572 en 44 pasos (retorno medio de 0.4487142857142856 en los últimos 100 episodios)
# Terminado episodio 196 con retorno 0.9321428571428572 en 9 pasos (retorno medio de 0.4487499999999999 en los últimos 100 episodios)
# Terminado episodio 197 con retorno 0.8392857142857143 en 33 pasos (retorno medio de 0.44785714285714284 en los últimos 100 episodios)
# Terminado episodio 198 con retorno 0 en 110 pasos (retorno medio de 0.439 en los últimos 100 episodios)
# Terminado episodio 199 con retorno 0 en 32 pasos (retorno medio de 0.4389999999999999 en los últimos 100 episodios)
# Terminado episodio 200 con retorno 0.8178571428571428 en 41 pasos (retorno medio de 0.4471785714285714 en los últimos 100 episodios)
# Terminado episodio 201 con retorno 0 en 244 pasos (retorno medio de 0.4471785714285714 en los últimos 100 episodios)
# Terminado episodio 202 con retorno 0.9642857142857143 en 3 pasos (retorno medio de 0.4475 en los últimos 100 episodios)
# Terminado episodio 203 con retorno 0 en 83 pasos (retorno medio de 0.4475 en los últimos 100 episodios)
# Terminado episodio 204 con retorno 0 en 179 pasos (retorno medio de 0.4475 en los últimos 100 episodios)
# Terminado episodio 205 con retorno 0 en 80 pasos (retorno medio de 0.4475 en los últimos 100 episodios)
# Terminado episodio 206 con retorno 0 en 10 pasos (retorno medio de 0.4475 en los últimos 100 episodios)
# Terminado episodio 207 con retorno 0 en 56 pasos (retorno medio de 0.4475 en los últimos 100 episodios)
# Terminado episodio 208 con retorno 0.3321428571428571 en 179 pasos (retorno medio de 0.45082142857142854 en los últimos 100 episodios)
# Terminado episodio 209 con retorno 0 en 45 pasos (retorno medio de 0.4414642857142857 en los últimos 100 episodios)
# Terminado episodio 210 con retorno 0.9571428571428572 en 3 pasos (retorno medio de 0.44139285714285714 en los últimos 100 episodios)
# Terminado episodio 211 con retorno 0 en 38 pasos (retorno medio de 0.4319285714285714 en los últimos 100 episodios)
# Terminado episodio 212 con retorno 0 en 243 pasos (retorno medio de 0.43192857142857144 en los últimos 100 episodios)
# Terminado episodio 213 con retorno 0 en 48 pasos (retorno medio de 0.4319285714285714 en los últimos 100 episodios)
# Terminado episodio 214 con retorno 0 en 245 pasos (retorno medio de 0.4226785714285714 en los últimos 100 episodios)
# Terminado episodio 215 con retorno 0 en 247 pasos (retorno medio de 0.41364285714285715 en los últimos 100 episodios)
# Terminado episodio 216 con retorno 0 en 243 pasos (retorno medio de 0.4040357142857143 en los últimos 100 episodios)
# Terminado episodio 217 con retorno 0 en 243 pasos (retorno medio de 0.4040357142857143 en los últimos 100 episodios)
# Terminado episodio 218 con retorno 0 en 60 pasos (retorno medio de 0.4040357142857143 en los últimos 100 episodios)
# Terminado episodio 219 con retorno 0 en 8 pasos (retorno medio de 0.4040357142857143 en los últimos 100 episodios)
# Terminado episodio 220 con retorno 0 en 54 pasos (retorno medio de 0.4040357142857143 en los últimos 100 episodios)
# Terminado episodio 221 con retorno 0 en 194 pasos (retorno medio de 0.4040357142857143 en los últimos 100 episodios)
# Terminado episodio 222 con retorno 0 en 169 pasos (retorno medio de 0.3945 en los últimos 100 episodios)
# Terminado episodio 223 con retorno 0 en 58 pasos (retorno medio de 0.38528571428571423 en los últimos 100 episodios)
# Terminado episodio 224 con retorno 0 en 24 pasos (retorno medio de 0.37575000000000003 en los últimos 100 episodios)
# Terminado episodio 225 con retorno 0 en 248 pasos (retorno medio de 0.37575000000000003 en los últimos 100 episodios)
# Terminado episodio 226 con retorno 0 en 147 pasos (retorno medio de 0.3663571428571429 en los últimos 100 episodios)
# Terminado episodio 227 con retorno 0 en 243 pasos (retorno medio de 0.3663571428571429 en los últimos 100 episodios)
# Terminado episodio 228 con retorno 0 en 243 pasos (retorno medio de 0.35675000000000007 en los últimos 100 episodios)
# Terminado episodio 229 con retorno 0 en 241 pasos (retorno medio de 0.35675000000000007 en los últimos 100 episodios)
# Terminado episodio 230 con retorno 0 en 241 pasos (retorno medio de 0.35674999999999996 en los últimos 100 episodios)
# Terminado episodio 231 con retorno 0 en 243 pasos (retorno medio de 0.34746428571428567 en los últimos 100 episodios)
# Terminado episodio 232 con retorno 0 en 238 pasos (retorno medio de 0.3378214285714286 en los últimos 100 episodios)
# Terminado episodio 233 con retorno 0 en 246 pasos (retorno medio de 0.3378214285714286 en los últimos 100 episodios)
# Terminado episodio 234 con retorno 0 en 244 pasos (retorno medio de 0.3378214285714286 en los últimos 100 episodios)
# Terminado episodio 235 con retorno 0 en 56 pasos (retorno medio de 0.3378214285714286 en los últimos 100 episodios)
# Terminado episodio 236 con retorno 0 en 1 pasos (retorno medio de 0.3378214285714286 en los últimos 100 episodios)
# Terminado episodio 237 con retorno 0 en 232 pasos (retorno medio de 0.3378214285714286 en los últimos 100 episodios)
# Terminado episodio 238 con retorno 0 en 246 pasos (retorno medio de 0.3378214285714286 en los últimos 100 episodios)
# Terminado episodio 239 con retorno 0 en 243 pasos (retorno medio de 0.3378214285714286 en los últimos 100 episodios)
# Terminado episodio 240 con retorno 0 en 18 pasos (retorno medio de 0.3378214285714286 en los últimos 100 episodios)
# Terminado episodio 241 con retorno 0 en 246 pasos (retorno medio de 0.3378214285714286 en los últimos 100 episodios)
# Terminado episodio 242 con retorno 0 en 39 pasos (retorno medio de 0.3378214285714286 en los últimos 100 episodios)
# Terminado episodio 243 con retorno 0 en 241 pasos (retorno medio de 0.3378214285714286 en los últimos 100 episodios)
# Terminado episodio 244 con retorno 0 en 240 pasos (retorno medio de 0.32853571428571426 en los últimos 100 episodios)
# Terminado episodio 245 con retorno 0 en 246 pasos (retorno medio de 0.32853571428571426 en los últimos 100 episodios)
# Terminado episodio 246 con retorno 0 en 3 pasos (retorno medio de 0.319 en los últimos 100 episodios)
# Terminado episodio 247 con retorno 0 en 140 pasos (retorno medio de 0.319 en los últimos 100 episodios)
# Terminado episodio 248 con retorno 0 en 245 pasos (retorno medio de 0.30950000000000005 en los últimos 100 episodios)
# Terminado episodio 249 con retorno 0 en 5 pasos (retorno medio de 0.30950000000000005 en los últimos 100 episodios)
# Terminado episodio 250 con retorno 0 en 8 pasos (retorno medio de 0.30950000000000005 en los últimos 100 episodios)
# Terminado episodio 251 con retorno 0 en 247 pasos (retorno medio de 0.3001785714285714 en los últimos 100 episodios)
# Terminado episodio 252 con retorno 0 en 247 pasos (retorno medio de 0.2911071428571429 en los últimos 100 episodios)
# Terminado episodio 253 con retorno 0 en 1 pasos (retorno medio de 0.29110714285714284 en los últimos 100 episodios)
# Terminado episodio 254 con retorno 0 en 203 pasos (retorno medio de 0.2911071428571429 en los últimos 100 episodios)
# Terminado episodio 255 con retorno 0 en 244 pasos (retorno medio de 0.29110714285714284 en los últimos 100 episodios)
# Terminado episodio 256 con retorno 0 en 2 pasos (retorno medio de 0.2911071428571429 en los últimos 100 episodios)
# Terminado episodio 257 con retorno 0 en 241 pasos (retorno medio de 0.28178571428571425 en los últimos 100 episodios)
# Terminado episodio 258 con retorno 0 en 244 pasos (retorno medio de 0.2722857142857143 en los últimos 100 episodios)
# Terminado episodio 259 con retorno 0 en 249 pasos (retorno medio de 0.2634642857142857 en los últimos 100 episodios)
# Terminado episodio 260 con retorno 0 en 47 pasos (retorno medio de 0.2539642857142857 en los últimos 100 episodios)
# Terminado episodio 261 con retorno 0 en 125 pasos (retorno medio de 0.25125 en los últimos 100 episodios)
# Terminado episodio 262 con retorno 0 en 241 pasos (retorno medio de 0.24200000000000002 en los últimos 100 episodios)
# Terminado episodio 263 con retorno 0 en 183 pasos (retorno medio de 0.23242857142857143 en los últimos 100 episodios)
# Terminado episodio 264 con retorno 0 en 243 pasos (retorno medio de 0.23042857142857145 en los últimos 100 episodios)
# Terminado episodio 265 con retorno 0 en 239 pasos (retorno medio de 0.22278571428571428 en los últimos 100 episodios)
# Terminado episodio 266 con retorno 0 en 244 pasos (retorno medio de 0.22278571428571428 en los últimos 100 episodios)
# Terminado episodio 267 con retorno 0 en 244 pasos (retorno medio de 0.21753571428571428 en los últimos 100 episodios)
# Terminado episodio 268 con retorno 0 en 246 pasos (retorno medio de 0.21753571428571428 en los últimos 100 episodios)
# Terminado episodio 269 con retorno 0 en 241 pasos (retorno medio de 0.2080357142857143 en los últimos 100 episodios)
# Terminado episodio 270 con retorno 0 en 246 pasos (retorno medio de 0.19989285714285715 en los últimos 100 episodios)
# Terminado episodio 271 con retorno 0 en 3 pasos (retorno medio de 0.19049999999999997 en los últimos 100 episodios)
# Terminado episodio 272 con retorno 0 en 67 pasos (retorno medio de 0.18214285714285716 en los últimos 100 episodios)
# Terminado episodio 273 con retorno 0 en 240 pasos (retorno medio de 0.17557142857142857 en los últimos 100 episodios)
# Terminado episodio 274 con retorno 0 en 243 pasos (retorno medio de 0.16685714285714284 en los últimos 100 episodios)
# Terminado episodio 275 con retorno 0 en 246 pasos (retorno medio de 0.15835714285714286 en los últimos 100 episodios)
# Terminado episodio 276 con retorno 0 en 104 pasos (retorno medio de 0.14889285714285713 en los últimos 100 episodios)
# Terminado episodio 277 con retorno 0 en 245 pasos (retorno medio de 0.13939285714285715 en los últimos 100 episodios)
# Terminado episodio 278 con retorno 0 en 242 pasos (retorno medio de 0.12975 en los últimos 100 episodios)
# Terminado episodio 279 con retorno 0.9535714285714285 en 1 pasos (retorno medio de 0.13928571428571432 en los últimos 100 episodios)
# Terminado episodio 280 con retorno 0 en 123 pasos (retorno medio de 0.13035714285714287 en los últimos 100 episodios)
# Terminado episodio 281 con retorno 0 en 244 pasos (retorno medio de 0.1303571428571429 en los últimos 100 episodios)
# Terminado episodio 282 con retorno 0 en 247 pasos (retorno medio de 0.12085714285714287 en los últimos 100 episodios)
# Terminado episodio 283 con retorno 0 en 246 pasos (retorno medio de 0.11303571428571431 en los últimos 100 episodios)
# Terminado episodio 284 con retorno 0 en 241 pasos (retorno medio de 0.10460714285714286 en los últimos 100 episodios)
# Terminado episodio 285 con retorno 0 en 21 pasos (retorno medio de 0.0960357142857143 en los últimos 100 episodios)
# Terminado episodio 286 con retorno 0 en 246 pasos (retorno medio de 0.09035714285714286 en los últimos 100 episodios)
# Terminado episodio 287 con retorno 0 en 3 pasos (retorno medio de 0.09035714285714284 en los últimos 100 episodios)
# Terminado episodio 288 con retorno 0 en 242 pasos (retorno medio de 0.09035714285714286 en los últimos 100 episodios)
# Terminado episodio 289 con retorno 0 en 5 pasos (retorno medio de 0.08142857142857142 en los últimos 100 episodios)
# Terminado episodio 290 con retorno 0 en 243 pasos (retorno medio de 0.08142857142857145 en los últimos 100 episodios)
# Terminado episodio 291 con retorno 0 en 238 pasos (retorno medio de 0.08142857142857142 en los últimos 100 episodios)
# Terminado episodio 292 con retorno 0 en 248 pasos (retorno medio de 0.07367857142857144 en los últimos 100 episodios)
# Terminado episodio 293 con retorno 0 en 244 pasos (retorno medio de 0.07367857142857143 en los últimos 100 episodios)
# Terminado episodio 294 con retorno 0.9535714285714285 en 3 pasos (retorno medio de 0.07557142857142858 en los últimos 100 episodios)
# Terminado episodio 295 con retorno 0 en 2 pasos (retorno medio de 0.06749999999999999 en los últimos 100 episodios)
# Terminado episodio 296 con retorno 0 en 242 pasos (retorno medio de 0.058178571428571434 en los últimos 100 episodios)
# Terminado episodio 297 con retorno 0 en 5 pasos (retorno medio de 0.04978571428571429 en los últimos 100 episodios)
# Terminado episodio 298 con retorno 0 en 243 pasos (retorno medio de 0.04978571428571429 en los últimos 100 episodios)
# Terminado episodio 299 con retorno 0 en 242 pasos (retorno medio de 0.04978571428571428 en los últimos 100 episodios)
# Terminado episodio 300 con retorno 0 en 247 pasos (retorno medio de 0.041607142857142856 en los últimos 100 episodios)
# Terminado episodio 301 con retorno 0 en 243 pasos (retorno medio de 0.041607142857142856 en los últimos 100 episodios)
# Terminado episodio 302 con retorno 0 en 172 pasos (retorno medio de 0.03196428571428571 en los últimos 100 episodios)
# Terminado episodio 303 con retorno 0 en 90 pasos (retorno medio de 0.03196428571428571 en los últimos 100 episodios)
# Terminado episodio 304 con retorno 0 en 239 pasos (retorno medio de 0.03196428571428571 en los últimos 100 episodios)
# Terminado episodio 305 con retorno 0 en 244 pasos (retorno medio de 0.03196428571428571 en los últimos 100 episodios)
# Terminado episodio 306 con retorno 0 en 1 pasos (retorno medio de 0.03196428571428571 en los últimos 100 episodios)
# Terminado episodio 307 con retorno 0 en 18 pasos (retorno medio de 0.03196428571428571 en los últimos 100 episodios)
# Terminado episodio 308 con retorno 0 en 243 pasos (retorno medio de 0.028642857142857144 en los últimos 100 episodios)
# Terminado episodio 309 con retorno 0 en 246 pasos (retorno medio de 0.028642857142857144 en los últimos 100 episodios)
# Terminado episodio 310 con retorno 0 en 2 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 311 con retorno 0 en 3 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 312 con retorno 0 en 248 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 313 con retorno 0 en 243 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 314 con retorno 0 en 1 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 315 con retorno 0 en 244 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 316 con retorno 0 en 242 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 317 con retorno 0 en 247 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 318 con retorno 0 en 247 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 319 con retorno 0 en 248 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 320 con retorno 0 en 243 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 321 con retorno 0 en 242 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 322 con retorno 0 en 9 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 323 con retorno 0 en 239 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 324 con retorno 0 en 239 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 325 con retorno 0 en 244 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 326 con retorno 0 en 246 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 327 con retorno 0 en 241 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 328 con retorno 0 en 239 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 329 con retorno 0 en 3 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 330 con retorno 0 en 241 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 331 con retorno 0 en 246 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 332 con retorno 0 en 13 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 333 con retorno 0 en 246 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 334 con retorno 0 en 244 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 335 con retorno 0 en 24 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 336 con retorno 0 en 146 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 337 con retorno 0 en 238 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 338 con retorno 0 en 240 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 339 con retorno 0 en 148 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 340 con retorno 0 en 246 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 341 con retorno 0 en 24 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 342 con retorno 0 en 248 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 343 con retorno 0 en 239 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 344 con retorno 0 en 246 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 345 con retorno 0 en 67 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 346 con retorno 0 en 243 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 347 con retorno 0 en 246 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 348 con retorno 0 en 39 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 349 con retorno 0 en 242 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 350 con retorno 0 en 248 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 351 con retorno 0 en 240 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 352 con retorno 0 en 245 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 353 con retorno 0 en 242 pasos (retorno medio de 0.01907142857142857 en los últimos 100 episodios)
# Terminado episodio 354 con retorno 0.7214285714285714 en 65 pasos (retorno medio de 0.026285714285714287 en los últimos 100 episodios)
# Terminado episodio 355 con retorno 0 en 200 pasos (retorno medio de 0.026285714285714287 en los últimos 100 episodios)
# Terminado episodio 356 con retorno 0 en 11 pasos (retorno medio de 0.026285714285714287 en los últimos 100 episodios)
# Terminado episodio 357 con retorno 0 en 246 pasos (retorno medio de 0.026285714285714287 en los últimos 100 episodios)
# Terminado episodio 358 con retorno 0 en 7 pasos (retorno medio de 0.02628571428571428 en los últimos 100 episodios)
# Terminado episodio 359 con retorno 0 en 57 pasos (retorno medio de 0.026285714285714287 en los últimos 100 episodios)
# Terminado episodio 360 con retorno 0 en 33 pasos (retorno medio de 0.026285714285714287 en los últimos 100 episodios)
# Terminado episodio 361 con retorno 0 en 158 pasos (retorno medio de 0.026285714285714287 en los últimos 100 episodios)
# Terminado episodio 362 con retorno 0 en 244 pasos (retorno medio de 0.02628571428571428 en los últimos 100 episodios)
# Terminado episodio 363 con retorno 0 en 6 pasos (retorno medio de 0.026285714285714287 en los últimos 100 episodios)
# Terminado episodio 364 con retorno 0 en 83 pasos (retorno medio de 0.026285714285714287 en los últimos 100 episodios)
# Terminado episodio 365 con retorno 0 en 120 pasos (retorno medio de 0.026285714285714287 en los últimos 100 episodios)
# Terminado episodio 366 con retorno 0 en 97 pasos (retorno medio de 0.02628571428571428 en los últimos 100 episodios)
# Terminado episodio 367 con retorno 0 en 161 pasos (retorno medio de 0.026285714285714287 en los últimos 100 episodios)
# Terminado episodio 368 con retorno 0 en 240 pasos (retorno medio de 0.026285714285714287 en los últimos 100 episodios)
# Terminado episodio 369 con retorno 0 en 189 pasos (retorno medio de 0.026285714285714287 en los últimos 100 episodios)
# Terminado episodio 370 con retorno 0 en 4 pasos (retorno medio de 0.02628571428571428 en los últimos 100 episodios)
# Terminado episodio 371 con retorno 0 en 6 pasos (retorno medio de 0.026285714285714287 en los últimos 100 episodios)
# Terminado episodio 372 con retorno 0 en 3 pasos (retorno medio de 0.026285714285714287 en los últimos 100 episodios)
# Terminado episodio 373 con retorno 0.85 en 31 pasos (retorno medio de 0.03478571428571429 en los últimos 100 episodios)
# Terminado episodio 374 con retorno 0 en 9 pasos (retorno medio de 0.03478571428571428 en los últimos 100 episodios)
# Terminado episodio 375 con retorno 0 en 4 pasos (retorno medio de 0.03478571428571429 en los últimos 100 episodios)
# Terminado episodio 376 con retorno 0.7857142857142857 en 45 pasos (retorno medio de 0.04264285714285714 en los últimos 100 episodios)
# Terminado episodio 377 con retorno 0.9 en 19 pasos (retorno medio de 0.05164285714285714 en los últimos 100 episodios)
# Terminado episodio 378 con retorno 0 en 13 pasos (retorno medio de 0.05164285714285714 en los últimos 100 episodios)
# Terminado episodio 379 con retorno 0 en 250 pasos (retorno medio de 0.04210714285714286 en los últimos 100 episodios)
# Terminado episodio 380 con retorno 0 en 9 pasos (retorno medio de 0.04210714285714286 en los últimos 100 episodios)
# Terminado episodio 381 con retorno 0 en 29 pasos (retorno medio de 0.04210714285714286 en los últimos 100 episodios)
# Terminado episodio 382 con retorno 0.9571428571428572 en 5 pasos (retorno medio de 0.05167857142857143 en los últimos 100 episodios)
# Terminado episodio 383 con retorno 0 en 4 pasos (retorno medio de 0.05167857142857143 en los últimos 100 episodios)
# Terminado episodio 384 con retorno 0 en 21 pasos (retorno medio de 0.05167857142857143 en los últimos 100 episodios)
# Terminado episodio 385 con retorno 0 en 74 pasos (retorno medio de 0.05167857142857143 en los últimos 100 episodios)
# Terminado episodio 386 con retorno 0 en 20 pasos (retorno medio de 0.05167857142857143 en los últimos 100 episodios)
# Terminado episodio 387 con retorno 0 en 7 pasos (retorno medio de 0.05167857142857143 en los últimos 100 episodios)
# Terminado episodio 388 con retorno 0.9 en 19 pasos (retorno medio de 0.06067857142857143 en los últimos 100 episodios)
# Terminado episodio 389 con retorno 0.95 en 5 pasos (retorno medio de 0.07017857142857144 en los últimos 100 episodios)
# Terminado episodio 390 con retorno 0 en 27 pasos (retorno medio de 0.07017857142857144 en los últimos 100 episodios)
# Terminado episodio 391 con retorno 0 en 5 pasos (retorno medio de 0.07017857142857144 en los últimos 100 episodios)
# Terminado episodio 392 con retorno 0 en 57 pasos (retorno medio de 0.07017857142857144 en los últimos 100 episodios)
# Terminado episodio 393 con retorno 0.9357142857142857 en 7 pasos (retorno medio de 0.07953571428571428 en los últimos 100 episodios)
# Terminado episodio 394 con retorno 0.9642857142857143 en 3 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 395 con retorno 0 en 4 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 396 con retorno 0 en 135 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 397 con retorno 0 en 12 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 398 con retorno 0 en 178 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 399 con retorno 0 en 33 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 400 con retorno 0 en 89 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 401 con retorno 0 en 32 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 402 con retorno 0 en 86 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 403 con retorno 0 en 31 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 404 con retorno 0 en 75 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 405 con retorno 0 en 244 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 406 con retorno 0 en 243 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 407 con retorno 0 en 208 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 408 con retorno 0 en 221 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 409 con retorno 0 en 198 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 410 con retorno 0 en 244 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 411 con retorno 0 en 10 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 412 con retorno 0 en 25 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 413 con retorno 0 en 49 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 414 con retorno 0 en 241 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 415 con retorno 0 en 41 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 416 con retorno 0 en 246 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 417 con retorno 0 en 143 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 418 con retorno 0 en 26 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 419 con retorno 0 en 4 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 420 con retorno 0 en 202 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 421 con retorno 0 en 97 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 422 con retorno 0 en 247 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 423 con retorno 0 en 246 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 424 con retorno 0 en 245 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 425 con retorno 0 en 240 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 426 con retorno 0 en 245 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 427 con retorno 0 en 242 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 428 con retorno 0 en 159 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 429 con retorno 0 en 8 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 430 con retorno 0 en 243 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 431 con retorno 0 en 248 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 432 con retorno 0 en 240 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 433 con retorno 0 en 12 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 434 con retorno 0 en 147 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 435 con retorno 0 en 244 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 436 con retorno 0 en 239 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 437 con retorno 0 en 241 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 438 con retorno 0 en 2 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 439 con retorno 0 en 222 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 440 con retorno 0 en 244 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 441 con retorno 0 en 2 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 442 con retorno 0 en 243 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 443 con retorno 0 en 243 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 444 con retorno 0 en 237 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 445 con retorno 0 en 74 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 446 con retorno 0 en 240 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 447 con retorno 0 en 29 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 448 con retorno 0 en 239 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 449 con retorno 0 en 20 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 450 con retorno 0 en 242 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 451 con retorno 0 en 1 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 452 con retorno 0 en 239 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 453 con retorno 0 en 244 pasos (retorno medio de 0.07964285714285714 en los últimos 100 episodios)
# Terminado episodio 454 con retorno 0 en 244 pasos (retorno medio de 0.07242857142857143 en los últimos 100 episodios)
# Terminado episodio 455 con retorno 0 en 2 pasos (retorno medio de 0.07242857142857143 en los últimos 100 episodios)
# Terminado episodio 456 con retorno 0 en 239 pasos (retorno medio de 0.07242857142857143 en los últimos 100 episodios)
# Terminado episodio 457 con retorno 0 en 241 pasos (retorno medio de 0.07242857142857143 en los últimos 100 episodios)
# Terminado episodio 458 con retorno 0 en 2 pasos (retorno medio de 0.07242857142857143 en los últimos 100 episodios)
# Terminado episodio 459 con retorno 0 en 242 pasos (retorno medio de 0.07242857142857143 en los últimos 100 episodios)
# Terminado episodio 460 con retorno 0 en 245 pasos (retorno medio de 0.07242857142857143 en los últimos 100 episodios)
# Terminado episodio 461 con retorno 0 en 244 pasos (retorno medio de 0.07242857142857143 en los últimos 100 episodios)
# Terminado episodio 462 con retorno 0 en 245 pasos (retorno medio de 0.07242857142857143 en los últimos 100 episodios)
# Terminado episodio 463 con retorno 0 en 242 pasos (retorno medio de 0.07242857142857143 en los últimos 100 episodios)
# Terminado episodio 464 con retorno 0 en 242 pasos (retorno medio de 0.07242857142857143 en los últimos 100 episodios)
# <ipython-input-31-7993d27bd4f6>:37: RuntimeWarning: overflow encountered in scalar add
#   q_valores[estado.x, estado.y, estado.dir, accion] += ALPHA * (reward + GAMMA * q_valores[estado_siguiente.x, estado_siguiente.y, estado_siguiente.dir, accion_siguiente])
# Terminado episodio 465 con retorno 0 en 245 pasos (retorno medio de 0.07242857142857143 en los últimos 100 episodios)
# Terminado episodio 466 con retorno 0 en 244 pasos (retorno medio de 0.07242857142857143 en los últimos 100 episodios)
# Terminado episodio 467 con retorno 0 en 40 pasos (retorno medio de 0.07242857142857143 en los últimos 100 episodios)
# Terminado episodio 468 con retorno 0 en 3 pasos (retorno medio de 0.07242857142857143 en los últimos 100 episodios)
# Terminado episodio 469 con retorno 0 en 249 pasos (retorno medio de 0.07242857142857143 en los últimos 100 episodios)
# Terminado episodio 470 con retorno 0 en 12 pasos (retorno medio de 0.07242857142857143 en los últimos 100 episodios)
# Terminado episodio 471 con retorno 0 en 35 pasos (retorno medio de 0.07242857142857143 en los últimos 100 episodios)
# Terminado episodio 472 con retorno 0 en 3 pasos (retorno medio de 0.07242857142857143 en los últimos 100 episodios)
# Terminado episodio 473 con retorno 0 en 33 pasos (retorno medio de 0.06392857142857143 en los últimos 100 episodios)
# Terminado episodio 474 con retorno 0 en 243 pasos (retorno medio de 0.06392857142857142 en los últimos 100 episodios)
# Terminado episodio 475 con retorno 0 en 243 pasos (retorno medio de 0.06392857142857143 en los últimos 100 episodios)
# Terminado episodio 476 con retorno 0 en 239 pasos (retorno medio de 0.05607142857142858 en los últimos 100 episodios)
# Terminado episodio 477 con retorno 0.23571428571428577 en 202 pasos (retorno medio de 0.04942857142857143 en los últimos 100 episodios)
# Terminado episodio 478 con retorno 0.27142857142857135 en 200 pasos (retorno medio de 0.052142857142857144 en los últimos 100 episodios)
# Terminado episodio 479 con retorno 0.7678571428571428 en 54 pasos (retorno medio de 0.059821428571428574 en los últimos 100 episodios)
# Terminado episodio 480 con retorno 0 en 96 pasos (retorno medio de 0.059821428571428574 en los últimos 100 episodios)
# Terminado episodio 481 con retorno 0.29999999999999993 en 187 pasos (retorno medio de 0.06282142857142857 en los últimos 100 episodios)
# Terminado episodio 482 con retorno 0 en 245 pasos (retorno medio de 0.05325 en los últimos 100 episodios)
# Terminado episodio 483 con retorno 0 en 244 pasos (retorno medio de 0.05325 en los últimos 100 episodios)
# Terminado episodio 484 con retorno 0 en 121 pasos (retorno medio de 0.05324999999999999 en los últimos 100 episodios)
# Terminado episodio 485 con retorno 0 en 248 pasos (retorno medio de 0.05325 en los últimos 100 episodios)
# Terminado episodio 486 con retorno 0 en 249 pasos (retorno medio de 0.05325 en los últimos 100 episodios)
# Terminado episodio 487 con retorno 0 en 247 pasos (retorno medio de 0.05325 en los últimos 100 episodios)
# Terminado episodio 488 con retorno 0 en 245 pasos (retorno medio de 0.04425 en los últimos 100 episodios)
# Terminado episodio 489 con retorno 0 en 240 pasos (retorno medio de 0.03475 en los últimos 100 episodios)
# Terminado episodio 490 con retorno 0 en 239 pasos (retorno medio de 0.03475 en los últimos 100 episodios)
# Terminado episodio 491 con retorno 0 en 39 pasos (retorno medio de 0.03475 en los últimos 100 episodios)
# Terminado episodio 492 con retorno 0 en 32 pasos (retorno medio de 0.03475 en los últimos 100 episodios)
# Terminado episodio 493 con retorno 0 en 29 pasos (retorno medio de 0.02539285714285714 en los últimos 100 episodios)
# Terminado episodio 494 con retorno 0 en 26 pasos (retorno medio de 0.015749999999999997 en los últimos 100 episodios)
# Terminado episodio 495 con retorno 0 en 16 pasos (retorno medio de 0.015749999999999997 en los últimos 100 episodios)
# Terminado episodio 496 con retorno 0 en 56 pasos (retorno medio de 0.015749999999999997 en los últimos 100 episodios)
# Terminado episodio 497 con retorno 0 en 43 pasos (retorno medio de 0.015749999999999997 en los últimos 100 episodios)
# Terminado episodio 498 con retorno 0 en 234 pasos (retorno medio de 0.015749999999999997 en los últimos 100 episodios)
# Terminado episodio 499 con retorno 0 en 129 pasos (retorno medio de 0.015749999999999997 en los últimos 100 episodios)

# %% [markdown]
# El proceso de aprendizaje tiene una componente aleatoria importante, por lo que dos ejecuciones consecutivas pueden aprender valores $Q$ diferentes de las que se deriven políticas $\pi$ también diferentes. No obstante, si has implementado bien el algoritmo, deberías haber observado lo siguiente:
#   1. Inicialmente hay muchos episodios con retorno 0 (el agente acaba en la lava). La duración de estos episodios es muy variable. Además, si imprimiésemos `q_values` tras cada uno de estos episodios, ¡veríamos que $Q$ no se modifica! Cada paso utiliza $R$ y $Q(S',A')$ para actualizar $Q(S,A)$, pero si tanto $R$ como $Q(S',A')$ son cero, el valor de $Q(S,A)$ no cambiará.
#   1. Con el tiempo, y por pura casualidad, el agente terminará algún episodio llegando a la meta. Esto le reportará una recompensa de 1, lo que hará que $Q(S_t,A_t)$ se actualice a un valor positivo.
#   1. La próxima vez que el agente esté en $S_t$, elegirá la acción $A_t$ (salvo que toque acción aleatoria por el $\epsilon$), lo que hará que termine el episodio con recompensa 1. **¡Habrá aprendido una política útil para la última casilla!** Pero, además, el estado $S_{t-1}$ que llevó a $S_t$ (usando la acción $A_{t-1}$) verá su $Q(S_{t-1},A_{t-1})$ actualizado a un valor positivo. **¡Ya sabrá una política útil para las dos últimas casillas!**
#   1. Mediante este proceso, la información respecto a qué política es útil se irá propagando desde las casillas aledañas a la meta a sus vecinas, y de estas a sus vecinas y así sucesivamente hasta cubrir el tablero entero. A esto hay que añadir que, también por pura casualidad, el agente puede encontrar otros caminos que conducen a la meta y lanzar este mismo proceso de propagación pero siguiendo otro camino que conduzca a la meta.
#   1. El efecto de esto es que, a medida que transcurren los episodios ocurren dos cosas:
#     - El número de episodios con retorno positivo aumenta
#     - La duración de los episodios con retorno positivos disminuye (el agente va más tiempo por "camino conocido")
#   1. Esto repercute en el retorno medio de los 100 últimos episodios: comenzará siendo minúsculo, pero llegado un punto subirá con gran velocidad.
#   1. El retorno de los últimos 100 episodios alcanzará un punto máximo en torno al cual oscilará hacia el final.
#
#
# Visualicemos la política aprendida. Vamos a mostrar, para cada casilla, la orientación que tiene el agente cuando la acción preferida (la que tiene mayor valor $Q$) sea `FORWARD`.
#
# >**Recordatorio**
# >
# > Las orientaciones se codifican así:
# > - 0 $\rightarrow$ derecha
# > - 1 $\rightarrow$ abajo
# > - 2 $\rightarrow$ izquierda
# > - 3 $\rightarrow$ arriba

# %%
# Esta función devuelve un carácter de flecha que representa la orientación del agente para la cual los q valores recomiendan la acción forward
def get_flecha_direccion_maximo_valor(q_values:np.ndarray) -> str:
    accion_preferida_por_orientacion = q_values.argmax(axis=1) # Para cada una de las cuatro orientaciones, calculamos qué acción se prefiere
    direccion = np.argmax(accion_preferida_por_orientacion == 2) # De las orientaciones que prefieran FORWARD, tomamos una (la primera)
    # En función de la orientación, devolvemos la flecha apropiada.
    if direccion==0:
        return '⮕'
    if direccion==1:
        return '⬇'
    if direccion==2:
        return '⬅'
    if direccion==3:
        return '⬆'
    return '?'

# Muestra la política por pantalla
def dibuja_politica(q_valores:np.ndarray) -> None:
    # Recorre las filas del tablero...
    for i in range(q_valores.shape[0]):
        # ... componiendo una línea por fila...
        linea = ''
        for j in range(q_valores.shape[1]): # Recorre las columnas
            if i==0 and j==6: # Pintamos la meta
                    linea+='🟥'
            elif (i==0 or i==1)and j>1 and j<5: # Pintamos la lava
                    linea+='🟧'
            else:
                linea+=get_flecha_direccion_maximo_valor(q_valores[i,j]) # Pintamos la flecha apropiada para esta casilla
        # ...que finalmente imprime
        print(linea)

# TODO - Muestra la política que se deriva de los valores aprendidos por SARSA
dibuja_politica(q_valores_sarsa)
# Out:
# ⮕⬇🟧🟧🟧⬇🟥
# ⬇⬇🟧🟧🟧⮕⬇
# ⮕⮕⮕⮕⮕⮕⮕
# ⬇⬆⮕⮕⮕⮕⬇
# ⮕⮕⮕⮕⮕⮕⬇

# %% [markdown]
# Hemos comprobado que nuestro agente tiene que hacer muchos episodios que no le llevan a aprender porque no le dan ninguna recompensa, lo cual provoca que no pueda actualizar $Q(S,A)$ para ninguno de los pares $S,A$ por los que transita.
#
# **¿Qué crees que ocurriría si diésemos una recompensa negativa a caer en la lava? ¿Cambiaría la velocidad a la que aprende el agente?**
#
# Haz la prueba añadiendo esto después de cada paso:
# ```python
#     if completado and reward==0:
#         reward = -1
# ```
#
# Modifica la función `sarsa` y ejecuta la celda siguiente. **¿Qué observas?**

# %%
q_valores_sarsa_con_lava_negativa = sarsa() # Sarsa debe haberse modificado para que caer a la lava proporcione recompensa -1
dibuja_politica(q_valores_sarsa_con_lava_negativa)
# Out:
# Terminado episodio 0 con retorno 0 en 212 pasos
# Terminado episodio 1 con retorno 0 en 158 pasos
# Terminado episodio 2 con retorno 0 en 4 pasos
# Terminado episodio 3 con retorno 0 en 60 pasos
# Terminado episodio 4 con retorno 0 en 244 pasos
# Terminado episodio 5 con retorno 0 en 243 pasos
# Terminado episodio 6 con retorno 0 en 19 pasos
# Terminado episodio 7 con retorno 0 en 243 pasos
# Terminado episodio 8 con retorno 0 en 80 pasos
# Terminado episodio 9 con retorno 0 en 9 pasos
# Terminado episodio 10 con retorno 0.9142857142857143 en 16 pasos
# Terminado episodio 11 con retorno 0 en 51 pasos
# Terminado episodio 12 con retorno 0 en 96 pasos
# Terminado episodio 13 con retorno 0.8142857142857143 en 39 pasos
# Terminado episodio 14 con retorno 0 en 247 pasos
# Terminado episodio 15 con retorno 0 en 243 pasos
# Terminado episodio 16 con retorno 0 en 248 pasos
# Terminado episodio 17 con retorno 0 en 13 pasos
# Terminado episodio 18 con retorno 0 en 38 pasos
# Terminado episodio 19 con retorno 0 en 246 pasos
# Terminado episodio 20 con retorno 0 en 245 pasos
# Terminado episodio 21 con retorno 0.30714285714285705 en 182 pasos
# Terminado episodio 22 con retorno 0.6464285714285714 en 85 pasos
# Terminado episodio 23 con retorno 0.9357142857142857 en 10 pasos
# Terminado episodio 24 con retorno 0 en 3 pasos
# Terminado episodio 25 con retorno 0.6892857142857143 en 78 pasos
# Terminado episodio 26 con retorno 0 en 115 pasos
# Terminado episodio 27 con retorno 0 en 4 pasos
# Terminado episodio 28 con retorno 0.5107142857142857 en 131 pasos
# Terminado episodio 29 con retorno 0 en 246 pasos
# Terminado episodio 30 con retorno 0.9535714285714285 en 3 pasos
# Terminado episodio 31 con retorno 0 en 246 pasos
# Terminado episodio 32 con retorno 0 en 102 pasos
# Terminado episodio 33 con retorno 0 en 186 pasos
# Terminado episodio 34 con retorno 0.9392857142857143 en 5 pasos
# Terminado episodio 35 con retorno 0 en 245 pasos
# Terminado episodio 36 con retorno 0 en 243 pasos
# Terminado episodio 37 con retorno 0 en 242 pasos
# Terminado episodio 38 con retorno 0.6321428571428571 en 96 pasos
# Terminado episodio 39 con retorno 0 en 4 pasos
# Terminado episodio 40 con retorno 0 en 5 pasos
# Terminado episodio 41 con retorno 0 en 247 pasos
# Terminado episodio 42 con retorno 0.95 en 5 pasos
# Terminado episodio 43 con retorno 0 en 179 pasos
# Terminado episodio 44 con retorno 0.925 en 9 pasos
# Terminado episodio 45 con retorno 0.925 en 10 pasos
# Terminado episodio 46 con retorno 0 en 244 pasos
# Terminado episodio 47 con retorno 0.9428571428571428 en 6 pasos
# Terminado episodio 48 con retorno 0 en 244 pasos
# Terminado episodio 49 con retorno 0.9571428571428572 en 6 pasos
# Terminado episodio 50 con retorno 0 en 240 pasos
# Terminado episodio 51 con retorno 0 en 242 pasos
# Terminado episodio 52 con retorno 0 en 244 pasos
# Terminado episodio 53 con retorno 0 en 20 pasos
# Terminado episodio 54 con retorno 0.9464285714285714 en 4 pasos
# Terminado episodio 55 con retorno 0 en 244 pasos
# Terminado episodio 56 con retorno 0.6428571428571428 en 91 pasos
# Terminado episodio 57 con retorno 0 en 56 pasos
# Terminado episodio 58 con retorno 0 en 135 pasos
# Terminado episodio 59 con retorno 0.8928571428571429 en 16 pasos
# Terminado episodio 60 con retorno 0 en 58 pasos
# Terminado episodio 61 con retorno 0 en 246 pasos
# Terminado episodio 62 con retorno 0 en 19 pasos
# Terminado episodio 63 con retorno 0.8821428571428571 en 20 pasos
# Terminado episodio 64 con retorno 0.8964285714285715 en 15 pasos
# Terminado episodio 65 con retorno 0.9571428571428572 en 4 pasos
# Terminado episodio 66 con retorno 0 en 37 pasos
# Terminado episodio 67 con retorno 0 en 243 pasos
# Terminado episodio 68 con retorno 0.8964285714285715 en 16 pasos
# Terminado episodio 69 con retorno 0.9571428571428572 en 4 pasos
# Terminado episodio 70 con retorno 0 en 2 pasos
# Terminado episodio 71 con retorno 0 en 241 pasos
# Terminado episodio 72 con retorno 0 en 246 pasos
# Terminado episodio 73 con retorno 0.7928571428571429 en 50 pasos
# Terminado episodio 74 con retorno 0 en 249 pasos
# Terminado episodio 75 con retorno 0 en 6 pasos
# Terminado episodio 76 con retorno 0 en 6 pasos
# Terminado episodio 77 con retorno 0.8607142857142858 en 26 pasos
# Terminado episodio 78 con retorno 0 en 249 pasos
# Terminado episodio 79 con retorno 0 en 9 pasos
# Terminado episodio 80 con retorno 0 en 5 pasos
# Terminado episodio 81 con retorno 0 en 6 pasos
# Terminado episodio 82 con retorno 0.925 en 9 pasos
# Terminado episodio 83 con retorno 0 en 243 pasos
# Terminado episodio 84 con retorno 0 en 23 pasos
# Terminado episodio 85 con retorno 0 en 54 pasos
# Terminado episodio 86 con retorno 0 en 53 pasos
# Terminado episodio 87 con retorno 0 en 245 pasos
# Terminado episodio 88 con retorno 0 en 247 pasos
# Terminado episodio 89 con retorno 0 en 246 pasos
# Terminado episodio 90 con retorno 0 en 245 pasos
# Terminado episodio 91 con retorno 0.9571428571428572 en 5 pasos
# Terminado episodio 92 con retorno 0 en 244 pasos
# Terminado episodio 93 con retorno 0 en 102 pasos
# Terminado episodio 94 con retorno 0 en 241 pasos
# Terminado episodio 95 con retorno 0 en 244 pasos
# Terminado episodio 96 con retorno 0 en 245 pasos
# Terminado episodio 97 con retorno 0 en 243 pasos
# Terminado episodio 98 con retorno 0 en 241 pasos
# Terminado episodio 99 con retorno 0 en 243 pasos
# Terminado episodio 100 con retorno 0 en 241 pasos (retorno medio de 0.22649999999999998 en los últimos 100 episodios)
# Terminado episodio 101 con retorno 0 en 243 pasos (retorno medio de 0.22649999999999998 en los últimos 100 episodios)
# Terminado episodio 102 con retorno 0 en 241 pasos (retorno medio de 0.22649999999999998 en los últimos 100 episodios)
# Terminado episodio 103 con retorno 0 en 242 pasos (retorno medio de 0.22649999999999998 en los últimos 100 episodios)
# Terminado episodio 104 con retorno 0 en 3 pasos (retorno medio de 0.22649999999999998 en los últimos 100 episodios)
# Terminado episodio 105 con retorno 0 en 241 pasos (retorno medio de 0.22649999999999998 en los últimos 100 episodios)
# Terminado episodio 106 con retorno 0 en 245 pasos (retorno medio de 0.22649999999999998 en los últimos 100 episodios)
# Terminado episodio 107 con retorno 0 en 245 pasos (retorno medio de 0.22649999999999998 en los últimos 100 episodios)
# Terminado episodio 108 con retorno 0 en 244 pasos (retorno medio de 0.22649999999999998 en los últimos 100 episodios)
# Terminado episodio 109 con retorno 0 en 239 pasos (retorno medio de 0.22649999999999998 en los últimos 100 episodios)
# Terminado episodio 110 con retorno 0 en 247 pasos (retorno medio de 0.2173571428571429 en los últimos 100 episodios)
# Terminado episodio 111 con retorno 0 en 243 pasos (retorno medio de 0.2173571428571429 en los últimos 100 episodios)
# Terminado episodio 112 con retorno 0.95 en 4 pasos (retorno medio de 0.22685714285714284 en los últimos 100 episodios)
# Terminado episodio 113 con retorno 0 en 245 pasos (retorno medio de 0.2187142857142857 en los últimos 100 episodios)
# Terminado episodio 114 con retorno 0 en 243 pasos (retorno medio de 0.2187142857142857 en los últimos 100 episodios)
# Terminado episodio 115 con retorno 0 en 8 pasos (retorno medio de 0.2187142857142857 en los últimos 100 episodios)
# Terminado episodio 116 con retorno 0 en 243 pasos (retorno medio de 0.2187142857142857 en los últimos 100 episodios)
# Terminado episodio 117 con retorno 0 en 248 pasos (retorno medio de 0.21871428571428575 en los últimos 100 episodios)
# Terminado episodio 118 con retorno 0 en 244 pasos (retorno medio de 0.2187142857142857 en los últimos 100 episodios)
# Terminado episodio 119 con retorno 0 en 7 pasos (retorno medio de 0.21871428571428575 en los últimos 100 episodios)
# Terminado episodio 120 con retorno 0 en 12 pasos (retorno medio de 0.2187142857142857 en los últimos 100 episodios)
# Terminado episodio 121 con retorno 0 en 243 pasos (retorno medio de 0.21564285714285714 en los últimos 100 episodios)
# Terminado episodio 122 con retorno 0 en 243 pasos (retorno medio de 0.20917857142857144 en los últimos 100 episodios)
# Terminado episodio 123 con retorno 0 en 4 pasos (retorno medio de 0.19982142857142857 en los últimos 100 episodios)
# Terminado episodio 124 con retorno 0 en 240 pasos (retorno medio de 0.19982142857142857 en los últimos 100 episodios)
# Terminado episodio 125 con retorno 0.8607142857142858 en 27 pasos (retorno medio de 0.20153571428571426 en los últimos 100 episodios)
# Terminado episodio 126 con retorno 0 en 52 pasos (retorno medio de 0.20153571428571432 en los últimos 100 episodios)
# Terminado episodio 127 con retorno 0 en 8 pasos (retorno medio de 0.20153571428571432 en los últimos 100 episodios)
# Terminado episodio 128 con retorno 0 en 241 pasos (retorno medio de 0.19642857142857145 en los últimos 100 episodios)
# Terminado episodio 129 con retorno 0 en 244 pasos (retorno medio de 0.19642857142857142 en los últimos 100 episodios)
# Terminado episodio 130 con retorno 0 en 7 pasos (retorno medio de 0.18689285714285714 en los últimos 100 episodios)
# Terminado episodio 131 con retorno 0 en 234 pasos (retorno medio de 0.18689285714285717 en los últimos 100 episodios)
# Terminado episodio 132 con retorno 0 en 54 pasos (retorno medio de 0.18689285714285714 en los últimos 100 episodios)
# Terminado episodio 133 con retorno 0.8428571428571429 en 35 pasos (retorno medio de 0.1953214285714286 en los últimos 100 episodios)
# Terminado episodio 134 con retorno 0 en 245 pasos (retorno medio de 0.18592857142857142 en los últimos 100 episodios)
# Terminado episodio 135 con retorno 0 en 240 pasos (retorno medio de 0.18592857142857142 en los últimos 100 episodios)
# Terminado episodio 136 con retorno 0 en 246 pasos (retorno medio de 0.18592857142857142 en los últimos 100 episodios)
# Terminado episodio 137 con retorno 0 en 242 pasos (retorno medio de 0.18592857142857142 en los últimos 100 episodios)
# Terminado episodio 138 con retorno 0 en 2 pasos (retorno medio de 0.17960714285714285 en los últimos 100 episodios)
# Terminado episodio 139 con retorno 0 en 246 pasos (retorno medio de 0.17960714285714285 en los últimos 100 episodios)
# Terminado episodio 140 con retorno 0 en 92 pasos (retorno medio de 0.17960714285714285 en los últimos 100 episodios)
# Terminado episodio 141 con retorno 0 en 1 pasos (retorno medio de 0.17960714285714285 en los últimos 100 episodios)
# Terminado episodio 142 con retorno 0 en 248 pasos (retorno medio de 0.17010714285714287 en los últimos 100 episodios)
# Terminado episodio 143 con retorno 0 en 245 pasos (retorno medio de 0.17010714285714287 en los últimos 100 episodios)
# Terminado episodio 144 con retorno 0 en 9 pasos (retorno medio de 0.1608571428571428 en los últimos 100 episodios)
# Terminado episodio 145 con retorno 0 en 6 pasos (retorno medio de 0.15160714285714286 en los últimos 100 episodios)
# Terminado episodio 146 con retorno 0 en 52 pasos (retorno medio de 0.15160714285714286 en los últimos 100 episodios)
# Terminado episodio 147 con retorno 0 en 247 pasos (retorno medio de 0.14217857142857143 en los últimos 100 episodios)
# Terminado episodio 148 con retorno 0 en 245 pasos (retorno medio de 0.1421785714285714 en los últimos 100 episodios)
# Terminado episodio 149 con retorno 0 en 245 pasos (retorno medio de 0.13260714285714287 en los últimos 100 episodios)
# Terminado episodio 150 con retorno 0 en 245 pasos (retorno medio de 0.13260714285714287 en los últimos 100 episodios)
# Terminado episodio 151 con retorno 0 en 6 pasos (retorno medio de 0.13260714285714287 en los últimos 100 episodios)
# Terminado episodio 152 con retorno 0 en 4 pasos (retorno medio de 0.13260714285714287 en los últimos 100 episodios)
# Terminado episodio 153 con retorno 0 en 246 pasos (retorno medio de 0.13260714285714287 en los últimos 100 episodios)
# Terminado episodio 154 con retorno 0 en 11 pasos (retorno medio de 0.12314285714285714 en los últimos 100 episodios)
# Terminado episodio 155 con retorno 0.6785714285714286 en 78 pasos (retorno medio de 0.12992857142857145 en los últimos 100 episodios)
# Terminado episodio 156 con retorno 0 en 243 pasos (retorno medio de 0.1235 en los últimos 100 episodios)
# Terminado episodio 157 con retorno 0 en 1 pasos (retorno medio de 0.12350000000000001 en los últimos 100 episodios)
# Terminado episodio 158 con retorno 0 en 8 pasos (retorno medio de 0.1235 en los últimos 100 episodios)
# Terminado episodio 159 con retorno 0 en 248 pasos (retorno medio de 0.11457142857142859 en los últimos 100 episodios)
# Terminado episodio 160 con retorno 0 en 245 pasos (retorno medio de 0.11457142857142857 en los últimos 100 episodios)
# Terminado episodio 161 con retorno 0 en 6 pasos (retorno medio de 0.11457142857142859 en los últimos 100 episodios)
# Terminado episodio 162 con retorno 0 en 36 pasos (retorno medio de 0.11457142857142857 en los últimos 100 episodios)
# Terminado episodio 163 con retorno 0 en 25 pasos (retorno medio de 0.10575000000000001 en los últimos 100 episodios)
# Terminado episodio 164 con retorno 0.6678571428571428 en 80 pasos (retorno medio de 0.10346428571428572 en los últimos 100 episodios)
# Terminado episodio 165 con retorno 0 en 125 pasos (retorno medio de 0.09389285714285714 en los últimos 100 episodios)
# Terminado episodio 166 con retorno 0 en 118 pasos (retorno medio de 0.09389285714285714 en los últimos 100 episodios)
# Terminado episodio 167 con retorno 0 en 2 pasos (retorno medio de 0.09389285714285714 en los últimos 100 episodios)
# Terminado episodio 168 con retorno 0 en 2 pasos (retorno medio de 0.08492857142857144 en los últimos 100 episodios)
# Terminado episodio 169 con retorno 0 en 242 pasos (retorno medio de 0.07535714285714286 en los últimos 100 episodios)
# Terminado episodio 170 con retorno 0 en 245 pasos (retorno medio de 0.07535714285714286 en los últimos 100 episodios)
# Terminado episodio 171 con retorno 0 en 246 pasos (retorno medio de 0.07535714285714286 en los últimos 100 episodios)
# Terminado episodio 172 con retorno 0 en 242 pasos (retorno medio de 0.07535714285714286 en los últimos 100 episodios)
# Terminado episodio 173 con retorno 0 en 242 pasos (retorno medio de 0.06742857142857143 en los últimos 100 episodios)
# Terminado episodio 174 con retorno 0 en 15 pasos (retorno medio de 0.06742857142857143 en los últimos 100 episodios)
# Terminado episodio 175 con retorno 0 en 28 pasos (retorno medio de 0.06742857142857143 en los últimos 100 episodios)
# Terminado episodio 176 con retorno 0 en 244 pasos (retorno medio de 0.06742857142857143 en los últimos 100 episodios)
# Terminado episodio 177 con retorno 0 en 242 pasos (retorno medio de 0.05882142857142857 en los últimos 100 episodios)
# Terminado episodio 178 con retorno 0 en 245 pasos (retorno medio de 0.05882142857142857 en los últimos 100 episodios)
# Terminado episodio 179 con retorno 0 en 243 pasos (retorno medio de 0.05882142857142858 en los últimos 100 episodios)
# Terminado episodio 180 con retorno 0 en 241 pasos (retorno medio de 0.05882142857142857 en los últimos 100 episodios)
# Terminado episodio 181 con retorno 0 en 6 pasos (retorno medio de 0.05882142857142857 en los últimos 100 episodios)
# Terminado episodio 182 con retorno 0 en 248 pasos (retorno medio de 0.04957142857142857 en los últimos 100 episodios)
# Terminado episodio 183 con retorno 0 en 246 pasos (retorno medio de 0.04957142857142857 en los últimos 100 episodios)
# Terminado episodio 184 con retorno 0 en 244 pasos (retorno medio de 0.04957142857142857 en los últimos 100 episodios)
# Terminado episodio 185 con retorno 0 en 240 pasos (retorno medio de 0.04957142857142857 en los últimos 100 episodios)
# Terminado episodio 186 con retorno 0 en 244 pasos (retorno medio de 0.04957142857142857 en los últimos 100 episodios)
# Terminado episodio 187 con retorno 0 en 245 pasos (retorno medio de 0.04957142857142857 en los últimos 100 episodios)
# Terminado episodio 188 con retorno 0 en 249 pasos (retorno medio de 0.04957142857142857 en los últimos 100 episodios)
# Terminado episodio 189 con retorno 0 en 243 pasos (retorno medio de 0.04957142857142857 en los últimos 100 episodios)
# Terminado episodio 190 con retorno 0 en 244 pasos (retorno medio de 0.04957142857142857 en los últimos 100 episodios)
# Terminado episodio 191 con retorno 0 en 4 pasos (retorno medio de 0.04 en los últimos 100 episodios)
# Terminado episodio 192 con retorno 0 en 247 pasos (retorno medio de 0.04 en los últimos 100 episodios)
# Terminado episodio 193 con retorno 0 en 247 pasos (retorno medio de 0.04 en los últimos 100 episodios)
# Terminado episodio 194 con retorno 0 en 241 pasos (retorno medio de 0.04 en los últimos 100 episodios)
# Terminado episodio 195 con retorno 0 en 8 pasos (retorno medio de 0.04 en los últimos 100 episodios)
# Terminado episodio 196 con retorno 0 en 241 pasos (retorno medio de 0.04 en los últimos 100 episodios)
# Terminado episodio 197 con retorno 0 en 241 pasos (retorno medio de 0.04 en los últimos 100 episodios)
# Terminado episodio 198 con retorno 0 en 245 pasos (retorno medio de 0.04 en los últimos 100 episodios)
# Terminado episodio 199 con retorno 0 en 242 pasos (retorno medio de 0.04 en los últimos 100 episodios)
# Terminado episodio 200 con retorno 0 en 244 pasos (retorno medio de 0.04 en los últimos 100 episodios)
# Terminado episodio 201 con retorno 0 en 246 pasos (retorno medio de 0.04 en los últimos 100 episodios)
# Terminado episodio 202 con retorno 0 en 246 pasos (retorno medio de 0.04 en los últimos 100 episodios)
# Terminado episodio 203 con retorno 0 en 243 pasos (retorno medio de 0.04 en los últimos 100 episodios)
# Terminado episodio 204 con retorno 0 en 248 pasos (retorno medio de 0.04 en los últimos 100 episodios)
# Terminado episodio 205 con retorno 0 en 242 pasos (retorno medio de 0.04 en los últimos 100 episodios)
# Terminado episodio 206 con retorno 0 en 239 pasos (retorno medio de 0.04 en los últimos 100 episodios)
# Terminado episodio 207 con retorno 0 en 239 pasos (retorno medio de 0.04 en los últimos 100 episodios)
# Terminado episodio 208 con retorno 0 en 239 pasos (retorno medio de 0.04 en los últimos 100 episodios)
# Terminado episodio 209 con retorno 0 en 239 pasos (retorno medio de 0.04 en los últimos 100 episodios)
# Terminado episodio 210 con retorno 0 en 241 pasos (retorno medio de 0.04 en los últimos 100 episodios)
# Terminado episodio 211 con retorno 0 en 244 pasos (retorno medio de 0.04 en los últimos 100 episodios)
# Terminado episodio 212 con retorno 0 en 2 pasos (retorno medio de 0.030500000000000003 en los últimos 100 episodios)
# Terminado episodio 213 con retorno 0 en 3 pasos (retorno medio de 0.0305 en los últimos 100 episodios)
# Terminado episodio 214 con retorno 0 en 245 pasos (retorno medio de 0.030500000000000003 en los últimos 100 episodios)
# Terminado episodio 215 con retorno 0 en 247 pasos (retorno medio de 0.0305 en los últimos 100 episodios)
# Terminado episodio 216 con retorno 0 en 241 pasos (retorno medio de 0.030500000000000003 en los últimos 100 episodios)
# Terminado episodio 217 con retorno 0 en 242 pasos (retorno medio de 0.0305 en los últimos 100 episodios)
# Terminado episodio 218 con retorno 0 en 249 pasos (retorno medio de 0.030500000000000003 en los últimos 100 episodios)
# Terminado episodio 219 con retorno 0 en 240 pasos (retorno medio de 0.0305 en los últimos 100 episodios)
# Terminado episodio 220 con retorno 0 en 239 pasos (retorno medio de 0.030500000000000003 en los últimos 100 episodios)
# Terminado episodio 221 con retorno 0 en 247 pasos (retorno medio de 0.0305 en los últimos 100 episodios)
# Terminado episodio 222 con retorno 0 en 246 pasos (retorno medio de 0.030500000000000003 en los últimos 100 episodios)
# Terminado episodio 223 con retorno 0 en 244 pasos (retorno medio de 0.0305 en los últimos 100 episodios)
# Terminado episodio 224 con retorno 0 en 245 pasos (retorno medio de 0.030500000000000003 en los últimos 100 episodios)
# Terminado episodio 225 con retorno 0 en 246 pasos (retorno medio de 0.02189285714285714 en los últimos 100 episodios)
# Terminado episodio 226 con retorno 0 en 247 pasos (retorno medio de 0.021892857142857144 en los últimos 100 episodios)
# Terminado episodio 227 con retorno 0 en 244 pasos (retorno medio de 0.02189285714285714 en los últimos 100 episodios)
# Terminado episodio 228 con retorno 0 en 246 pasos (retorno medio de 0.021892857142857144 en los últimos 100 episodios)
# Terminado episodio 229 con retorno 0 en 247 pasos (retorno medio de 0.02189285714285714 en los últimos 100 episodios)
# Terminado episodio 230 con retorno 0 en 246 pasos (retorno medio de 0.021892857142857144 en los últimos 100 episodios)
# Terminado episodio 231 con retorno 0 en 242 pasos (retorno medio de 0.02189285714285714 en los últimos 100 episodios)
# Terminado episodio 232 con retorno 0 en 239 pasos (retorno medio de 0.021892857142857144 en los últimos 100 episodios)
# Terminado episodio 233 con retorno 0 en 247 pasos (retorno medio de 0.013464285714285715 en los últimos 100 episodios)
# Terminado episodio 234 con retorno 0 en 6 pasos (retorno medio de 0.013464285714285715 en los últimos 100 episodios)
# Terminado episodio 235 con retorno 0 en 1 pasos (retorno medio de 0.013464285714285715 en los últimos 100 episodios)
# Terminado episodio 236 con retorno 0 en 242 pasos (retorno medio de 0.013464285714285715 en los últimos 100 episodios)
# Terminado episodio 237 con retorno 0 en 242 pasos (retorno medio de 0.013464285714285715 en los últimos 100 episodios)
# Terminado episodio 238 con retorno 0 en 241 pasos (retorno medio de 0.013464285714285715 en los últimos 100 episodios)
# Terminado episodio 239 con retorno 0 en 241 pasos (retorno medio de 0.013464285714285715 en los últimos 100 episodios)
# Terminado episodio 240 con retorno 0 en 242 pasos (retorno medio de 0.013464285714285715 en los últimos 100 episodios)
# Terminado episodio 241 con retorno 0 en 242 pasos (retorno medio de 0.013464285714285715 en los últimos 100 episodios)
# Terminado episodio 242 con retorno 0 en 239 pasos (retorno medio de 0.013464285714285715 en los últimos 100 episodios)
# Terminado episodio 243 con retorno 0 en 247 pasos (retorno medio de 0.013464285714285715 en los últimos 100 episodios)
# Terminado episodio 244 con retorno 0 en 238 pasos (retorno medio de 0.013464285714285715 en los últimos 100 episodios)
# Terminado episodio 245 con retorno 0 en 249 pasos (retorno medio de 0.013464285714285715 en los últimos 100 episodios)
# Terminado episodio 246 con retorno 0 en 246 pasos (retorno medio de 0.013464285714285715 en los últimos 100 episodios)
# Terminado episodio 247 con retorno 0 en 247 pasos (retorno medio de 0.013464285714285715 en los últimos 100 episodios)
# Terminado episodio 248 con retorno 0 en 241 pasos (retorno medio de 0.013464285714285715 en los últimos 100 episodios)
# Terminado episodio 249 con retorno 0 en 241 pasos (retorno medio de 0.013464285714285715 en los últimos 100 episodios)
# Terminado episodio 250 con retorno 0 en 240 pasos (retorno medio de 0.013464285714285715 en los últimos 100 episodios)
# Terminado episodio 251 con retorno 0 en 242 pasos (retorno medio de 0.013464285714285715 en los últimos 100 episodios)
# Terminado episodio 252 con retorno 0 en 241 pasos (retorno medio de 0.013464285714285715 en los últimos 100 episodios)
# Terminado episodio 253 con retorno 0 en 242 pasos (retorno medio de 0.013464285714285715 en los últimos 100 episodios)
# Terminado episodio 254 con retorno 0 en 246 pasos (retorno medio de 0.013464285714285715 en los últimos 100 episodios)
# <ipython-input-33-0306e76b5589>:37: RuntimeWarning: overflow encountered in scalar add
#   q_valores[estado.x, estado.y, estado.dir, accion] += ALPHA * (reward + GAMMA * q_valores[estado_siguiente.x, estado_siguiente.y, estado_siguiente.dir, accion_siguiente])
# Terminado episodio 255 con retorno 0 en 239 pasos (retorno medio de 0.006678571428571428 en los últimos 100 episodios)
# Terminado episodio 256 con retorno 0 en 239 pasos (retorno medio de 0.006678571428571428 en los últimos 100 episodios)
# Terminado episodio 257 con retorno 0 en 240 pasos (retorno medio de 0.006678571428571428 en los últimos 100 episodios)
# Terminado episodio 258 con retorno 0 en 247 pasos (retorno medio de 0.006678571428571428 en los últimos 100 episodios)
# Terminado episodio 259 con retorno 0 en 242 pasos (retorno medio de 0.006678571428571428 en los últimos 100 episodios)
# Terminado episodio 260 con retorno 0 en 239 pasos (retorno medio de 0.006678571428571428 en los últimos 100 episodios)
# Terminado episodio 261 con retorno 0 en 2 pasos (retorno medio de 0.006678571428571428 en los últimos 100 episodios)
# Terminado episodio 262 con retorno 0 en 213 pasos (retorno medio de 0.006678571428571428 en los últimos 100 episodios)
# Terminado episodio 263 con retorno 0 en 238 pasos (retorno medio de 0.006678571428571428 en los últimos 100 episodios)
# Terminado episodio 264 con retorno 0 en 244 pasos (retorno medio de 0.0 en los últimos 100 episodios)
# Terminado episodio 265 con retorno 0 en 3 pasos (retorno medio de 0.0 en los últimos 100 episodios)
# Terminado episodio 266 con retorno 0 en 245 pasos (retorno medio de 0.0 en los últimos 100 episodios)
# Terminado episodio 267 con retorno 0.9714285714285714 en 1 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 268 con retorno 0 en 1 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 269 con retorno 0 en 244 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 270 con retorno 0 en 246 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 271 con retorno 0 en 239 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 272 con retorno 0 en 242 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 273 con retorno 0 en 245 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 274 con retorno 0 en 244 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 275 con retorno 0 en 246 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 276 con retorno 0 en 20 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 277 con retorno 0 en 2 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 278 con retorno 0 en 241 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 279 con retorno 0 en 245 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 280 con retorno 0 en 1 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 281 con retorno 0 en 238 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 282 con retorno 0 en 218 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 283 con retorno 0 en 126 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 284 con retorno 0 en 28 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 285 con retorno 0 en 242 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 286 con retorno 0 en 245 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 287 con retorno 0 en 241 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 288 con retorno 0 en 15 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 289 con retorno 0 en 247 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 290 con retorno 0 en 244 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 291 con retorno 0 en 241 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 292 con retorno 0 en 189 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 293 con retorno 0 en 247 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 294 con retorno 0 en 63 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 295 con retorno 0 en 243 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 296 con retorno 0 en 78 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 297 con retorno 0 en 246 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 298 con retorno 0 en 9 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 299 con retorno 0 en 244 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 300 con retorno 0 en 10 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 301 con retorno 0 en 149 pasos (retorno medio de 0.009714285714285713 en los últimos 100 episodios)
# Terminado episodio 302 con retorno 0.5464285714285715 en 113 pasos (retorno medio de 0.015178571428571428 en los últimos 100 episodios)
# Terminado episodio 303 con retorno 0 en 244 pasos (retorno medio de 0.015178571428571428 en los últimos 100 episodios)
# Terminado episodio 304 con retorno 0.9571428571428572 en 3 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 305 con retorno 0 en 129 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 306 con retorno 0 en 108 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 307 con retorno 0 en 3 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 308 con retorno 0 en 205 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 309 con retorno 0 en 241 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 310 con retorno 0 en 42 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 311 con retorno 0 en 242 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 312 con retorno 0 en 243 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 313 con retorno 0 en 118 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 314 con retorno 0 en 2 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 315 con retorno 0 en 76 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 316 con retorno 0 en 5 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 317 con retorno 0 en 241 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 318 con retorno 0 en 99 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 319 con retorno 0 en 242 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 320 con retorno 0 en 104 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 321 con retorno 0 en 24 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 322 con retorno 0 en 18 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 323 con retorno 0 en 246 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 324 con retorno 0 en 39 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 325 con retorno 0 en 103 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 326 con retorno 0 en 34 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 327 con retorno 0 en 108 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 328 con retorno 0 en 84 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 329 con retorno 0 en 42 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 330 con retorno 0 en 177 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 331 con retorno 0 en 246 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 332 con retorno 0 en 27 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 333 con retorno 0 en 157 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 334 con retorno 0 en 128 pasos (retorno medio de 0.02475 en los últimos 100 episodios)
# Terminado episodio 335 con retorno 0.39642857142857146 en 161 pasos (retorno medio de 0.028714285714285713 en los últimos 100 episodios)
# Terminado episodio 336 con retorno 0 en 245 pasos (retorno medio de 0.028714285714285713 en los últimos 100 episodios)
# Terminado episodio 337 con retorno 0 en 244 pasos (retorno medio de 0.028714285714285713 en los últimos 100 episodios)
# Terminado episodio 338 con retorno 0 en 241 pasos (retorno medio de 0.028714285714285713 en los últimos 100 episodios)
# Terminado episodio 339 con retorno 0 en 163 pasos (retorno medio de 0.028714285714285713 en los últimos 100 episodios)
# Terminado episodio 340 con retorno 0 en 74 pasos (retorno medio de 0.028714285714285713 en los últimos 100 episodios)
# Terminado episodio 341 con retorno 0.3321428571428571 en 175 pasos (retorno medio de 0.032035714285714285 en los últimos 100 episodios)
# Terminado episodio 342 con retorno 0 en 52 pasos (retorno medio de 0.032035714285714285 en los últimos 100 episodios)
# Terminado episodio 343 con retorno 0 en 39 pasos (retorno medio de 0.032035714285714285 en los últimos 100 episodios)
# Terminado episodio 344 con retorno 0.8214285714285714 en 41 pasos (retorno medio de 0.040249999999999994 en los últimos 100 episodios)
# Terminado episodio 345 con retorno 0 en 14 pasos (retorno medio de 0.040249999999999994 en los últimos 100 episodios)
# Terminado episodio 346 con retorno 0 en 245 pasos (retorno medio de 0.04025 en los últimos 100 episodios)
# Terminado episodio 347 con retorno 0 en 13 pasos (retorno medio de 0.040249999999999994 en los últimos 100 episodios)
# Terminado episodio 348 con retorno 0 en 13 pasos (retorno medio de 0.040249999999999994 en los últimos 100 episodios)
# Terminado episodio 349 con retorno 0 en 53 pasos (retorno medio de 0.04025 en los últimos 100 episodios)
# Terminado episodio 350 con retorno 0 en 216 pasos (retorno medio de 0.04025 en los últimos 100 episodios)
# Terminado episodio 351 con retorno 0 en 243 pasos (retorno medio de 0.04025 en los últimos 100 episodios)
# Terminado episodio 352 con retorno 0 en 191 pasos (retorno medio de 0.040249999999999994 en los últimos 100 episodios)
# Terminado episodio 353 con retorno 0.9214285714285715 en 13 pasos (retorno medio de 0.04946428571428572 en los últimos 100 episodios)
# Terminado episodio 354 con retorno 0 en 32 pasos (retorno medio de 0.04946428571428572 en los últimos 100 episodios)
# Terminado episodio 355 con retorno 0 en 243 pasos (retorno medio de 0.04946428571428572 en los últimos 100 episodios)
# Terminado episodio 356 con retorno 0 en 250 pasos (retorno medio de 0.04946428571428571 en los últimos 100 episodios)
# Terminado episodio 357 con retorno 0 en 248 pasos (retorno medio de 0.04946428571428571 en los últimos 100 episodios)
# Terminado episodio 358 con retorno 0 en 245 pasos (retorno medio de 0.04946428571428571 en los últimos 100 episodios)
# Terminado episodio 359 con retorno 0 en 240 pasos (retorno medio de 0.04946428571428571 en los últimos 100 episodios)
# Terminado episodio 360 con retorno 0 en 48 pasos (retorno medio de 0.04946428571428571 en los últimos 100 episodios)
# Terminado episodio 361 con retorno 0 en 140 pasos (retorno medio de 0.04946428571428571 en los últimos 100 episodios)
# Terminado episodio 362 con retorno 0 en 18 pasos (retorno medio de 0.04946428571428571 en los últimos 100 episodios)
# Terminado episodio 363 con retorno 0 en 64 pasos (retorno medio de 0.04946428571428571 en los últimos 100 episodios)
# Terminado episodio 364 con retorno 0 en 27 pasos (retorno medio de 0.04946428571428571 en los últimos 100 episodios)
# Terminado episodio 365 con retorno 0 en 11 pasos (retorno medio de 0.04946428571428571 en los últimos 100 episodios)
# Terminado episodio 366 con retorno 0 en 146 pasos (retorno medio de 0.04946428571428571 en los últimos 100 episodios)
# Terminado episodio 367 con retorno 0 en 28 pasos (retorno medio de 0.03975 en los últimos 100 episodios)
# Terminado episodio 368 con retorno 0.24642857142857144 en 199 pasos (retorno medio de 0.04221428571428572 en los últimos 100 episodios)
# Terminado episodio 369 con retorno 0 en 1 pasos (retorno medio de 0.04221428571428572 en los últimos 100 episodios)
# Terminado episodio 370 con retorno 0 en 123 pasos (retorno medio de 0.04221428571428572 en los últimos 100 episodios)
# Terminado episodio 371 con retorno 0 en 198 pasos (retorno medio de 0.04221428571428572 en los últimos 100 episodios)
# Terminado episodio 372 con retorno 0 en 245 pasos (retorno medio de 0.04221428571428572 en los últimos 100 episodios)
# Terminado episodio 373 con retorno 0 en 4 pasos (retorno medio de 0.04221428571428572 en los últimos 100 episodios)
# Terminado episodio 374 con retorno 0 en 249 pasos (retorno medio de 0.04221428571428572 en los últimos 100 episodios)
# Terminado episodio 375 con retorno 0 en 245 pasos (retorno medio de 0.04221428571428572 en los últimos 100 episodios)
# Terminado episodio 376 con retorno 0 en 243 pasos (retorno medio de 0.04221428571428572 en los últimos 100 episodios)
# Terminado episodio 377 con retorno 0 en 113 pasos (retorno medio de 0.04221428571428572 en los últimos 100 episodios)
# Terminado episodio 378 con retorno 0 en 104 pasos (retorno medio de 0.04221428571428572 en los últimos 100 episodios)
# Terminado episodio 379 con retorno 0 en 247 pasos (retorno medio de 0.04221428571428572 en los últimos 100 episodios)
# Terminado episodio 380 con retorno 0 en 22 pasos (retorno medio de 0.04221428571428572 en los últimos 100 episodios)
# Terminado episodio 381 con retorno 0 en 30 pasos (retorno medio de 0.04221428571428572 en los últimos 100 episodios)
# Terminado episodio 382 con retorno 0 en 242 pasos (retorno medio de 0.04221428571428572 en los últimos 100 episodios)
# Terminado episodio 383 con retorno 0 en 103 pasos (retorno medio de 0.04221428571428572 en los últimos 100 episodios)
# Terminado episodio 384 con retorno 0 en 2 pasos (retorno medio de 0.04221428571428572 en los últimos 100 episodios)
# Terminado episodio 385 con retorno 0 en 203 pasos (retorno medio de 0.04221428571428572 en los últimos 100 episodios)
# Terminado episodio 386 con retorno 0 en 79 pasos (retorno medio de 0.04221428571428572 en los últimos 100 episodios)
# Terminado episodio 387 con retorno 0 en 220 pasos (retorno medio de 0.04221428571428572 en los últimos 100 episodios)
# Terminado episodio 388 con retorno 0 en 241 pasos (retorno medio de 0.04221428571428572 en los últimos 100 episodios)
# Terminado episodio 389 con retorno 0 en 2 pasos (retorno medio de 0.04221428571428572 en los últimos 100 episodios)
# Terminado episodio 390 con retorno 0.925 en 10 pasos (retorno medio de 0.05146428571428571 en los últimos 100 episodios)
# Terminado episodio 391 con retorno 0 en 27 pasos (retorno medio de 0.05146428571428571 en los últimos 100 episodios)
# Terminado episodio 392 con retorno 0 en 248 pasos (retorno medio de 0.05146428571428571 en los últimos 100 episodios)
# Terminado episodio 393 con retorno 0 en 18 pasos (retorno medio de 0.05146428571428571 en los últimos 100 episodios)
# Terminado episodio 394 con retorno 0 en 66 pasos (retorno medio de 0.05146428571428571 en los últimos 100 episodios)
# Terminado episodio 395 con retorno 0 en 142 pasos (retorno medio de 0.05146428571428571 en los últimos 100 episodios)
# Terminado episodio 396 con retorno 0 en 225 pasos (retorno medio de 0.05146428571428571 en los últimos 100 episodios)
# Terminado episodio 397 con retorno 0 en 246 pasos (retorno medio de 0.05146428571428571 en los últimos 100 episodios)
# Terminado episodio 398 con retorno 0 en 244 pasos (retorno medio de 0.05146428571428571 en los últimos 100 episodios)
# Terminado episodio 399 con retorno 0.775 en 55 pasos (retorno medio de 0.05921428571428572 en los últimos 100 episodios)
# Terminado episodio 400 con retorno 0 en 114 pasos (retorno medio de 0.05921428571428572 en los últimos 100 episodios)
# Terminado episodio 401 con retorno 0 en 115 pasos (retorno medio de 0.05921428571428572 en los últimos 100 episodios)
# Terminado episodio 402 con retorno 0.5857142857142857 en 101 pasos (retorno medio de 0.05960714285714285 en los últimos 100 episodios)
# Terminado episodio 403 con retorno 0 en 2 pasos (retorno medio de 0.05960714285714285 en los últimos 100 episodios)
# Terminado episodio 404 con retorno 0 en 247 pasos (retorno medio de 0.05003571428571428 en los últimos 100 episodios)
# Terminado episodio 405 con retorno 0 en 26 pasos (retorno medio de 0.05003571428571428 en los últimos 100 episodios)
# Terminado episodio 406 con retorno 0 en 6 pasos (retorno medio de 0.05003571428571428 en los últimos 100 episodios)
# Terminado episodio 407 con retorno 0 en 3 pasos (retorno medio de 0.05003571428571429 en los últimos 100 episodios)
# Terminado episodio 408 con retorno 0 en 184 pasos (retorno medio de 0.05003571428571428 en los últimos 100 episodios)
# Terminado episodio 409 con retorno 0 en 5 pasos (retorno medio de 0.05003571428571428 en los últimos 100 episodios)
# Terminado episodio 410 con retorno 0 en 194 pasos (retorno medio de 0.05003571428571428 en los últimos 100 episodios)
# Terminado episodio 411 con retorno 0 en 28 pasos (retorno medio de 0.05003571428571429 en los últimos 100 episodios)
# Terminado episodio 412 con retorno 0 en 188 pasos (retorno medio de 0.05003571428571428 en los últimos 100 episodios)
# Terminado episodio 413 con retorno 0 en 14 pasos (retorno medio de 0.05003571428571428 en los últimos 100 episodios)
# Terminado episodio 414 con retorno 0 en 242 pasos (retorno medio de 0.05003571428571428 en los últimos 100 episodios)
# Terminado episodio 415 con retorno 0 en 234 pasos (retorno medio de 0.05003571428571429 en los últimos 100 episodios)
# Terminado episodio 416 con retorno 0 en 12 pasos (retorno medio de 0.05003571428571428 en los últimos 100 episodios)
# Terminado episodio 417 con retorno 0 en 246 pasos (retorno medio de 0.05003571428571428 en los últimos 100 episodios)
# Terminado episodio 418 con retorno 0.5892857142857143 en 104 pasos (retorno medio de 0.055928571428571425 en los últimos 100 episodios)
# Terminado episodio 419 con retorno 0 en 240 pasos (retorno medio de 0.05592857142857143 en los últimos 100 episodios)
# Terminado episodio 420 con retorno 0 en 123 pasos (retorno medio de 0.055928571428571425 en los últimos 100 episodios)
# Terminado episodio 421 con retorno 0 en 241 pasos (retorno medio de 0.055928571428571425 en los últimos 100 episodios)
# Terminado episodio 422 con retorno 0 en 244 pasos (retorno medio de 0.055928571428571425 en los últimos 100 episodios)
# Terminado episodio 423 con retorno 0 en 241 pasos (retorno medio de 0.05592857142857143 en los últimos 100 episodios)
# Terminado episodio 424 con retorno 0 en 4 pasos (retorno medio de 0.05592857142857143 en los últimos 100 episodios)
# Terminado episodio 425 con retorno 0 en 68 pasos (retorno medio de 0.055928571428571425 en los últimos 100 episodios)
# Terminado episodio 426 con retorno 0 en 246 pasos (retorno medio de 0.055928571428571425 en los últimos 100 episodios)
# Terminado episodio 427 con retorno 0 en 15 pasos (retorno medio de 0.05592857142857143 en los últimos 100 episodios)
# Terminado episodio 428 con retorno 0 en 108 pasos (retorno medio de 0.05592857142857143 en los últimos 100 episodios)
# Terminado episodio 429 con retorno 0 en 241 pasos (retorno medio de 0.055928571428571425 en los últimos 100 episodios)
# Terminado episodio 430 con retorno 0 en 205 pasos (retorno medio de 0.055928571428571425 en los últimos 100 episodios)
# Terminado episodio 431 con retorno 0 en 70 pasos (retorno medio de 0.05592857142857143 en los últimos 100 episodios)
# Terminado episodio 432 con retorno 0 en 13 pasos (retorno medio de 0.05592857142857143 en los últimos 100 episodios)
# Terminado episodio 433 con retorno 0.8964285714285715 en 22 pasos (retorno medio de 0.06489285714285714 en los últimos 100 episodios)
# Terminado episodio 434 con retorno 0 en 239 pasos (retorno medio de 0.06489285714285714 en los últimos 100 episodios)
# Terminado episodio 435 con retorno 0 en 227 pasos (retorno medio de 0.060928571428571436 en los últimos 100 episodios)
# Terminado episodio 436 con retorno 0 en 120 pasos (retorno medio de 0.06092857142857142 en los últimos 100 episodios)
# Terminado episodio 437 con retorno 0 en 141 pasos (retorno medio de 0.060928571428571436 en los últimos 100 episodios)
# Terminado episodio 438 con retorno 0 en 10 pasos (retorno medio de 0.06092857142857142 en los últimos 100 episodios)
# Terminado episodio 439 con retorno 0 en 242 pasos (retorno medio de 0.060928571428571436 en los últimos 100 episodios)
# Terminado episodio 440 con retorno 0.8857142857142857 en 21 pasos (retorno medio de 0.0697857142857143 en los últimos 100 episodios)
# Terminado episodio 441 con retorno 0 en 179 pasos (retorno medio de 0.06646428571428573 en los últimos 100 episodios)
# Terminado episodio 442 con retorno 0 en 56 pasos (retorno medio de 0.0664642857142857 en los últimos 100 episodios)
# Terminado episodio 443 con retorno 0 en 229 pasos (retorno medio de 0.06646428571428573 en los últimos 100 episodios)
# Terminado episodio 444 con retorno 0 en 56 pasos (retorno medio de 0.05825 en los últimos 100 episodios)
# Terminado episodio 445 con retorno 0 en 31 pasos (retorno medio de 0.05825 en los últimos 100 episodios)
# Terminado episodio 446 con retorno 0.40714285714285714 en 153 pasos (retorno medio de 0.062321428571428576 en los últimos 100 episodios)
# Terminado episodio 447 con retorno 0 en 242 pasos (retorno medio de 0.062321428571428576 en los últimos 100 episodios)
# Terminado episodio 448 con retorno 0 en 42 pasos (retorno medio de 0.062321428571428576 en los últimos 100 episodios)
# Terminado episodio 449 con retorno 0 en 45 pasos (retorno medio de 0.062321428571428576 en los últimos 100 episodios)
# Terminado episodio 450 con retorno 0 en 2 pasos (retorno medio de 0.062321428571428576 en los últimos 100 episodios)
# Terminado episodio 451 con retorno 0 en 240 pasos (retorno medio de 0.062321428571428576 en los últimos 100 episodios)
# Terminado episodio 452 con retorno 0 en 247 pasos (retorno medio de 0.062321428571428576 en los últimos 100 episodios)
# Terminado episodio 453 con retorno 0 en 93 pasos (retorno medio de 0.05310714285714286 en los últimos 100 episodios)
# Terminado episodio 454 con retorno 0 en 162 pasos (retorno medio de 0.05310714285714286 en los últimos 100 episodios)
# Terminado episodio 455 con retorno 0 en 240 pasos (retorno medio de 0.05310714285714285 en los últimos 100 episodios)
# Terminado episodio 456 con retorno 0 en 35 pasos (retorno medio de 0.05310714285714286 en los últimos 100 episodios)
# Terminado episodio 457 con retorno 0 en 1 pasos (retorno medio de 0.05310714285714286 en los últimos 100 episodios)
# Terminado episodio 458 con retorno 0 en 34 pasos (retorno medio de 0.05310714285714286 en los últimos 100 episodios)
# Terminado episodio 459 con retorno 0 en 14 pasos (retorno medio de 0.05310714285714285 en los últimos 100 episodios)
# Terminado episodio 460 con retorno 0.7392857142857143 en 65 pasos (retorno medio de 0.060500000000000005 en los últimos 100 episodios)
# Terminado episodio 461 con retorno 0 en 3 pasos (retorno medio de 0.060500000000000005 en los últimos 100 episodios)
# Terminado episodio 462 con retorno 0 en 245 pasos (retorno medio de 0.060500000000000005 en los últimos 100 episodios)
# Terminado episodio 463 con retorno 0 en 46 pasos (retorno medio de 0.06049999999999999 en los últimos 100 episodios)
# Terminado episodio 464 con retorno 0 en 200 pasos (retorno medio de 0.060500000000000005 en los últimos 100 episodios)
# Terminado episodio 465 con retorno 0 en 8 pasos (retorno medio de 0.060500000000000005 en los últimos 100 episodios)
# Terminado episodio 466 con retorno 0 en 244 pasos (retorno medio de 0.060500000000000005 en los últimos 100 episodios)
# Terminado episodio 467 con retorno 0 en 247 pasos (retorno medio de 0.0605 en los últimos 100 episodios)
# Terminado episodio 468 con retorno 0 en 245 pasos (retorno medio de 0.05803571428571429 en los últimos 100 episodios)
# Terminado episodio 469 con retorno 0 en 2 pasos (retorno medio de 0.05803571428571429 en los últimos 100 episodios)
# Terminado episodio 470 con retorno 0 en 10 pasos (retorno medio de 0.05803571428571429 en los últimos 100 episodios)
# Terminado episodio 471 con retorno 0 en 245 pasos (retorno medio de 0.05803571428571429 en los últimos 100 episodios)
# Terminado episodio 472 con retorno 0 en 151 pasos (retorno medio de 0.05803571428571429 en los últimos 100 episodios)
# Terminado episodio 473 con retorno 0 en 130 pasos (retorno medio de 0.05803571428571429 en los últimos 100 episodios)
# Terminado episodio 474 con retorno 0 en 171 pasos (retorno medio de 0.05803571428571429 en los últimos 100 episodios)
# Terminado episodio 475 con retorno 0 en 76 pasos (retorno medio de 0.05803571428571429 en los últimos 100 episodios)
# Terminado episodio 476 con retorno 0 en 239 pasos (retorno medio de 0.05803571428571429 en los últimos 100 episodios)
# Terminado episodio 477 con retorno 0 en 243 pasos (retorno medio de 0.05803571428571429 en los últimos 100 episodios)
# Terminado episodio 478 con retorno 0 en 10 pasos (retorno medio de 0.05803571428571429 en los últimos 100 episodios)
# Terminado episodio 479 con retorno 0 en 243 pasos (retorno medio de 0.05803571428571429 en los últimos 100 episodios)
# Terminado episodio 480 con retorno 0 en 57 pasos (retorno medio de 0.05803571428571429 en los últimos 100 episodios)
# Terminado episodio 481 con retorno 0 en 196 pasos (retorno medio de 0.05803571428571429 en los últimos 100 episodios)
# Terminado episodio 482 con retorno 0 en 215 pasos (retorno medio de 0.05803571428571429 en los últimos 100 episodios)
# Terminado episodio 483 con retorno 0 en 244 pasos (retorno medio de 0.05803571428571429 en los últimos 100 episodios)
# Terminado episodio 484 con retorno 0 en 243 pasos (retorno medio de 0.05803571428571429 en los últimos 100 episodios)
# Terminado episodio 485 con retorno 0 en 235 pasos (retorno medio de 0.05803571428571429 en los últimos 100 episodios)
# Terminado episodio 486 con retorno 0 en 237 pasos (retorno medio de 0.05803571428571429 en los últimos 100 episodios)
# Terminado episodio 487 con retorno 0 en 240 pasos (retorno medio de 0.05803571428571429 en los últimos 100 episodios)
# Terminado episodio 488 con retorno 0 en 102 pasos (retorno medio de 0.05803571428571429 en los últimos 100 episodios)
# Terminado episodio 489 con retorno 0 en 10 pasos (retorno medio de 0.05803571428571429 en los últimos 100 episodios)
# Terminado episodio 490 con retorno 0 en 233 pasos (retorno medio de 0.04878571428571428 en los últimos 100 episodios)
# Terminado episodio 491 con retorno 0 en 140 pasos (retorno medio de 0.04878571428571429 en los últimos 100 episodios)
# Terminado episodio 492 con retorno 0 en 38 pasos (retorno medio de 0.04878571428571428 en los últimos 100 episodios)
# Terminado episodio 493 con retorno 0 en 157 pasos (retorno medio de 0.04878571428571429 en los últimos 100 episodios)
# Terminado episodio 494 con retorno 0 en 243 pasos (retorno medio de 0.04878571428571428 en los últimos 100 episodios)
# Terminado episodio 495 con retorno 0 en 18 pasos (retorno medio de 0.04878571428571429 en los últimos 100 episodios)
# Terminado episodio 496 con retorno 0.44285714285714284 en 145 pasos (retorno medio de 0.053214285714285714 en los últimos 100 episodios)
# Terminado episodio 497 con retorno 0 en 245 pasos (retorno medio de 0.05321428571428572 en los últimos 100 episodios)
# Terminado episodio 498 con retorno 0 en 12 pasos (retorno medio de 0.053214285714285714 en los últimos 100 episodios)
# Terminado episodio 499 con retorno 0.46785714285714286 en 138 pasos (retorno medio de 0.05014285714285714 en los últimos 100 episodios)
# ⮕⮕🟧🟧🟧⮕🟥
# ⮕⮕🟧🟧🟧⮕⮕
# ⮕⬇⮕⮕⮕⮕⮕
# ⮕⮕⮕⮕⮕⬆⮕
# ⮕⮕⮕⮕⮕⮕⮕

# %% [markdown]
# ### Q-learning
# El algoritmo Q-learning es de los más populares dentro del Aprendizaje por Refuerzo. Es muy similar a SARSA, pero tiene una importante diferencia: es *off-policy*. Si SARSA hacía las actualizaciones de $Q(S_t,A_t)$ en función de la acción $A_{t+1}$ que tomaba, Q-learning va a hacer dichas actualizaciones independientemente de la acción que finalmente tome. Por tanto, estará utilizando una política para explorar pero otra para actualizar. En concreto, Q-learning actualiza según esta fórmula:
#
# $$Q(S_t,A_t) \leftarrow Q(S_t,A_t) + \alpha [R_{t+1} + \gamma \max_aQ(S_{t+1},a) - Q(S_t,A_t)]$$
#
# Q-learning no actualiza en función de la acción que va a tomar, sino en función de la mejor acción posible. El algoritmo completo aparece descrito a continuación.
#
# ![Q-learning](https://github.com/eirasf/GCED-AA3/blob/main/lab6/img/q-learning.png?raw=true)
#
# Implementemos Q-learning mostrando los mismos mensajes a cada paso que mostrábamos con SARSA. Mantén las recompensas negativas para cuando el agente caiga en la lava.

# %%
# TODO - Implementa q_learning
#  Utiliza el mismo código que para sarsa pero cambiando la actualización
#  Recuerda mantener las recompensas negativas para cuando el agente caiga en la lava y mostrar los mensajes
def q_learning(num_episodios:int = 500, ALPHA:float = 0.1, EPSILON:float = 0.25) -> np.ndarray:

    # TODO - Inicializa los valores Q a cero con el shape adecuado
    q_valores = np.zeros((NUM_FILAS, NUM_COLUMNAS, NUM_ORIENTACIONES, NUM_ACCIONES))

    # En ultimos100retornos almacenaremos los retornos de los últimos 100 episodios
    ultimos100retornos = []
    # TODO - Haz tantos episodios como indica num_episodes
    for i in range(num_episodios):
        # TODO - Devuelve el entorno a su estado inicial
        env.reset()
        # TODO - Initialize S
        estado = get_estado_aleatorio()
        set_estado(env, estado)
        # TODO - Choose A from S using policy derived from Q (e.g. epsilon-greedy)
        accion = get_accion_epsilon_greedy(q_valores[estado.x, estado.y, estado.dir], EPSILON)

        retorno = 0
        num_pasos = 0
        # TODO - Loop for each step of episode (repite hasta que el episodio termine)
        while True:
            num_pasos += 1
            # TODO - Take action A, observe R, S'
            obs, reward, terminated, truncated, info = env.step(accion)
            # TODO - Acumula la recompensa R a returns para poder imprimir el retorno del episodio
            retorno += reward
            # TODO - Choose A' from S' using policy derived from Q (e.g. epsilon-greedy)
            estado_siguiente = get_estado(env)
            #Verificar que los valores esten dentro de los rangos permitidos
            estado_siguiente = Estado(
                x=min(max(estado_siguiente.x, 0), NUM_FILAS - 1),
                y=min(max(estado_siguiente.y, 0), NUM_COLUMNAS - 1),
                dir=min(max(estado_siguiente.dir, 0), NUM_ORIENTACIONES - 1)
            )

            accion_siguiente = get_accion_epsilon_greedy(q_valores[estado_siguiente.x, estado_siguiente.y, estado_siguiente.dir], EPSILON)
            # TODO - Q(S,A) <- Q(S,A) + ALPHA * [R + GAMMA * Q(S',A') - Q(S,A)]
            q_valores[estado.x, estado.y, estado.dir, accion] += ALPHA * (reward + GAMMA * np.max(q_valores[estado_siguiente.x, estado_siguiente.y, estado_siguiente.dir]) - q_valores[estado.x, estado.y, estado.dir, accion])

            # TODO - S <- S'; A <- A'
            estado = estado_siguiente
            accion = accion_siguiente
            # TODO - Si el episodio ha terminado, sale del bucle
            if terminated or truncated:
                break
            if terminated and reward == 0:
              reward = -1


        # Tras terminar el episodio almacenamos el retorno en los 100 últimos...
        ultimos100retornos.append(retorno)
        string_retornos100 = ''
        if len(ultimos100retornos)==101: # ... y si hay ya más de 100...
            ultimos100retornos.pop(0) # ...quitamos el más antiguo (para tener siempre 100, no más)...
            #... y preparamos el mensaje para mostrar la media de los retornos
            string_retornos100=f'(retorno medio de {np.mean(ultimos100retornos)} en los últimos 100 episodios)'
        # Mostramos el mensaje tras cada episodio
        print(f'Terminado episodio {i} con retorno {retorno} en {num_pasos} pasos {string_retornos100}')
    return q_valores

# %%
q_valores_q = q_learning()
dibuja_politica(q_valores_q)
# Out:
# Terminado episodio 0 con retorno 0 en 13 pasos
# Terminado episodio 1 con retorno 0 en 78 pasos
# Terminado episodio 2 con retorno 0 en 244 pasos
# Terminado episodio 3 con retorno 0 en 8 pasos
# Terminado episodio 4 con retorno 0 en 3 pasos
# Terminado episodio 5 con retorno 0 en 246 pasos
# Terminado episodio 6 con retorno 0 en 243 pasos
# Terminado episodio 7 con retorno 0 en 24 pasos
# Terminado episodio 8 con retorno 0 en 177 pasos
# Terminado episodio 9 con retorno 0 en 242 pasos
# Terminado episodio 10 con retorno 0 en 75 pasos
# Terminado episodio 11 con retorno 0 en 242 pasos
# Terminado episodio 12 con retorno 0 en 239 pasos
# Terminado episodio 13 con retorno 0 en 244 pasos
# Terminado episodio 14 con retorno 0 en 51 pasos
# Terminado episodio 15 con retorno 0 en 44 pasos
# Terminado episodio 16 con retorno 0 en 2 pasos
# Terminado episodio 17 con retorno 0 en 241 pasos
# Terminado episodio 18 con retorno 0 en 2 pasos
# Terminado episodio 19 con retorno 0 en 243 pasos
# Terminado episodio 20 con retorno 0 en 86 pasos
# Terminado episodio 21 con retorno 0 en 244 pasos
# Terminado episodio 22 con retorno 0 en 159 pasos
# Terminado episodio 23 con retorno 0 en 105 pasos
# Terminado episodio 24 con retorno 0 en 240 pasos
# Terminado episodio 25 con retorno 0 en 245 pasos
# Terminado episodio 26 con retorno 0 en 1 pasos
# Terminado episodio 27 con retorno 0 en 13 pasos
# Terminado episodio 28 con retorno 0 en 238 pasos
# Terminado episodio 29 con retorno 0 en 242 pasos
# Terminado episodio 30 con retorno 0 en 123 pasos
# Terminado episodio 31 con retorno 0.7357142857142858 en 65 pasos
# Terminado episodio 32 con retorno 0 en 242 pasos
# Terminado episodio 33 con retorno 0.8178571428571428 en 42 pasos
# Terminado episodio 34 con retorno 0 en 7 pasos
# Terminado episodio 35 con retorno 0 en 189 pasos
# Terminado episodio 36 con retorno 0 en 83 pasos
# Terminado episodio 37 con retorno 0 en 196 pasos
# Terminado episodio 38 con retorno 0 en 59 pasos
# Terminado episodio 39 con retorno 0.9392857142857143 en 10 pasos
# Terminado episodio 40 con retorno 0 en 135 pasos
# Terminado episodio 41 con retorno 0 en 44 pasos
# Terminado episodio 42 con retorno 0 en 247 pasos
# Terminado episodio 43 con retorno 0.95 en 5 pasos
# Terminado episodio 44 con retorno 0.7714285714285715 en 55 pasos
# Terminado episodio 45 con retorno 0 en 247 pasos
# Terminado episodio 46 con retorno 0.575 en 107 pasos
# Terminado episodio 47 con retorno 0 en 208 pasos
# Terminado episodio 48 con retorno 0 en 21 pasos
# Terminado episodio 49 con retorno 0 en 246 pasos
# Terminado episodio 50 con retorno 0 en 240 pasos
# Terminado episodio 51 con retorno 0.7857142857142857 en 48 pasos
# Terminado episodio 52 con retorno 0 en 154 pasos
# Terminado episodio 53 con retorno 0 en 4 pasos
# Terminado episodio 54 con retorno 0.475 en 139 pasos
# Terminado episodio 55 con retorno 0 en 46 pasos
# Terminado episodio 56 con retorno 0 en 11 pasos
# Terminado episodio 57 con retorno 0 en 244 pasos
# Terminado episodio 58 con retorno 0 en 26 pasos
# Terminado episodio 59 con retorno 0 en 9 pasos
# Terminado episodio 60 con retorno 0.925 en 9 pasos
# Terminado episodio 61 con retorno 0 en 2 pasos
# Terminado episodio 62 con retorno 0.9071428571428571 en 11 pasos
# Terminado episodio 63 con retorno 0 en 45 pasos
# Terminado episodio 64 con retorno 0 en 6 pasos
# Terminado episodio 65 con retorno 0 en 6 pasos
# Terminado episodio 66 con retorno 0 en 243 pasos
# Terminado episodio 67 con retorno 0.9071428571428571 en 15 pasos
# Terminado episodio 68 con retorno 0 en 11 pasos
# Terminado episodio 69 con retorno 0 en 5 pasos
# Terminado episodio 70 con retorno 0 en 219 pasos
# Terminado episodio 71 con retorno 0.9357142857142857 en 8 pasos
# Terminado episodio 72 con retorno 0.9285714285714286 en 11 pasos
# Terminado episodio 73 con retorno 0.6142857142857143 en 99 pasos
# Terminado episodio 74 con retorno 0.9392857142857143 en 5 pasos
# Terminado episodio 75 con retorno 0 en 21 pasos
# Terminado episodio 76 con retorno 0 en 27 pasos
# Terminado episodio 77 con retorno 0 en 40 pasos
# Terminado episodio 78 con retorno 0 en 176 pasos
# Terminado episodio 79 con retorno 0.9357142857142857 en 8 pasos
# Terminado episodio 80 con retorno 0 en 3 pasos
# Terminado episodio 81 con retorno 0 en 246 pasos
# Terminado episodio 82 con retorno 0 en 11 pasos
# Terminado episodio 83 con retorno 0 en 205 pasos
# Terminado episodio 84 con retorno 0 en 15 pasos
# Terminado episodio 85 con retorno 0 en 48 pasos
# Terminado episodio 86 con retorno 0 en 242 pasos
# Terminado episodio 87 con retorno 0 en 12 pasos
# Terminado episodio 88 con retorno 0.9285714285714286 en 12 pasos
# Terminado episodio 89 con retorno 0 en 26 pasos
# Terminado episodio 90 con retorno 0 en 131 pasos
# Terminado episodio 91 con retorno 0 en 24 pasos
# Terminado episodio 92 con retorno 0 en 242 pasos
# Terminado episodio 93 con retorno 0 en 44 pasos
# Terminado episodio 94 con retorno 0 en 5 pasos
# Terminado episodio 95 con retorno 0 en 19 pasos
# Terminado episodio 96 con retorno 0.9321428571428572 en 6 pasos
# Terminado episodio 97 con retorno 0.8821428571428571 en 22 pasos
# Terminado episodio 98 con retorno 0.9357142857142857 en 7 pasos
# Terminado episodio 99 con retorno 0 en 25 pasos
# Terminado episodio 100 con retorno 0 en 243 pasos (retorno medio de 0.16821428571428573 en los últimos 100 episodios)
# Terminado episodio 101 con retorno 0.9 en 18 pasos (retorno medio de 0.1772142857142857 en los últimos 100 episodios)
# Terminado episodio 102 con retorno 0 en 6 pasos (retorno medio de 0.17721428571428569 en los últimos 100 episodios)
# Terminado episodio 103 con retorno 0 en 7 pasos (retorno medio de 0.17721428571428569 en los últimos 100 episodios)
# Terminado episodio 104 con retorno 0 en 246 pasos (retorno medio de 0.17721428571428569 en los últimos 100 episodios)
# Terminado episodio 105 con retorno 0 en 246 pasos (retorno medio de 0.1772142857142857 en los últimos 100 episodios)
# Terminado episodio 106 con retorno 0 en 9 pasos (retorno medio de 0.1772142857142857 en los últimos 100 episodios)
# Terminado episodio 107 con retorno 0.9178571428571428 en 9 pasos (retorno medio de 0.18639285714285714 en los últimos 100 episodios)
# Terminado episodio 108 con retorno 0 en 30 pasos (retorno medio de 0.18639285714285717 en los últimos 100 episodios)
# Terminado episodio 109 con retorno 0.9428571428571428 en 6 pasos (retorno medio de 0.1958214285714286 en los últimos 100 episodios)
# Terminado episodio 110 con retorno 0 en 64 pasos (retorno medio de 0.1958214285714286 en los últimos 100 episodios)
# Terminado episodio 111 con retorno 0.9214285714285715 en 8 pasos (retorno medio de 0.20503571428571427 en los últimos 100 episodios)
# Terminado episodio 112 con retorno 0 en 213 pasos (retorno medio de 0.20503571428571427 en los últimos 100 episodios)
# Terminado episodio 113 con retorno 0 en 81 pasos (retorno medio de 0.20503571428571427 en los últimos 100 episodios)
# Terminado episodio 114 con retorno 0 en 203 pasos (retorno medio de 0.20503571428571427 en los últimos 100 episodios)
# Terminado episodio 115 con retorno 0.9285714285714286 en 9 pasos (retorno medio de 0.21432142857142858 en los últimos 100 episodios)
# Terminado episodio 116 con retorno 0.9214285714285715 en 8 pasos (retorno medio de 0.22353571428571425 en los últimos 100 episodios)
# Terminado episodio 117 con retorno 0 en 5 pasos (retorno medio de 0.22353571428571425 en los últimos 100 episodios)
# Terminado episodio 118 con retorno 0 en 28 pasos (retorno medio de 0.22353571428571428 en los últimos 100 episodios)
# Terminado episodio 119 con retorno 0.775 en 57 pasos (retorno medio de 0.23128571428571426 en los últimos 100 episodios)
# Terminado episodio 120 con retorno 0.9071428571428571 en 13 pasos (retorno medio de 0.24035714285714285 en los últimos 100 episodios)
# Terminado episodio 121 con retorno 0.9464285714285714 en 4 pasos (retorno medio de 0.24982142857142858 en los últimos 100 episodios)
# Terminado episodio 122 con retorno 0 en 2 pasos (retorno medio de 0.24982142857142858 en los últimos 100 episodios)
# Terminado episodio 123 con retorno 0 en 69 pasos (retorno medio de 0.24982142857142858 en los últimos 100 episodios)
# Terminado episodio 124 con retorno 0.9142857142857143 en 10 pasos (retorno medio de 0.2589642857142857 en los últimos 100 episodios)
# Terminado episodio 125 con retorno 0 en 5 pasos (retorno medio de 0.2589642857142857 en los últimos 100 episodios)
# Terminado episodio 126 con retorno 0.9428571428571428 en 7 pasos (retorno medio de 0.2683928571428571 en los últimos 100 episodios)
# Terminado episodio 127 con retorno 0 en 56 pasos (retorno medio de 0.26839285714285716 en los últimos 100 episodios)
# Terminado episodio 128 con retorno 0.8428571428571429 en 35 pasos (retorno medio de 0.27682142857142855 en los últimos 100 episodios)
# Terminado episodio 129 con retorno 0.9428571428571428 en 7 pasos (retorno medio de 0.28625 en los últimos 100 episodios)
# Terminado episodio 130 con retorno 0 en 2 pasos (retorno medio de 0.28624999999999995 en los últimos 100 episodios)
# Terminado episodio 131 con retorno 0 en 43 pasos (retorno medio de 0.2788928571428571 en los últimos 100 episodios)
# Terminado episodio 132 con retorno 0 en 245 pasos (retorno medio de 0.2788928571428571 en los últimos 100 episodios)
# Terminado episodio 133 con retorno 0 en 5 pasos (retorno medio de 0.27071428571428574 en los últimos 100 episodios)
# Terminado episodio 134 con retorno 0.5571428571428572 en 118 pasos (retorno medio de 0.27628571428571425 en los últimos 100 episodios)
# Terminado episodio 135 con retorno 0 en 30 pasos (retorno medio de 0.2762857142857143 en los últimos 100 episodios)
# Terminado episodio 136 con retorno 0 en 54 pasos (retorno medio de 0.27628571428571425 en los últimos 100 episodios)
# Terminado episodio 137 con retorno 0.9285714285714286 en 8 pasos (retorno medio de 0.2855714285714286 en los últimos 100 episodios)
# Terminado episodio 138 con retorno 0 en 8 pasos (retorno medio de 0.28557142857142853 en los últimos 100 episodios)
# Terminado episodio 139 con retorno 0 en 5 pasos (retorno medio de 0.2761785714285714 en los últimos 100 episodios)
# Terminado episodio 140 con retorno 0 en 25 pasos (retorno medio de 0.2761785714285714 en los últimos 100 episodios)
# Terminado episodio 141 con retorno 0 en 18 pasos (retorno medio de 0.2761785714285714 en los últimos 100 episodios)
# Terminado episodio 142 con retorno 0.9357142857142857 en 8 pasos (retorno medio de 0.2855357142857143 en los últimos 100 episodios)
# Terminado episodio 143 con retorno 0.9428571428571428 en 6 pasos (retorno medio de 0.2854642857142857 en los últimos 100 episodios)
# Terminado episodio 144 con retorno 0 en 6 pasos (retorno medio de 0.27775 en los últimos 100 episodios)
# Terminado episodio 145 con retorno 0 en 8 pasos (retorno medio de 0.27775 en los últimos 100 episodios)
# Terminado episodio 146 con retorno 0.9178571428571428 en 8 pasos (retorno medio de 0.2811785714285715 en los últimos 100 episodios)
# Terminado episodio 147 con retorno 0.9214285714285715 en 10 pasos (retorno medio de 0.2903928571428572 en los últimos 100 episodios)
# Terminado episodio 148 con retorno 0.9714285714285714 en 1 pasos (retorno medio de 0.3001071428571429 en los últimos 100 episodios)
# Terminado episodio 149 con retorno 0 en 87 pasos (retorno medio de 0.30010714285714285 en los últimos 100 episodios)
# Terminado episodio 150 con retorno 0.9357142857142857 en 6 pasos (retorno medio de 0.30946428571428575 en los últimos 100 episodios)
# Terminado episodio 151 con retorno 0.9428571428571428 en 6 pasos (retorno medio de 0.3110357142857143 en los últimos 100 episodios)
# Terminado episodio 152 con retorno 0 en 35 pasos (retorno medio de 0.3110357142857143 en los últimos 100 episodios)
# Terminado episodio 153 con retorno 0 en 1 pasos (retorno medio de 0.3110357142857143 en los últimos 100 episodios)
# Terminado episodio 154 con retorno 0.9214285714285715 en 16 pasos (retorno medio de 0.3155 en los últimos 100 episodios)
# Terminado episodio 155 con retorno 0 en 34 pasos (retorno medio de 0.3155 en los últimos 100 episodios)
# Terminado episodio 156 con retorno 0.9428571428571428 en 8 pasos (retorno medio de 0.3249285714285714 en los últimos 100 episodios)
# Terminado episodio 157 con retorno 0.9428571428571428 en 6 pasos (retorno medio de 0.3343571428571429 en los últimos 100 episodios)
# Terminado episodio 158 con retorno 0 en 9 pasos (retorno medio de 0.33435714285714285 en los últimos 100 episodios)
# Terminado episodio 159 con retorno 0.9214285714285715 en 10 pasos (retorno medio de 0.3435714285714285 en los últimos 100 episodios)
# Terminado episodio 160 con retorno 0.9321428571428572 en 6 pasos (retorno medio de 0.34364285714285714 en los últimos 100 episodios)
# Terminado episodio 161 con retorno 0 en 12 pasos (retorno medio de 0.34364285714285714 en los últimos 100 episodios)
# Terminado episodio 162 con retorno 0 en 8 pasos (retorno medio de 0.3345714285714286 en los últimos 100 episodios)
# Terminado episodio 163 con retorno 0 en 7 pasos (retorno medio de 0.33457142857142863 en los últimos 100 episodios)
# Terminado episodio 164 con retorno 0 en 19 pasos (retorno medio de 0.3345714285714286 en los últimos 100 episodios)
# Terminado episodio 165 con retorno 0.925 en 17 pasos (retorno medio de 0.3438214285714285 en los últimos 100 episodios)
# Terminado episodio 166 con retorno 0 en 19 pasos (retorno medio de 0.3438214285714285 en los últimos 100 episodios)
# Terminado episodio 167 con retorno 0 en 12 pasos (retorno medio de 0.33475 en los últimos 100 episodios)
# Terminado episodio 168 con retorno 0.9428571428571428 en 6 pasos (retorno medio de 0.3441785714285714 en los últimos 100 episodios)
# Terminado episodio 169 con retorno 0 en 21 pasos (retorno medio de 0.34417857142857144 en los últimos 100 episodios)
# Terminado episodio 170 con retorno 0.9571428571428572 en 4 pasos (retorno medio de 0.35375 en los últimos 100 episodios)
# Terminado episodio 171 con retorno 0.9714285714285714 en 2 pasos (retorno medio de 0.35410714285714284 en los últimos 100 episodios)
# Terminado episodio 172 con retorno 0.9357142857142857 en 6 pasos (retorno medio de 0.3541785714285714 en los últimos 100 episodios)
# Terminado episodio 173 con retorno 0.9464285714285714 en 5 pasos (retorno medio de 0.35749999999999993 en los últimos 100 episodios)
# Terminado episodio 174 con retorno 0.9464285714285714 en 4 pasos (retorno medio de 0.35757142857142854 en los últimos 100 episodios)
# Terminado episodio 175 con retorno 0.9464285714285714 en 4 pasos (retorno medio de 0.36703571428571424 en los últimos 100 episodios)
# Terminado episodio 176 con retorno 0 en 1 pasos (retorno medio de 0.36703571428571424 en los últimos 100 episodios)
# Terminado episodio 177 con retorno 0 en 21 pasos (retorno medio de 0.36703571428571424 en los últimos 100 episodios)
# Terminado episodio 178 con retorno 0 en 9 pasos (retorno medio de 0.36703571428571424 en los últimos 100 episodios)
# Terminado episodio 179 con retorno 0 en 15 pasos (retorno medio de 0.3576785714285714 en los últimos 100 episodios)
# Terminado episodio 180 con retorno 0 en 7 pasos (retorno medio de 0.3576785714285714 en los últimos 100 episodios)
# Terminado episodio 181 con retorno 0.9178571428571428 en 12 pasos (retorno medio de 0.3668571428571428 en los últimos 100 episodios)
# Terminado episodio 182 con retorno 0 en 8 pasos (retorno medio de 0.3668571428571428 en los últimos 100 episodios)
# Terminado episodio 183 con retorno 0.9571428571428572 en 4 pasos (retorno medio de 0.3764285714285714 en los últimos 100 episodios)
# Terminado episodio 184 con retorno 0 en 8 pasos (retorno medio de 0.3764285714285714 en los últimos 100 episodios)
# Terminado episodio 185 con retorno 0 en 16 pasos (retorno medio de 0.3764285714285714 en los últimos 100 episodios)
# Terminado episodio 186 con retorno 0 en 17 pasos (retorno medio de 0.3764285714285714 en los últimos 100 episodios)
# Terminado episodio 187 con retorno 0 en 12 pasos (retorno medio de 0.37642857142857145 en los últimos 100 episodios)
# Terminado episodio 188 con retorno 0.9428571428571428 en 5 pasos (retorno medio de 0.37657142857142856 en los últimos 100 episodios)
# Terminado episodio 189 con retorno 0 en 15 pasos (retorno medio de 0.37657142857142867 en los últimos 100 episodios)
# Terminado episodio 190 con retorno 0 en 11 pasos (retorno medio de 0.37657142857142856 en los últimos 100 episodios)
# Terminado episodio 191 con retorno 0 en 4 pasos (retorno medio de 0.37657142857142867 en los últimos 100 episodios)
# Terminado episodio 192 con retorno 0 en 21 pasos (retorno medio de 0.37657142857142856 en los últimos 100 episodios)
# Terminado episodio 193 con retorno 0 en 9 pasos (retorno medio de 0.37657142857142856 en los últimos 100 episodios)
# Terminado episodio 194 con retorno 0.9464285714285714 en 4 pasos (retorno medio de 0.38603571428571426 en los últimos 100 episodios)
# Terminado episodio 195 con retorno 0 en 12 pasos (retorno medio de 0.38603571428571426 en los últimos 100 episodios)
# Terminado episodio 196 con retorno 0 en 3 pasos (retorno medio de 0.3767142857142857 en los últimos 100 episodios)
# Terminado episodio 197 con retorno 0.9357142857142857 en 5 pasos (retorno medio de 0.3772499999999999 en los últimos 100 episodios)
# Terminado episodio 198 con retorno 0.9392857142857143 en 5 pasos (retorno medio de 0.3772857142857143 en los últimos 100 episodios)
# Terminado episodio 199 con retorno 0.925 en 7 pasos (retorno medio de 0.38653571428571426 en los últimos 100 episodios)
# Terminado episodio 200 con retorno 0.9571428571428572 en 4 pasos (retorno medio de 0.3961071428571428 en los últimos 100 episodios)
# Terminado episodio 201 con retorno 0 en 11 pasos (retorno medio de 0.38710714285714287 en los últimos 100 episodios)
# Terminado episodio 202 con retorno 0.9357142857142857 en 9 pasos (retorno medio de 0.3964642857142857 en los últimos 100 episodios)
# Terminado episodio 203 con retorno 0 en 3 pasos (retorno medio de 0.3964642857142857 en los últimos 100 episodios)
# Terminado episodio 204 con retorno 0.9285714285714286 en 12 pasos (retorno medio de 0.40575000000000006 en los últimos 100 episodios)
# Terminado episodio 205 con retorno 0 en 15 pasos (retorno medio de 0.40575000000000006 en los últimos 100 episodios)
# Terminado episodio 206 con retorno 0 en 14 pasos (retorno medio de 0.40575000000000006 en los últimos 100 episodios)
# Terminado episodio 207 con retorno 0 en 18 pasos (retorno medio de 0.3965714285714286 en los últimos 100 episodios)
# Terminado episodio 208 con retorno 0 en 4 pasos (retorno medio de 0.3965714285714286 en los últimos 100 episodios)
# Terminado episodio 209 con retorno 0.9178571428571428 en 9 pasos (retorno medio de 0.3963214285714286 en los últimos 100 episodios)
# Terminado episodio 210 con retorno 0.9428571428571428 en 6 pasos (retorno medio de 0.40575000000000006 en los últimos 100 episodios)
# Terminado episodio 211 con retorno 0 en 20 pasos (retorno medio de 0.3965357142857143 en los últimos 100 episodios)
# Terminado episodio 212 con retorno 0 en 8 pasos (retorno medio de 0.3965357142857143 en los últimos 100 episodios)
# Terminado episodio 213 con retorno 0 en 21 pasos (retorno medio de 0.3965357142857143 en los últimos 100 episodios)
# Terminado episodio 214 con retorno 0.9428571428571428 en 5 pasos (retorno medio de 0.4059642857142858 en los últimos 100 episodios)
# Terminado episodio 215 con retorno 0 en 8 pasos (retorno medio de 0.39667857142857144 en los últimos 100 episodios)
# Terminado episodio 216 con retorno 0.9392857142857143 en 6 pasos (retorno medio de 0.3968571428571429 en los últimos 100 episodios)
# Terminado episodio 217 con retorno 0 en 5 pasos (retorno medio de 0.3968571428571429 en los últimos 100 episodios)
# Terminado episodio 218 con retorno 0 en 42 pasos (retorno medio de 0.3968571428571429 en los últimos 100 episodios)
# Terminado episodio 219 con retorno 0 en 14 pasos (retorno medio de 0.3891071428571429 en los últimos 100 episodios)
# Terminado episodio 220 con retorno 0.9142857142857143 en 15 pasos (retorno medio de 0.38917857142857143 en los últimos 100 episodios)
# Terminado episodio 221 con retorno 0 en 12 pasos (retorno medio de 0.37971428571428567 en los últimos 100 episodios)
# Terminado episodio 222 con retorno 0 en 6 pasos (retorno medio de 0.37971428571428567 en los últimos 100 episodios)
# Terminado episodio 223 con retorno 0 en 19 pasos (retorno medio de 0.37971428571428567 en los últimos 100 episodios)
# Terminado episodio 224 con retorno 0 en 21 pasos (retorno medio de 0.37057142857142855 en los últimos 100 episodios)
# Terminado episodio 225 con retorno 0 en 13 pasos (retorno medio de 0.37057142857142855 en los últimos 100 episodios)
# Terminado episodio 226 con retorno 0.9178571428571428 en 11 pasos (retorno medio de 0.3703214285714286 en los últimos 100 episodios)
# Terminado episodio 227 con retorno 0.9428571428571428 en 7 pasos (retorno medio de 0.37975000000000003 en los últimos 100 episodios)
# Terminado episodio 228 con retorno 0 en 3 pasos (retorno medio de 0.3713214285714286 en los últimos 100 episodios)
# Terminado episodio 229 con retorno 0 en 10 pasos (retorno medio de 0.3618928571428572 en los últimos 100 episodios)
# Terminado episodio 230 con retorno 0 en 1 pasos (retorno medio de 0.3618928571428572 en los últimos 100 episodios)
# Terminado episodio 231 con retorno 0 en 9 pasos (retorno medio de 0.3618928571428572 en los últimos 100 episodios)
# Terminado episodio 232 con retorno 0 en 12 pasos (retorno medio de 0.3618928571428572 en los últimos 100 episodios)
# Terminado episodio 233 con retorno 0 en 17 pasos (retorno medio de 0.3618928571428572 en los últimos 100 episodios)
# Terminado episodio 234 con retorno 0.9428571428571428 en 8 pasos (retorno medio de 0.36575 en los últimos 100 episodios)
# Terminado episodio 235 con retorno 0 en 4 pasos (retorno medio de 0.36574999999999996 en los últimos 100 episodios)
# Terminado episodio 236 con retorno 0.9142857142857143 en 10 pasos (retorno medio de 0.3748928571428571 en los últimos 100 episodios)
# Terminado episodio 237 con retorno 0.8785714285714286 en 27 pasos (retorno medio de 0.3743928571428571 en los últimos 100 episodios)
# Terminado episodio 238 con retorno 0 en 6 pasos (retorno medio de 0.3743928571428571 en los últimos 100 episodios)
# Terminado episodio 239 con retorno 0.925 en 9 pasos (retorno medio de 0.38364285714285706 en los últimos 100 episodios)
# Terminado episodio 240 con retorno 0 en 17 pasos (retorno medio de 0.38364285714285706 en los últimos 100 episodios)
# Terminado episodio 241 con retorno 0 en 12 pasos (retorno medio de 0.3836428571428571 en los últimos 100 episodios)
# Terminado episodio 242 con retorno 0.9071428571428571 en 13 pasos (retorno medio de 0.38335714285714284 en los últimos 100 episodios)
# Terminado episodio 243 con retorno 0 en 19 pasos (retorno medio de 0.3739285714285714 en los últimos 100 episodios)
# Terminado episodio 244 con retorno 0 en 4 pasos (retorno medio de 0.3739285714285714 en los últimos 100 episodios)
# Terminado episodio 245 con retorno 0 en 3 pasos (retorno medio de 0.3739285714285714 en los últimos 100 episodios)
# Terminado episodio 246 con retorno 0.9607142857142857 en 2 pasos (retorno medio de 0.3743571428571429 en los últimos 100 episodios)
# Terminado episodio 247 con retorno 0.9285714285714286 en 8 pasos (retorno medio de 0.3744285714285715 en los últimos 100 episodios)
# Terminado episodio 248 con retorno 0.95 en 6 pasos (retorno medio de 0.3742142857142858 en los últimos 100 episodios)
# Terminado episodio 249 con retorno 0 en 3 pasos (retorno medio de 0.3742142857142858 en los últimos 100 episodios)
# Terminado episodio 250 con retorno 0 en 14 pasos (retorno medio de 0.36485714285714294 en los últimos 100 episodios)
# Terminado episodio 251 con retorno 0 en 9 pasos (retorno medio de 0.3554285714285714 en los últimos 100 episodios)
# Terminado episodio 252 con retorno 0 en 2 pasos (retorno medio de 0.3554285714285714 en los últimos 100 episodios)
# Terminado episodio 253 con retorno 0.9214285714285715 en 10 pasos (retorno medio de 0.36464285714285716 en los últimos 100 episodios)
# Terminado episodio 254 con retorno 0 en 30 pasos (retorno medio de 0.3554285714285714 en los últimos 100 episodios)
# Terminado episodio 255 con retorno 0 en 9 pasos (retorno medio de 0.3554285714285714 en los últimos 100 episodios)
# Terminado episodio 256 con retorno 0.9428571428571428 en 7 pasos (retorno medio de 0.3554285714285714 en los últimos 100 episodios)
# Terminado episodio 257 con retorno 0.9392857142857143 en 5 pasos (retorno medio de 0.3553928571428572 en los últimos 100 episodios)
# Terminado episodio 258 con retorno 0 en 8 pasos (retorno medio de 0.3553928571428572 en los últimos 100 episodios)
# Terminado episodio 259 con retorno 0.9035714285714286 en 18 pasos (retorno medio de 0.3552142857142858 en los últimos 100 episodios)
# Terminado episodio 260 con retorno 0 en 17 pasos (retorno medio de 0.34589285714285717 en los últimos 100 episodios)
# Terminado episodio 261 con retorno 0 en 2 pasos (retorno medio de 0.34589285714285717 en los últimos 100 episodios)
# Terminado episodio 262 con retorno 0 en 7 pasos (retorno medio de 0.34589285714285717 en los últimos 100 episodios)
# Terminado episodio 263 con retorno 0.9071428571428571 en 15 pasos (retorno medio de 0.35496428571428573 en los últimos 100 episodios)
# Terminado episodio 264 con retorno 0 en 16 pasos (retorno medio de 0.35496428571428573 en los últimos 100 episodios)
# Terminado episodio 265 con retorno 0 en 6 pasos (retorno medio de 0.3457142857142857 en los últimos 100 episodios)
# Terminado episodio 266 con retorno 0 en 22 pasos (retorno medio de 0.3457142857142857 en los últimos 100 episodios)
# Terminado episodio 267 con retorno 0 en 15 pasos (retorno medio de 0.3457142857142857 en los últimos 100 episodios)
# Terminado episodio 268 con retorno 0.9714285714285714 en 2 pasos (retorno medio de 0.34600000000000003 en los últimos 100 episodios)
# Terminado episodio 269 con retorno 0 en 3 pasos (retorno medio de 0.3459999999999999 en los últimos 100 episodios)
# Terminado episodio 270 con retorno 0 en 12 pasos (retorno medio de 0.3364285714285714 en los últimos 100 episodios)
# Terminado episodio 271 con retorno 0 en 7 pasos (retorno medio de 0.32671428571428573 en los últimos 100 episodios)
# Terminado episodio 272 con retorno 0 en 22 pasos (retorno medio de 0.3173571428571429 en los últimos 100 episodios)
# Terminado episodio 273 con retorno 0.6607142857142857 en 85 pasos (retorno medio de 0.3145 en los últimos 100 episodios)
# Terminado episodio 274 con retorno 0 en 11 pasos (retorno medio de 0.30503571428571424 en los últimos 100 episodios)
# Terminado episodio 275 con retorno 0 en 6 pasos (retorno medio de 0.2955714285714286 en los últimos 100 episodios)
# Terminado episodio 276 con retorno 0 en 20 pasos (retorno medio de 0.2955714285714286 en los últimos 100 episodios)
# Terminado episodio 277 con retorno 0 en 9 pasos (retorno medio de 0.2955714285714286 en los últimos 100 episodios)
# Terminado episodio 278 con retorno 0 en 4 pasos (retorno medio de 0.2955714285714286 en los últimos 100 episodios)
# Terminado episodio 279 con retorno 0 en 12 pasos (retorno medio de 0.2955714285714286 en los últimos 100 episodios)
# Terminado episodio 280 con retorno 0 en 20 pasos (retorno medio de 0.2955714285714286 en los últimos 100 episodios)
# Terminado episodio 281 con retorno 0 en 14 pasos (retorno medio de 0.2863928571428571 en los últimos 100 episodios)
# Terminado episodio 282 con retorno 0 en 6 pasos (retorno medio de 0.28639285714285717 en los últimos 100 episodios)
# Terminado episodio 283 con retorno 0 en 7 pasos (retorno medio de 0.27682142857142855 en los últimos 100 episodios)
# Terminado episodio 284 con retorno 0 en 16 pasos (retorno medio de 0.27682142857142855 en los últimos 100 episodios)
# Terminado episodio 285 con retorno 0 en 8 pasos (retorno medio de 0.27682142857142855 en los últimos 100 episodios)
# Terminado episodio 286 con retorno 0 en 31 pasos (retorno medio de 0.27682142857142855 en los últimos 100 episodios)
# Terminado episodio 287 con retorno 0 en 25 pasos (retorno medio de 0.27682142857142855 en los últimos 100 episodios)
# Terminado episodio 288 con retorno 0 en 8 pasos (retorno medio de 0.26739285714285715 en los últimos 100 episodios)
# Terminado episodio 289 con retorno 0 en 18 pasos (retorno medio de 0.26739285714285715 en los últimos 100 episodios)
# Terminado episodio 290 con retorno 0 en 12 pasos (retorno medio de 0.26739285714285715 en los últimos 100 episodios)
# Terminado episodio 291 con retorno 0 en 13 pasos (retorno medio de 0.26739285714285715 en los últimos 100 episodios)
# Terminado episodio 292 con retorno 0.9071428571428571 en 16 pasos (retorno medio de 0.2764642857142857 en los últimos 100 episodios)
# Terminado episodio 293 con retorno 0.37857142857142856 en 166 pasos (retorno medio de 0.28025 en los últimos 100 episodios)
# Terminado episodio 294 con retorno 0 en 27 pasos (retorno medio de 0.27078571428571435 en los últimos 100 episodios)
# Terminado episodio 295 con retorno 0 en 3 pasos (retorno medio de 0.27078571428571435 en los últimos 100 episodios)
# Terminado episodio 296 con retorno 0.6607142857142857 en 86 pasos (retorno medio de 0.27739285714285716 en los últimos 100 episodios)
# Terminado episodio 297 con retorno 0 en 16 pasos (retorno medio de 0.26803571428571427 en los últimos 100 episodios)
# Terminado episodio 298 con retorno 0 en 7 pasos (retorno medio de 0.2586428571428571 en los últimos 100 episodios)
# Terminado episodio 299 con retorno 0.9321428571428572 en 7 pasos (retorno medio de 0.25871428571428573 en los últimos 100 episodios)
# Terminado episodio 300 con retorno 0.9428571428571428 en 8 pasos (retorno medio de 0.25857142857142856 en los últimos 100 episodios)
# Terminado episodio 301 con retorno 0 en 5 pasos (retorno medio de 0.25857142857142856 en los últimos 100 episodios)
# Terminado episodio 302 con retorno 0.9714285714285714 en 1 pasos (retorno medio de 0.2589285714285714 en los últimos 100 episodios)
# Terminado episodio 303 con retorno 0 en 1 pasos (retorno medio de 0.2589285714285714 en los últimos 100 episodios)
# Terminado episodio 304 con retorno 0.9571428571428572 en 3 pasos (retorno medio de 0.2592142857142857 en los últimos 100 episodios)
# Terminado episodio 305 con retorno 0 en 9 pasos (retorno medio de 0.25921428571428573 en los últimos 100 episodios)
# Terminado episodio 306 con retorno 0 en 7 pasos (retorno medio de 0.25921428571428573 en los últimos 100 episodios)
# Terminado episodio 307 con retorno 0 en 2 pasos (retorno medio de 0.25921428571428573 en los últimos 100 episodios)
# Terminado episodio 308 con retorno 0.9464285714285714 en 6 pasos (retorno medio de 0.26867857142857143 en los últimos 100 episodios)
# Terminado episodio 309 con retorno 0 en 11 pasos (retorno medio de 0.2595 en los últimos 100 episodios)
# Terminado episodio 310 con retorno 0.9571428571428572 en 4 pasos (retorno medio de 0.2596428571428572 en los últimos 100 episodios)
# Terminado episodio 311 con retorno 0 en 2 pasos (retorno medio de 0.2596428571428572 en los últimos 100 episodios)
# Terminado episodio 312 con retorno 0.9392857142857143 en 6 pasos (retorno medio de 0.26903571428571427 en los últimos 100 episodios)
# Terminado episodio 313 con retorno 0.9428571428571428 en 7 pasos (retorno medio de 0.27846428571428566 en los últimos 100 episodios)
# Terminado episodio 314 con retorno 0.9714285714285714 en 1 pasos (retorno medio de 0.27875 en los últimos 100 episodios)
# Terminado episodio 315 con retorno 0.8964285714285715 en 22 pasos (retorno medio de 0.2877142857142857 en los últimos 100 episodios)
# Terminado episodio 316 con retorno 0 en 8 pasos (retorno medio de 0.2783214285714286 en los últimos 100 episodios)
# Terminado episodio 317 con retorno 0.9464285714285714 en 5 pasos (retorno medio de 0.2877857142857143 en los últimos 100 episodios)
# Terminado episodio 318 con retorno 0 en 13 pasos (retorno medio de 0.2877857142857143 en los últimos 100 episodios)
# Terminado episodio 319 con retorno 0 en 9 pasos (retorno medio de 0.2877857142857143 en los últimos 100 episodios)
# Terminado episodio 320 con retorno 0 en 17 pasos (retorno medio de 0.2786428571428572 en los últimos 100 episodios)
# Terminado episodio 321 con retorno 0.9571428571428572 en 3 pasos (retorno medio de 0.2882142857142857 en los últimos 100 episodios)
# Terminado episodio 322 con retorno 0.9142857142857143 en 16 pasos (retorno medio de 0.2973571428571428 en los últimos 100 episodios)
# Terminado episodio 323 con retorno 0 en 14 pasos (retorno medio de 0.2973571428571428 en los últimos 100 episodios)
# Terminado episodio 324 con retorno 0 en 6 pasos (retorno medio de 0.2973571428571428 en los últimos 100 episodios)
# Terminado episodio 325 con retorno 0 en 19 pasos (retorno medio de 0.2973571428571429 en los últimos 100 episodios)
# Terminado episodio 326 con retorno 0.9178571428571428 en 10 pasos (retorno medio de 0.2973571428571429 en los últimos 100 episodios)
# Terminado episodio 327 con retorno 0 en 13 pasos (retorno medio de 0.2879285714285714 en los últimos 100 episodios)
# Terminado episodio 328 con retorno 0 en 8 pasos (retorno medio de 0.2879285714285714 en los últimos 100 episodios)
# Terminado episodio 329 con retorno 0 en 9 pasos (retorno medio de 0.2879285714285714 en los últimos 100 episodios)
# Terminado episodio 330 con retorno 0 en 14 pasos (retorno medio de 0.2879285714285714 en los últimos 100 episodios)
# Terminado episodio 331 con retorno 0 en 13 pasos (retorno medio de 0.2879285714285714 en los últimos 100 episodios)
# Terminado episodio 332 con retorno 0.925 en 7 pasos (retorno medio de 0.29717857142857146 en los últimos 100 episodios)
# Terminado episodio 333 con retorno 0 en 24 pasos (retorno medio de 0.29717857142857146 en los últimos 100 episodios)
# Terminado episodio 334 con retorno 0 en 6 pasos (retorno medio de 0.28775 en los últimos 100 episodios)
# Terminado episodio 335 con retorno 0.95 en 5 pasos (retorno medio de 0.29725 en los últimos 100 episodios)
# Terminado episodio 336 con retorno 0 en 2 pasos (retorno medio de 0.28810714285714284 en los últimos 100 episodios)
# Terminado episodio 337 con retorno 0 en 4 pasos (retorno medio de 0.27932142857142855 en los últimos 100 episodios)
# Terminado episodio 338 con retorno 0 en 2 pasos (retorno medio de 0.27932142857142855 en los últimos 100 episodios)
# Terminado episodio 339 con retorno 0 en 12 pasos (retorno medio de 0.2700714285714286 en los últimos 100 episodios)
# Terminado episodio 340 con retorno 0 en 15 pasos (retorno medio de 0.2700714285714286 en los últimos 100 episodios)
# Terminado episodio 341 con retorno 0 en 11 pasos (retorno medio de 0.2700714285714286 en los últimos 100 episodios)
# Terminado episodio 342 con retorno 0.9285714285714286 en 9 pasos (retorno medio de 0.2702857142857143 en los últimos 100 episodios)
# Terminado episodio 343 con retorno 0 en 20 pasos (retorno medio de 0.27028571428571424 en los últimos 100 episodios)
# Terminado episodio 344 con retorno 0 en 1 pasos (retorno medio de 0.2702857142857143 en los últimos 100 episodios)
# Terminado episodio 345 con retorno 0.9607142857142857 en 2 pasos (retorno medio de 0.27989285714285717 en los últimos 100 episodios)
# Terminado episodio 346 con retorno 0 en 9 pasos (retorno medio de 0.2702857142857143 en los últimos 100 episodios)
# Terminado episodio 347 con retorno 0.9357142857142857 en 7 pasos (retorno medio de 0.27035714285714285 en los últimos 100 episodios)
# Terminado episodio 348 con retorno 0 en 19 pasos (retorno medio de 0.2608571428571429 en los últimos 100 episodios)
# Terminado episodio 349 con retorno 0 en 14 pasos (retorno medio de 0.26085714285714284 en los últimos 100 episodios)
# Terminado episodio 350 con retorno 0 en 11 pasos (retorno medio de 0.26085714285714284 en los últimos 100 episodios)
# Terminado episodio 351 con retorno 0 en 5 pasos (retorno medio de 0.26085714285714284 en los últimos 100 episodios)
# Terminado episodio 352 con retorno 0 en 1 pasos (retorno medio de 0.26085714285714284 en los últimos 100 episodios)
# Terminado episodio 353 con retorno 0.9571428571428572 en 4 pasos (retorno medio de 0.2612142857142857 en los últimos 100 episodios)
# Terminado episodio 354 con retorno 0 en 7 pasos (retorno medio de 0.2612142857142857 en los últimos 100 episodios)
# Terminado episodio 355 con retorno 0.9428571428571428 en 6 pasos (retorno medio de 0.27064285714285713 en los últimos 100 episodios)
# Terminado episodio 356 con retorno 0.9357142857142857 en 7 pasos (retorno medio de 0.2705714285714286 en los últimos 100 episodios)
# Terminado episodio 357 con retorno 0 en 15 pasos (retorno medio de 0.2611785714285714 en los últimos 100 episodios)
# Terminado episodio 358 con retorno 0.9571428571428572 en 4 pasos (retorno medio de 0.27075 en los últimos 100 episodios)
# Terminado episodio 359 con retorno 0.9 en 14 pasos (retorno medio de 0.27071428571428574 en los últimos 100 episodios)
# Terminado episodio 360 con retorno 0.532142857142857 en 120 pasos (retorno medio de 0.2760357142857143 en los últimos 100 episodios)
# Terminado episodio 361 con retorno 0.8892857142857142 en 24 pasos (retorno medio de 0.2849285714285714 en los últimos 100 episodios)
# Terminado episodio 362 con retorno 0 en 166 pasos (retorno medio de 0.2849285714285714 en los últimos 100 episodios)
# Terminado episodio 363 con retorno 0.9035714285714286 en 12 pasos (retorno medio de 0.28489285714285717 en los últimos 100 episodios)
# Terminado episodio 364 con retorno 0 en 7 pasos (retorno medio de 0.2848928571428571 en los últimos 100 episodios)
# Terminado episodio 365 con retorno 0 en 17 pasos (retorno medio de 0.2848928571428571 en los últimos 100 episodios)
# Terminado episodio 366 con retorno 0 en 17 pasos (retorno medio de 0.2848928571428571 en los últimos 100 episodios)
# Terminado episodio 367 con retorno 0 en 3 pasos (retorno medio de 0.2848928571428571 en los últimos 100 episodios)
# Terminado episodio 368 con retorno 0 en 18 pasos (retorno medio de 0.27517857142857144 en los últimos 100 episodios)
# Terminado episodio 369 con retorno 0 en 20 pasos (retorno medio de 0.27517857142857144 en los últimos 100 episodios)
# Terminado episodio 370 con retorno 0.9321428571428572 en 7 pasos (retorno medio de 0.2845 en los últimos 100 episodios)
# Terminado episodio 371 con retorno 0 en 3 pasos (retorno medio de 0.28450000000000003 en los últimos 100 episodios)
# Terminado episodio 372 con retorno 0 en 5 pasos (retorno medio de 0.28450000000000003 en los últimos 100 episodios)
# Terminado episodio 373 con retorno 0.9535714285714285 en 3 pasos (retorno medio de 0.2874285714285714 en los últimos 100 episodios)
# Terminado episodio 374 con retorno 0 en 5 pasos (retorno medio de 0.2874285714285714 en los últimos 100 episodios)
# Terminado episodio 375 con retorno 0 en 4 pasos (retorno medio de 0.2874285714285714 en los últimos 100 episodios)
# Terminado episodio 376 con retorno 0 en 3 pasos (retorno medio de 0.2874285714285715 en los últimos 100 episodios)
# Terminado episodio 377 con retorno 0.9464285714285714 en 4 pasos (retorno medio de 0.2968928571428571 en los últimos 100 episodios)
# Terminado episodio 378 con retorno 0 en 7 pasos (retorno medio de 0.2968928571428572 en los últimos 100 episodios)
# Terminado episodio 379 con retorno 0.9428571428571428 en 6 pasos (retorno medio de 0.3063214285714286 en los últimos 100 episodios)
# Terminado episodio 380 con retorno 0 en 16 pasos (retorno medio de 0.3063214285714286 en los últimos 100 episodios)
# Terminado episodio 381 con retorno 0.9392857142857143 en 5 pasos (retorno medio de 0.31571428571428567 en los últimos 100 episodios)
# Terminado episodio 382 con retorno 0.8928571428571429 en 23 pasos (retorno medio de 0.3246428571428572 en los últimos 100 episodios)
# Terminado episodio 383 con retorno 0 en 3 pasos (retorno medio de 0.3246428571428572 en los últimos 100 episodios)
# Terminado episodio 384 con retorno 0 en 21 pasos (retorno medio de 0.3246428571428572 en los últimos 100 episodios)
# Terminado episodio 385 con retorno 0.9428571428571428 en 5 pasos (retorno medio de 0.3340714285714286 en los últimos 100 episodios)
# Terminado episodio 386 con retorno 0.9428571428571428 en 6 pasos (retorno medio de 0.3435 en los últimos 100 episodios)
# Terminado episodio 387 con retorno 0 en 12 pasos (retorno medio de 0.3435 en los últimos 100 episodios)
# Terminado episodio 388 con retorno 0 en 15 pasos (retorno medio de 0.3435 en los últimos 100 episodios)
# Terminado episodio 389 con retorno 0 en 1 pasos (retorno medio de 0.3435 en los últimos 100 episodios)
# Terminado episodio 390 con retorno 0.95 en 5 pasos (retorno medio de 0.35300000000000004 en los últimos 100 episodios)
# Terminado episodio 391 con retorno 0.7964285714285715 en 52 pasos (retorno medio de 0.36096428571428574 en los últimos 100 episodios)
# Terminado episodio 392 con retorno 0 en 9 pasos (retorno medio de 0.3518928571428572 en los últimos 100 episodios)
# Terminado episodio 393 con retorno 0 en 5 pasos (retorno medio de 0.3481071428571429 en los últimos 100 episodios)
# Terminado episodio 394 con retorno 0.9 en 23 pasos (retorno medio de 0.35710714285714285 en los últimos 100 episodios)
# Terminado episodio 395 con retorno 0 en 16 pasos (retorno medio de 0.35710714285714285 en los últimos 100 episodios)
# Terminado episodio 396 con retorno 0 en 24 pasos (retorno medio de 0.3505 en los últimos 100 episodios)
# Terminado episodio 397 con retorno 0.925 en 6 pasos (retorno medio de 0.35975 en los últimos 100 episodios)
# Terminado episodio 398 con retorno 0.9178571428571428 en 21 pasos (retorno medio de 0.3689285714285714 en los últimos 100 episodios)
# Terminado episodio 399 con retorno 0.9571428571428572 en 3 pasos (retorno medio de 0.36917857142857147 en los últimos 100 episodios)
# Terminado episodio 400 con retorno 0 en 11 pasos (retorno medio de 0.35974999999999996 en los últimos 100 episodios)
# Terminado episodio 401 con retorno 0 en 19 pasos (retorno medio de 0.35975 en los últimos 100 episodios)
# Terminado episodio 402 con retorno 0 en 23 pasos (retorno medio de 0.3500357142857143 en los últimos 100 episodios)
# Terminado episodio 403 con retorno 0.9464285714285714 en 4 pasos (retorno medio de 0.35949999999999993 en los últimos 100 episodios)
# Terminado episodio 404 con retorno 0 en 14 pasos (retorno medio de 0.3499285714285715 en los últimos 100 episodios)
# Terminado episodio 405 con retorno 0 en 4 pasos (retorno medio de 0.3499285714285714 en los últimos 100 episodios)
# Terminado episodio 406 con retorno 0 en 2 pasos (retorno medio de 0.3499285714285715 en los últimos 100 episodios)
# Terminado episodio 407 con retorno 0 en 20 pasos (retorno medio de 0.3499285714285714 en los últimos 100 episodios)
# Terminado episodio 408 con retorno 0 en 3 pasos (retorno medio de 0.3404642857142858 en los últimos 100 episodios)
# Terminado episodio 409 con retorno 0 en 7 pasos (retorno medio de 0.3404642857142857 en los últimos 100 episodios)
# Terminado episodio 410 con retorno 0 en 9 pasos (retorno medio de 0.3308928571428572 en los últimos 100 episodios)
# Terminado episodio 411 con retorno 0 en 6 pasos (retorno medio de 0.33089285714285716 en los últimos 100 episodios)
# Terminado episodio 412 con retorno 0.9321428571428572 en 10 pasos (retorno medio de 0.3308214285714286 en los últimos 100 episodios)
# Terminado episodio 413 con retorno 0 en 13 pasos (retorno medio de 0.32139285714285715 en los últimos 100 episodios)
# Terminado episodio 414 con retorno 0 en 32 pasos (retorno medio de 0.31167857142857147 en los últimos 100 episodios)
# Terminado episodio 415 con retorno 0.9428571428571428 en 6 pasos (retorno medio de 0.31214285714285717 en los últimos 100 episodios)
# Terminado episodio 416 con retorno 0 en 6 pasos (retorno medio de 0.31214285714285717 en los últimos 100 episodios)
# Terminado episodio 417 con retorno 0 en 12 pasos (retorno medio de 0.3026785714285714 en los últimos 100 episodios)
# Terminado episodio 418 con retorno 0.9464285714285714 en 3 pasos (retorno medio de 0.31214285714285717 en los últimos 100 episodios)
# Terminado episodio 419 con retorno 0 en 4 pasos (retorno medio de 0.31214285714285717 en los últimos 100 episodios)
# Terminado episodio 420 con retorno 0 en 11 pasos (retorno medio de 0.31214285714285717 en los últimos 100 episodios)
# Terminado episodio 421 con retorno 0.9178571428571428 en 12 pasos (retorno medio de 0.31175 en los últimos 100 episodios)
# Terminado episodio 422 con retorno 0 en 23 pasos (retorno medio de 0.30260714285714285 en los últimos 100 episodios)
# Terminado episodio 423 con retorno 0 en 17 pasos (retorno medio de 0.30260714285714285 en los últimos 100 episodios)
# Terminado episodio 424 con retorno 0.9464285714285714 en 6 pasos (retorno medio de 0.3120714285714286 en los últimos 100 episodios)
# Terminado episodio 425 con retorno 0.9321428571428572 en 7 pasos (retorno medio de 0.3213928571428572 en los últimos 100 episodios)
# Terminado episodio 426 con retorno 0.9392857142857143 en 8 pasos (retorno medio de 0.32160714285714287 en los últimos 100 episodios)
# Terminado episodio 427 con retorno 0 en 9 pasos (retorno medio de 0.32160714285714287 en los últimos 100 episodios)
# Terminado episodio 428 con retorno 0.95 en 6 pasos (retorno medio de 0.3311071428571429 en los últimos 100 episodios)
# Terminado episodio 429 con retorno 0 en 4 pasos (retorno medio de 0.3311071428571429 en los últimos 100 episodios)
# Terminado episodio 430 con retorno 0 en 8 pasos (retorno medio de 0.3311071428571429 en los últimos 100 episodios)
# Terminado episodio 431 con retorno 0 en 13 pasos (retorno medio de 0.3311071428571429 en los últimos 100 episodios)
# Terminado episodio 432 con retorno 0 en 21 pasos (retorno medio de 0.32185714285714284 en los últimos 100 episodios)
# Terminado episodio 433 con retorno 0 en 10 pasos (retorno medio de 0.32185714285714284 en los últimos 100 episodios)
# Terminado episodio 434 con retorno 0 en 18 pasos (retorno medio de 0.32185714285714284 en los últimos 100 episodios)
# Terminado episodio 435 con retorno 0.9214285714285715 en 12 pasos (retorno medio de 0.32157142857142856 en los últimos 100 episodios)
# Terminado episodio 436 con retorno 0 en 5 pasos (retorno medio de 0.32157142857142856 en los últimos 100 episodios)
# Terminado episodio 437 con retorno 0 en 9 pasos (retorno medio de 0.32157142857142856 en los últimos 100 episodios)
# Terminado episodio 438 con retorno 0.9071428571428571 en 12 pasos (retorno medio de 0.3306428571428572 en los últimos 100 episodios)
# Terminado episodio 439 con retorno 0.9464285714285714 en 11 pasos (retorno medio de 0.3401071428571429 en los últimos 100 episodios)
# Terminado episodio 440 con retorno 0 en 15 pasos (retorno medio de 0.3401071428571429 en los últimos 100 episodios)
# Terminado episodio 441 con retorno 0.9214285714285715 en 13 pasos (retorno medio de 0.34932142857142856 en los últimos 100 episodios)
# Terminado episodio 442 con retorno 0 en 3 pasos (retorno medio de 0.3400357142857143 en los últimos 100 episodios)
# Terminado episodio 443 con retorno 0 en 5 pasos (retorno medio de 0.3400357142857143 en los últimos 100 episodios)
# Terminado episodio 444 con retorno 0.9214285714285715 en 10 pasos (retorno medio de 0.34924999999999995 en los últimos 100 episodios)
# Terminado episodio 445 con retorno 0 en 17 pasos (retorno medio de 0.33964285714285714 en los últimos 100 episodios)
# Terminado episodio 446 con retorno 0.8214285714285714 en 39 pasos (retorno medio de 0.34785714285714286 en los últimos 100 episodios)
# Terminado episodio 447 con retorno 0 en 9 pasos (retorno medio de 0.3385 en los últimos 100 episodios)
# Terminado episodio 448 con retorno 0 en 18 pasos (retorno medio de 0.33849999999999997 en los últimos 100 episodios)
# Terminado episodio 449 con retorno 0.925 en 9 pasos (retorno medio de 0.34775 en los últimos 100 episodios)
# Terminado episodio 450 con retorno 0 en 7 pasos (retorno medio de 0.34775 en los últimos 100 episodios)
# Terminado episodio 451 con retorno 0 en 6 pasos (retorno medio de 0.34775 en los últimos 100 episodios)
# Terminado episodio 452 con retorno 0 en 17 pasos (retorno medio de 0.34775 en los últimos 100 episodios)
# Terminado episodio 453 con retorno 0 en 2 pasos (retorno medio de 0.33817857142857144 en los últimos 100 episodios)
# Terminado episodio 454 con retorno 0 en 1 pasos (retorno medio de 0.33817857142857144 en los últimos 100 episodios)
# Terminado episodio 455 con retorno 0 en 7 pasos (retorno medio de 0.32875 en los últimos 100 episodios)
# Terminado episodio 456 con retorno 0.9214285714285715 en 10 pasos (retorno medio de 0.3286071428571429 en los últimos 100 episodios)
# Terminado episodio 457 con retorno 0.9214285714285715 en 11 pasos (retorno medio de 0.3378214285714286 en los últimos 100 episodios)
# Terminado episodio 458 con retorno 0 en 5 pasos (retorno medio de 0.32825000000000004 en los últimos 100 episodios)
# Terminado episodio 459 con retorno 0 en 7 pasos (retorno medio de 0.31925 en los últimos 100 episodios)
# Terminado episodio 460 con retorno 0.9321428571428572 en 12 pasos (retorno medio de 0.32325 en los últimos 100 episodios)
# Terminado episodio 461 con retorno 0.9428571428571428 en 5 pasos (retorno medio de 0.3237857142857143 en los últimos 100 episodios)
# Terminado episodio 462 con retorno 0 en 3 pasos (retorno medio de 0.3237857142857143 en los últimos 100 episodios)
# Terminado episodio 463 con retorno 0 en 25 pasos (retorno medio de 0.31475000000000003 en los últimos 100 episodios)
# Terminado episodio 464 con retorno 0 en 3 pasos (retorno medio de 0.31475 en los últimos 100 episodios)
# Terminado episodio 465 con retorno 0.8928571428571429 en 21 pasos (retorno medio de 0.3236785714285715 en los últimos 100 episodios)
# Terminado episodio 466 con retorno 0.9571428571428572 en 3 pasos (retorno medio de 0.33325000000000005 en los últimos 100 episodios)
# Terminado episodio 467 con retorno 0.95 en 6 pasos (retorno medio de 0.34275000000000005 en los últimos 100 episodios)
# Terminado episodio 468 con retorno 0.9428571428571428 en 6 pasos (retorno medio de 0.3521785714285714 en los últimos 100 episodios)
# Terminado episodio 469 con retorno 0 en 6 pasos (retorno medio de 0.3521785714285715 en los últimos 100 episodios)
# Terminado episodio 470 con retorno 0 en 20 pasos (retorno medio de 0.3428571428571429 en los últimos 100 episodios)
# Terminado episodio 471 con retorno 0 en 13 pasos (retorno medio de 0.34285714285714286 en los últimos 100 episodios)
# Terminado episodio 472 con retorno 0 en 8 pasos (retorno medio de 0.3428571428571429 en los últimos 100 episodios)
# Terminado episodio 473 con retorno 0 en 11 pasos (retorno medio de 0.33332142857142855 en los últimos 100 episodios)
# Terminado episodio 474 con retorno 0.9357142857142857 en 7 pasos (retorno medio de 0.3426785714285714 en los últimos 100 episodios)
# Terminado episodio 475 con retorno 0 en 11 pasos (retorno medio de 0.3426785714285714 en los últimos 100 episodios)
# Terminado episodio 476 con retorno 0 en 5 pasos (retorno medio de 0.3426785714285714 en los últimos 100 episodios)
# Terminado episodio 477 con retorno 0 en 4 pasos (retorno medio de 0.3332142857142857 en los últimos 100 episodios)
# Terminado episodio 478 con retorno 0 en 9 pasos (retorno medio de 0.3332142857142857 en los últimos 100 episodios)
# Terminado episodio 479 con retorno 0 en 6 pasos (retorno medio de 0.32378571428571434 en los últimos 100 episodios)
# Terminado episodio 480 con retorno 0.9392857142857143 en 4 pasos (retorno medio de 0.3331785714285715 en los últimos 100 episodios)
# Terminado episodio 481 con retorno 0 en 11 pasos (retorno medio de 0.3237857142857143 en los últimos 100 episodios)
# Terminado episodio 482 con retorno 0.9321428571428572 en 5 pasos (retorno medio de 0.3241785714285714 en los últimos 100 episodios)
# Terminado episodio 483 con retorno 0.9464285714285714 en 5 pasos (retorno medio de 0.33364285714285713 en los últimos 100 episodios)
# Terminado episodio 484 con retorno 0 en 18 pasos (retorno medio de 0.33364285714285713 en los últimos 100 episodios)
# Terminado episodio 485 con retorno 0.9357142857142857 en 7 pasos (retorno medio de 0.3335714285714285 en los últimos 100 episodios)
# Terminado episodio 486 con retorno 0 en 9 pasos (retorno medio de 0.3241428571428572 en los últimos 100 episodios)
# Terminado episodio 487 con retorno 0.9535714285714285 en 2 pasos (retorno medio de 0.3336785714285714 en los últimos 100 episodios)
# Terminado episodio 488 con retorno 0 en 5 pasos (retorno medio de 0.3336785714285714 en los últimos 100 episodios)
# Terminado episodio 489 con retorno 0.9464285714285714 en 4 pasos (retorno medio de 0.3431428571428571 en los últimos 100 episodios)
# Terminado episodio 490 con retorno 0.95 en 5 pasos (retorno medio de 0.3431428571428572 en los últimos 100 episodios)
# Terminado episodio 491 con retorno 0 en 4 pasos (retorno medio de 0.33517857142857144 en los últimos 100 episodios)
# Terminado episodio 492 con retorno 0 en 3 pasos (retorno medio de 0.33517857142857144 en los últimos 100 episodios)
# Terminado episodio 493 con retorno 0.9714285714285714 en 2 pasos (retorno medio de 0.3448928571428571 en los últimos 100 episodios)
# Terminado episodio 494 con retorno 0.9321428571428572 en 7 pasos (retorno medio de 0.3452142857142857 en los últimos 100 episodios)
# Terminado episodio 495 con retorno 0 en 5 pasos (retorno medio de 0.3452142857142857 en los últimos 100 episodios)
# Terminado episodio 496 con retorno 0 en 15 pasos (retorno medio de 0.34521428571428564 en los últimos 100 episodios)
# Terminado episodio 497 con retorno 0.9142857142857143 en 16 pasos (retorno medio de 0.34510714285714283 en los últimos 100 episodios)
# Terminado episodio 498 con retorno 0 en 10 pasos (retorno medio de 0.3359285714285714 en los últimos 100 episodios)
# Terminado episodio 499 con retorno 0.9428571428571428 en 5 pasos (retorno medio de 0.3357857142857143 en los últimos 100 episodios)
# ⮕⬇🟧🟧🟧⮕🟥
# ⬇⬇🟧🟧🟧⬆⮕
# ⬇⬇⮕⮕⮕⮕⮕
# ⬇⬇⮕⮕⮕⬆⮕
# ⮕⬆⬆⬆⬆⬅⬇

# %% [markdown]
# ### Comparativa SARSA vs Q-Learning
# Compara los resultados obtenidos por ambos algoritmos. Deberías observar lo siguiente:
#   - La política obtenida por SARSA es más conservadora (no quiere estar cerca de la lava), mientras que la de Q-learning es más optimista (no le importa estar cerca de la lava; confía en su política).
#   - Por tanto, los episodios de Q-learning son más cortos que los de SARSA.
#   - Sin embargo, al seguir una política $\epsilon$-greedy, estar en una casilla contigua a la lava desemboca en una recompensa de -1 (caer a la lava) un $\frac{\epsilon}{4}$ de las veces, por lo que el retorno medio de Q-learning es más bajo.
#
# Completa la siguiente celda para comprobarlo.

# %%
def comprueba_politica_derivada(q_values:np.ndarray, epsilon:float) -> None:
    env.reset()
    # TODO - Escribe un bucle que simule un episodio completo siguiendo una política COMPLETAMENTE GREEDY respecto a q_values
    # y muestra su duración y su retorno
    ...
    print(f'La política greedy hace un episodio de {contador} pasos con un retorno de {retorno}')

    env.reset()
    # TODO - Escribe otro bucle que simule 500 episodios siguiendo una política epsilon-greedy respecto a q_values
    # y muestra su duración media y su retorno medio
    ...
    print(f'La política greedy hace episodios de {np.mean(duraciones)} pasos de media con un retorno de {np.mean(retornos)} de media')

print('SARSA')
comprueba_politica_derivada(q_valores_sarsa_con_lava_negativa, 0.25)
dibuja_politica(q_valores_sarsa_con_lava_negativa)
print('\nQ-LEARNING')
comprueba_politica_derivada(q_valores_q, 0.25)
dibuja_politica(q_valores_q)
